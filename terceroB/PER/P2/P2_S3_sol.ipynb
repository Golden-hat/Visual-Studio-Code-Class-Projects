# %% [markdown]
# # AdaBoost y Gradient boosting con árboles en un dataset de detección de spam
#
# Árboles de decisión y todos los ensembles propuestos funcionan en la práctica muy bien en datos tabulares como puede ser el problema de reconocimiento de spam en mails.
#
# Se propone pues emplear el dataset id=44 de openml de detección de Spam. Son un total de 4601 muestras con 57 características.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)
# Out:
# (4601, 57)
# /usr/local/lib/python3.10/dist-packages/sklearn/datasets/_openml.py:968: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %% [markdown]
# ## AdaBoost
#
# Probemos el clasificador de AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

ab = AdaBoostClassifier()

acc=ab.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 93.8%

# %% [markdown]
# **Ejercicio** Teniendo en cuenta la documentación [AdaBoost](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html) prueba mediante grid search a encontrar mejores parámetros.

# %%
## Solución

from sklearn.model_selection import GridSearchCV

G = {"n_estimators":[50,100,150,200,400],"learning_rate":[0.01,0.1,0.2]}

GS = GridSearchCV(AdaBoostClassifier(), G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 15 candidates, totalling 75 fits
# [CV 1/5; 1/15] START learning_rate=0.01, n_estimators=50........................
# [CV 1/5; 1/15] END learning_rate=0.01, n_estimators=50;, score=0.844 total time=   0.8s
# [CV 2/5; 1/15] START learning_rate=0.01, n_estimators=50........................
# [CV 2/5; 1/15] END learning_rate=0.01, n_estimators=50;, score=0.827 total time=   0.7s
# [CV 3/5; 1/15] START learning_rate=0.01, n_estimators=50........................
# [CV 3/5; 1/15] END learning_rate=0.01, n_estimators=50;, score=0.870 total time=   0.8s
# [CV 4/5; 1/15] START learning_rate=0.01, n_estimators=50........................
# [CV 4/5; 1/15] END learning_rate=0.01, n_estimators=50;, score=0.838 total time=   0.8s
# [CV 5/5; 1/15] START learning_rate=0.01, n_estimators=50........................
# [CV 5/5; 1/15] END learning_rate=0.01, n_estimators=50;, score=0.834 total time=   0.8s
# [CV 1/5; 2/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 1/5; 2/15] END learning_rate=0.01, n_estimators=100;, score=0.864 total time=   1.2s
# [CV 2/5; 2/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 2/5; 2/15] END learning_rate=0.01, n_estimators=100;, score=0.870 total time=   1.0s
# [CV 3/5; 2/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 3/5; 2/15] END learning_rate=0.01, n_estimators=100;, score=0.880 total time=   1.0s
# [CV 4/5; 2/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 4/5; 2/15] END learning_rate=0.01, n_estimators=100;, score=0.867 total time=   1.0s
# [CV 5/5; 2/15] START learning_rate=0.01, n_estimators=100.......................
# [CV 5/5; 2/15] END learning_rate=0.01, n_estimators=100;, score=0.882 total time=   1.0s
# [CV 1/5; 3/15] START learning_rate=0.01, n_estimators=150.......................
# [CV 1/5; 3/15] END learning_rate=0.01, n_estimators=150;, score=0.897 total time=   1.5s
# [CV 2/5; 3/15] START learning_rate=0.01, n_estimators=150.......................
# [CV 2/5; 3/15] END learning_rate=0.01, n_estimators=150;, score=0.886 total time=   1.5s
# [CV 3/5; 3/15] START learning_rate=0.01, n_estimators=150.......................
# [CV 3/5; 3/15] END learning_rate=0.01, n_estimators=150;, score=0.880 total time=   1.5s
# [CV 4/5; 3/15] START learning_rate=0.01, n_estimators=150.......................
# [CV 4/5; 3/15] END learning_rate=0.01, n_estimators=150;, score=0.885 total time=   2.0s
# [CV 5/5; 3/15] START learning_rate=0.01, n_estimators=150.......................
# [CV 5/5; 3/15] END learning_rate=0.01, n_estimators=150;, score=0.894 total time=   2.3s
# [CV 1/5; 4/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 1/5; 4/15] END learning_rate=0.01, n_estimators=200;, score=0.904 total time=   2.0s
# [CV 2/5; 4/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 2/5; 4/15] END learning_rate=0.01, n_estimators=200;, score=0.887 total time=   2.0s
# [CV 3/5; 4/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 3/5; 4/15] END learning_rate=0.01, n_estimators=200;, score=0.897 total time=   2.0s
# [CV 4/5; 4/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 4/5; 4/15] END learning_rate=0.01, n_estimators=200;, score=0.889 total time=   2.0s
# [CV 5/5; 4/15] START learning_rate=0.01, n_estimators=200.......................
# [CV 5/5; 4/15] END learning_rate=0.01, n_estimators=200;, score=0.901 total time=   2.3s
# [CV 1/5; 5/15] START learning_rate=0.01, n_estimators=400.......................
# [CV 1/5; 5/15] END learning_rate=0.01, n_estimators=400;, score=0.920 total time=   5.0s
# [CV 2/5; 5/15] START learning_rate=0.01, n_estimators=400.......................
# [CV 2/5; 5/15] END learning_rate=0.01, n_estimators=400;, score=0.906 total time=   4.1s
# [CV 3/5; 5/15] START learning_rate=0.01, n_estimators=400.......................
# [CV 3/5; 5/15] END learning_rate=0.01, n_estimators=400;, score=0.925 total time=   4.4s
# [CV 4/5; 5/15] START learning_rate=0.01, n_estimators=400.......................
# [CV 4/5; 5/15] END learning_rate=0.01, n_estimators=400;, score=0.918 total time=   4.9s
# [CV 5/5; 5/15] START learning_rate=0.01, n_estimators=400.......................
# [CV 5/5; 5/15] END learning_rate=0.01, n_estimators=400;, score=0.914 total time=   4.1s
# [CV 1/5; 6/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 1/5; 6/15] END learning_rate=0.1, n_estimators=50;, score=0.925 total time=   0.5s
# [CV 2/5; 6/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 2/5; 6/15] END learning_rate=0.1, n_estimators=50;, score=0.909 total time=   0.5s
# [CV 3/5; 6/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 3/5; 6/15] END learning_rate=0.1, n_estimators=50;, score=0.927 total time=   0.5s
# [CV 4/5; 6/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 4/5; 6/15] END learning_rate=0.1, n_estimators=50;, score=0.921 total time=   0.5s
# [CV 5/5; 6/15] START learning_rate=0.1, n_estimators=50.........................
# [CV 5/5; 6/15] END learning_rate=0.1, n_estimators=50;, score=0.914 total time=   0.5s
# [CV 1/5; 7/15] START learning_rate=0.1, n_estimators=100........................
# [CV 1/5; 7/15] END learning_rate=0.1, n_estimators=100;, score=0.939 total time=   1.1s
# [CV 2/5; 7/15] START learning_rate=0.1, n_estimators=100........................
# [CV 2/5; 7/15] END learning_rate=0.1, n_estimators=100;, score=0.925 total time=   1.6s
# [CV 3/5; 7/15] START learning_rate=0.1, n_estimators=100........................
# [CV 3/5; 7/15] END learning_rate=0.1, n_estimators=100;, score=0.947 total time=   1.5s
# [CV 4/5; 7/15] START learning_rate=0.1, n_estimators=100........................
# [CV 4/5; 7/15] END learning_rate=0.1, n_estimators=100;, score=0.927 total time=   1.0s
# [CV 5/5; 7/15] START learning_rate=0.1, n_estimators=100........................
# [CV 5/5; 7/15] END learning_rate=0.1, n_estimators=100;, score=0.928 total time=   1.0s
# [CV 1/5; 8/15] START learning_rate=0.1, n_estimators=150........................
# [CV 1/5; 8/15] END learning_rate=0.1, n_estimators=150;, score=0.942 total time=   1.5s
# [CV 2/5; 8/15] START learning_rate=0.1, n_estimators=150........................
# [CV 2/5; 8/15] END learning_rate=0.1, n_estimators=150;, score=0.929 total time=   1.5s
# [CV 3/5; 8/15] START learning_rate=0.1, n_estimators=150........................
# [CV 3/5; 8/15] END learning_rate=0.1, n_estimators=150;, score=0.951 total time=   1.9s
# [CV 4/5; 8/15] START learning_rate=0.1, n_estimators=150........................
# [CV 4/5; 8/15] END learning_rate=0.1, n_estimators=150;, score=0.932 total time=   1.5s
# [CV 5/5; 8/15] START learning_rate=0.1, n_estimators=150........................
# [CV 5/5; 8/15] END learning_rate=0.1, n_estimators=150;, score=0.939 total time=   1.6s
# [CV 1/5; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 1/5; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.944 total time=   3.0s
# [CV 2/5; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 2/5; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.932 total time=   2.0s
# [CV 3/5; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 3/5; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.954 total time=   2.0s
# [CV 4/5; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 4/5; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.940 total time=   2.0s
# [CV 5/5; 9/15] START learning_rate=0.1, n_estimators=200........................
# [CV 5/5; 9/15] END learning_rate=0.1, n_estimators=200;, score=0.942 total time=   2.1s
# [CV 1/5; 10/15] START learning_rate=0.1, n_estimators=400.......................
# [CV 1/5; 10/15] END learning_rate=0.1, n_estimators=400;, score=0.939 total time=   5.3s
# [CV 2/5; 10/15] START learning_rate=0.1, n_estimators=400.......................
# [CV 2/5; 10/15] END learning_rate=0.1, n_estimators=400;, score=0.938 total time=   4.1s
# [CV 3/5; 10/15] START learning_rate=0.1, n_estimators=400.......................
# [CV 3/5; 10/15] END learning_rate=0.1, n_estimators=400;, score=0.958 total time=   4.1s
# [CV 4/5; 10/15] START learning_rate=0.1, n_estimators=400.......................
# [CV 4/5; 10/15] END learning_rate=0.1, n_estimators=400;, score=0.944 total time=   5.2s
# [CV 5/5; 10/15] START learning_rate=0.1, n_estimators=400.......................
# [CV 5/5; 10/15] END learning_rate=0.1, n_estimators=400;, score=0.948 total time=   4.1s
# [CV 1/5; 11/15] START learning_rate=0.2, n_estimators=50........................
# [CV 1/5; 11/15] END learning_rate=0.2, n_estimators=50;, score=0.940 total time=   0.5s
# [CV 2/5; 11/15] START learning_rate=0.2, n_estimators=50........................
# [CV 2/5; 11/15] END learning_rate=0.2, n_estimators=50;, score=0.928 total time=   0.5s
# [CV 3/5; 11/15] START learning_rate=0.2, n_estimators=50........................
# [CV 3/5; 11/15] END learning_rate=0.2, n_estimators=50;, score=0.938 total time=   0.5s
# [CV 4/5; 11/15] START learning_rate=0.2, n_estimators=50........................
# [CV 4/5; 11/15] END learning_rate=0.2, n_estimators=50;, score=0.929 total time=   0.5s
# [CV 5/5; 11/15] START learning_rate=0.2, n_estimators=50........................
# [CV 5/5; 11/15] END learning_rate=0.2, n_estimators=50;, score=0.925 total time=   0.5s
# [CV 1/5; 12/15] START learning_rate=0.2, n_estimators=100.......................
# [CV 1/5; 12/15] END learning_rate=0.2, n_estimators=100;, score=0.943 total time=   1.0s
# [CV 2/5; 12/15] START learning_rate=0.2, n_estimators=100.......................
# [CV 2/5; 12/15] END learning_rate=0.2, n_estimators=100;, score=0.933 total time=   1.0s
# [CV 3/5; 12/15] START learning_rate=0.2, n_estimators=100.......................
# [CV 3/5; 12/15] END learning_rate=0.2, n_estimators=100;, score=0.954 total time=   1.2s
# [CV 4/5; 12/15] START learning_rate=0.2, n_estimators=100.......................
# [CV 4/5; 12/15] END learning_rate=0.2, n_estimators=100;, score=0.936 total time=   1.6s
# [CV 5/5; 12/15] START learning_rate=0.2, n_estimators=100.......................
# [CV 5/5; 12/15] END learning_rate=0.2, n_estimators=100;, score=0.939 total time=   1.5s
# [CV 1/5; 13/15] START learning_rate=0.2, n_estimators=150.......................
# [CV 1/5; 13/15] END learning_rate=0.2, n_estimators=150;, score=0.940 total time=   1.5s
# [CV 2/5; 13/15] START learning_rate=0.2, n_estimators=150.......................
# [CV 2/5; 13/15] END learning_rate=0.2, n_estimators=150;, score=0.940 total time=   1.5s
# [CV 3/5; 13/15] START learning_rate=0.2, n_estimators=150.......................
# [CV 3/5; 13/15] END learning_rate=0.2, n_estimators=150;, score=0.959 total time=   1.5s
# [CV 4/5; 13/15] START learning_rate=0.2, n_estimators=150.......................
# [CV 4/5; 13/15] END learning_rate=0.2, n_estimators=150;, score=0.939 total time=   1.5s
# [CV 5/5; 13/15] START learning_rate=0.2, n_estimators=150.......................
# [CV 5/5; 13/15] END learning_rate=0.2, n_estimators=150;, score=0.948 total time=   1.5s
# [CV 1/5; 14/15] START learning_rate=0.2, n_estimators=200.......................
# [CV 1/5; 14/15] END learning_rate=0.2, n_estimators=200;, score=0.939 total time=   2.0s
# [CV 2/5; 14/15] START learning_rate=0.2, n_estimators=200.......................
# [CV 2/5; 14/15] END learning_rate=0.2, n_estimators=200;, score=0.946 total time=   3.1s
# [CV 3/5; 14/15] START learning_rate=0.2, n_estimators=200.......................
# [CV 3/5; 14/15] END learning_rate=0.2, n_estimators=200;, score=0.958 total time=   2.0s
# [CV 4/5; 14/15] START learning_rate=0.2, n_estimators=200.......................
# [CV 4/5; 14/15] END learning_rate=0.2, n_estimators=200;, score=0.940 total time=   2.0s
# [CV 5/5; 14/15] START learning_rate=0.2, n_estimators=200.......................
# [CV 5/5; 14/15] END learning_rate=0.2, n_estimators=200;, score=0.948 total time=   2.0s
# [CV 1/5; 15/15] START learning_rate=0.2, n_estimators=400.......................
# [CV 1/5; 15/15] END learning_rate=0.2, n_estimators=400;, score=0.943 total time=   4.1s
# [CV 2/5; 15/15] START learning_rate=0.2, n_estimators=400.......................
# [CV 2/5; 15/15] END learning_rate=0.2, n_estimators=400;, score=0.944 total time=   5.2s
# [CV 3/5; 15/15] START learning_rate=0.2, n_estimators=400.......................
# [CV 3/5; 15/15] END learning_rate=0.2, n_estimators=400;, score=0.961 total time=   4.1s
# [CV 4/5; 15/15] START learning_rate=0.2, n_estimators=400.......................
# [CV 4/5; 15/15] END learning_rate=0.2, n_estimators=400;, score=0.939 total time=   4.1s
# [CV 5/5; 15/15] START learning_rate=0.2, n_estimators=400.......................
# [CV 5/5; 15/15] END learning_rate=0.2, n_estimators=400;, score=0.952 total time=   6.6s
# Precisión: 94.2% con {'learning_rate': 0.2, 'n_estimators': 400}

# %% [markdown]
# ## GradientBoostingClassifier
#
# Probemos el clasificador Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()

acc=gb.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 95.2%

# %% [markdown]
# Los principales parámetros del GradientBoosting son:
# * n_estimators (100)
# * max_depth (3)
# * max_features
#
# **Ejercicio** prueba diferentes valores (lógicos) de estos parámetros mediante GridSearch.

# %%
## Solución, ATENCION puede tardar (>5-10 min) dependiendo de la máquina

from sklearn.model_selection import GridSearchCV

G = {"max_depth": [1,2,3,4],"n_estimators":[50,100,150,200],"max_features":[10,20,30,40,57]}

GS = GridSearchCV(GradientBoostingClassifier(), G, scoring='accuracy', refit=True, cv=5, verbose=10)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')
# Out:
# Fitting 5 folds for each of 80 candidates, totalling 400 fits
# [CV 1/5; 1/80] START max_depth=1, max_features=10, n_estimators=50..............
# [CV 1/5; 1/80] END max_depth=1, max_features=10, n_estimators=50;, score=0.920 total time=   0.1s
# [CV 2/5; 1/80] START max_depth=1, max_features=10, n_estimators=50..............
# [CV 2/5; 1/80] END max_depth=1, max_features=10, n_estimators=50;, score=0.901 total time=   0.1s
# [CV 3/5; 1/80] START max_depth=1, max_features=10, n_estimators=50..............
# [CV 3/5; 1/80] END max_depth=1, max_features=10, n_estimators=50;, score=0.918 total time=   0.1s
# [CV 4/5; 1/80] START max_depth=1, max_features=10, n_estimators=50..............
# [CV 4/5; 1/80] END max_depth=1, max_features=10, n_estimators=50;, score=0.909 total time=   0.1s
# [CV 5/5; 1/80] START max_depth=1, max_features=10, n_estimators=50..............
# [CV 5/5; 1/80] END max_depth=1, max_features=10, n_estimators=50;, score=0.921 total time=   0.1s
# [CV 1/5; 2/80] START max_depth=1, max_features=10, n_estimators=100.............
# [CV 1/5; 2/80] END max_depth=1, max_features=10, n_estimators=100;, score=0.940 total time=   0.2s
# [CV 2/5; 2/80] START max_depth=1, max_features=10, n_estimators=100.............
# [CV 2/5; 2/80] END max_depth=1, max_features=10, n_estimators=100;, score=0.916 total time=   0.3s
# [CV 3/5; 2/80] START max_depth=1, max_features=10, n_estimators=100.............
# [CV 3/5; 2/80] END max_depth=1, max_features=10, n_estimators=100;, score=0.932 total time=   0.3s
# [CV 4/5; 2/80] START max_depth=1, max_features=10, n_estimators=100.............
# [CV 4/5; 2/80] END max_depth=1, max_features=10, n_estimators=100;, score=0.928 total time=   0.4s
# [CV 5/5; 2/80] START max_depth=1, max_features=10, n_estimators=100.............
# [CV 5/5; 2/80] END max_depth=1, max_features=10, n_estimators=100;, score=0.924 total time=   0.5s
# [CV 1/5; 3/80] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 1/5; 3/80] END max_depth=1, max_features=10, n_estimators=150;, score=0.940 total time=   0.7s
# [CV 2/5; 3/80] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 2/5; 3/80] END max_depth=1, max_features=10, n_estimators=150;, score=0.924 total time=   0.5s
# [CV 3/5; 3/80] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 3/5; 3/80] END max_depth=1, max_features=10, n_estimators=150;, score=0.947 total time=   0.6s
# [CV 4/5; 3/80] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 4/5; 3/80] END max_depth=1, max_features=10, n_estimators=150;, score=0.935 total time=   1.1s
# [CV 5/5; 3/80] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 5/5; 3/80] END max_depth=1, max_features=10, n_estimators=150;, score=0.929 total time=   1.1s
# [CV 1/5; 4/80] START max_depth=1, max_features=10, n_estimators=200.............
# [CV 1/5; 4/80] END max_depth=1, max_features=10, n_estimators=200;, score=0.944 total time=   1.1s
# [CV 2/5; 4/80] START max_depth=1, max_features=10, n_estimators=200.............
# [CV 2/5; 4/80] END max_depth=1, max_features=10, n_estimators=200;, score=0.923 total time=   0.9s
# [CV 3/5; 4/80] START max_depth=1, max_features=10, n_estimators=200.............
# [CV 3/5; 4/80] END max_depth=1, max_features=10, n_estimators=200;, score=0.947 total time=   0.5s
# [CV 4/5; 4/80] START max_depth=1, max_features=10, n_estimators=200.............
# [CV 4/5; 4/80] END max_depth=1, max_features=10, n_estimators=200;, score=0.936 total time=   0.4s
# [CV 5/5; 4/80] START max_depth=1, max_features=10, n_estimators=200.............
# [CV 5/5; 4/80] END max_depth=1, max_features=10, n_estimators=200;, score=0.938 total time=   0.4s
# [CV 1/5; 5/80] START max_depth=1, max_features=20, n_estimators=50..............
# [CV 1/5; 5/80] END max_depth=1, max_features=20, n_estimators=50;, score=0.918 total time=   0.1s
# [CV 2/5; 5/80] START max_depth=1, max_features=20, n_estimators=50..............
# [CV 2/5; 5/80] END max_depth=1, max_features=20, n_estimators=50;, score=0.901 total time=   0.2s
# [CV 3/5; 5/80] START max_depth=1, max_features=20, n_estimators=50..............
# [CV 3/5; 5/80] END max_depth=1, max_features=20, n_estimators=50;, score=0.923 total time=   0.1s
# [CV 4/5; 5/80] START max_depth=1, max_features=20, n_estimators=50..............
# [CV 4/5; 5/80] END max_depth=1, max_features=20, n_estimators=50;, score=0.916 total time=   0.1s
# [CV 5/5; 5/80] START max_depth=1, max_features=20, n_estimators=50..............
# [CV 5/5; 5/80] END max_depth=1, max_features=20, n_estimators=50;, score=0.914 total time=   0.1s
# [CV 1/5; 6/80] START max_depth=1, max_features=20, n_estimators=100.............
# [CV 1/5; 6/80] END max_depth=1, max_features=20, n_estimators=100;, score=0.929 total time=   0.3s
# [CV 2/5; 6/80] START max_depth=1, max_features=20, n_estimators=100.............
# [CV 2/5; 6/80] END max_depth=1, max_features=20, n_estimators=100;, score=0.913 total time=   0.3s
# [CV 3/5; 6/80] START max_depth=1, max_features=20, n_estimators=100.............
# [CV 3/5; 6/80] END max_depth=1, max_features=20, n_estimators=100;, score=0.935 total time=   0.3s
# [CV 4/5; 6/80] START max_depth=1, max_features=20, n_estimators=100.............
# [CV 4/5; 6/80] END max_depth=1, max_features=20, n_estimators=100;, score=0.927 total time=   0.3s
# [CV 5/5; 6/80] START max_depth=1, max_features=20, n_estimators=100.............
# [CV 5/5; 6/80] END max_depth=1, max_features=20, n_estimators=100;, score=0.929 total time=   0.3s
# [CV 1/5; 7/80] START max_depth=1, max_features=20, n_estimators=150.............
# [CV 1/5; 7/80] END max_depth=1, max_features=20, n_estimators=150;, score=0.942 total time=   0.4s
# [CV 2/5; 7/80] START max_depth=1, max_features=20, n_estimators=150.............
# [CV 2/5; 7/80] END max_depth=1, max_features=20, n_estimators=150;, score=0.921 total time=   0.4s
# [CV 3/5; 7/80] START max_depth=1, max_features=20, n_estimators=150.............
# [CV 3/5; 7/80] END max_depth=1, max_features=20, n_estimators=150;, score=0.943 total time=   0.4s
# [CV 4/5; 7/80] START max_depth=1, max_features=20, n_estimators=150.............
# [CV 4/5; 7/80] END max_depth=1, max_features=20, n_estimators=150;, score=0.935 total time=   0.4s
# [CV 5/5; 7/80] START max_depth=1, max_features=20, n_estimators=150.............
# [CV 5/5; 7/80] END max_depth=1, max_features=20, n_estimators=150;, score=0.939 total time=   0.4s
# [CV 1/5; 8/80] START max_depth=1, max_features=20, n_estimators=200.............
# [CV 1/5; 8/80] END max_depth=1, max_features=20, n_estimators=200;, score=0.946 total time=   0.5s
# [CV 2/5; 8/80] START max_depth=1, max_features=20, n_estimators=200.............
# [CV 2/5; 8/80] END max_depth=1, max_features=20, n_estimators=200;, score=0.927 total time=   0.5s
# [CV 3/5; 8/80] START max_depth=1, max_features=20, n_estimators=200.............
# [CV 3/5; 8/80] END max_depth=1, max_features=20, n_estimators=200;, score=0.948 total time=   0.6s
# [CV 4/5; 8/80] START max_depth=1, max_features=20, n_estimators=200.............
# [CV 4/5; 8/80] END max_depth=1, max_features=20, n_estimators=200;, score=0.939 total time=   0.7s
# [CV 5/5; 8/80] START max_depth=1, max_features=20, n_estimators=200.............
# [CV 5/5; 8/80] END max_depth=1, max_features=20, n_estimators=200;, score=0.940 total time=   0.6s
# [CV 1/5; 9/80] START max_depth=1, max_features=30, n_estimators=50..............
# [CV 1/5; 9/80] END max_depth=1, max_features=30, n_estimators=50;, score=0.918 total time=   0.2s
# [CV 2/5; 9/80] START max_depth=1, max_features=30, n_estimators=50..............
# [CV 2/5; 9/80] END max_depth=1, max_features=30, n_estimators=50;, score=0.905 total time=   0.2s
# [CV 3/5; 9/80] START max_depth=1, max_features=30, n_estimators=50..............
# [CV 3/5; 9/80] END max_depth=1, max_features=30, n_estimators=50;, score=0.923 total time=   0.2s
# [CV 4/5; 9/80] START max_depth=1, max_features=30, n_estimators=50..............
# [CV 4/5; 9/80] END max_depth=1, max_features=30, n_estimators=50;, score=0.917 total time=   0.2s
# [CV 5/5; 9/80] START max_depth=1, max_features=30, n_estimators=50..............
# [CV 5/5; 9/80] END max_depth=1, max_features=30, n_estimators=50;, score=0.914 total time=   0.2s
# [CV 1/5; 10/80] START max_depth=1, max_features=30, n_estimators=100............
# [CV 1/5; 10/80] END max_depth=1, max_features=30, n_estimators=100;, score=0.932 total time=   0.4s
# [CV 2/5; 10/80] START max_depth=1, max_features=30, n_estimators=100............
# [CV 2/5; 10/80] END max_depth=1, max_features=30, n_estimators=100;, score=0.909 total time=   0.3s
# [CV 3/5; 10/80] START max_depth=1, max_features=30, n_estimators=100............
# [CV 3/5; 10/80] END max_depth=1, max_features=30, n_estimators=100;, score=0.933 total time=   0.4s
# [CV 4/5; 10/80] START max_depth=1, max_features=30, n_estimators=100............
# [CV 4/5; 10/80] END max_depth=1, max_features=30, n_estimators=100;, score=0.929 total time=   0.7s
# [CV 5/5; 10/80] START max_depth=1, max_features=30, n_estimators=100............
# [CV 5/5; 10/80] END max_depth=1, max_features=30, n_estimators=100;, score=0.925 total time=   0.6s
# [CV 1/5; 11/80] START max_depth=1, max_features=30, n_estimators=150............
# [CV 1/5; 11/80] END max_depth=1, max_features=30, n_estimators=150;, score=0.940 total time=   0.9s
# [CV 2/5; 11/80] START max_depth=1, max_features=30, n_estimators=150............
# [CV 2/5; 11/80] END max_depth=1, max_features=30, n_estimators=150;, score=0.924 total time=   1.0s
# [CV 3/5; 11/80] START max_depth=1, max_features=30, n_estimators=150............
# [CV 3/5; 11/80] END max_depth=1, max_features=30, n_estimators=150;, score=0.944 total time=   0.8s
# [CV 4/5; 11/80] START max_depth=1, max_features=30, n_estimators=150............
# [CV 4/5; 11/80] END max_depth=1, max_features=30, n_estimators=150;, score=0.933 total time=   0.9s
# [CV 5/5; 11/80] START max_depth=1, max_features=30, n_estimators=150............
# [CV 5/5; 11/80] END max_depth=1, max_features=30, n_estimators=150;, score=0.935 total time=   0.6s
# [CV 1/5; 12/80] START max_depth=1, max_features=30, n_estimators=200............
# [CV 1/5; 12/80] END max_depth=1, max_features=30, n_estimators=200;, score=0.944 total time=   0.7s
# [CV 2/5; 12/80] START max_depth=1, max_features=30, n_estimators=200............
# [CV 2/5; 12/80] END max_depth=1, max_features=30, n_estimators=200;, score=0.928 total time=   1.2s
# [CV 3/5; 12/80] START max_depth=1, max_features=30, n_estimators=200............
# [CV 3/5; 12/80] END max_depth=1, max_features=30, n_estimators=200;, score=0.948 total time=   0.7s
# [CV 4/5; 12/80] START max_depth=1, max_features=30, n_estimators=200............
# [CV 4/5; 12/80] END max_depth=1, max_features=30, n_estimators=200;, score=0.938 total time=   0.7s
# [CV 5/5; 12/80] START max_depth=1, max_features=30, n_estimators=200............
# [CV 5/5; 12/80] END max_depth=1, max_features=30, n_estimators=200;, score=0.939 total time=   0.8s
# [CV 1/5; 13/80] START max_depth=1, max_features=40, n_estimators=50.............
# [CV 1/5; 13/80] END max_depth=1, max_features=40, n_estimators=50;, score=0.918 total time=   0.2s
# [CV 2/5; 13/80] START max_depth=1, max_features=40, n_estimators=50.............
# [CV 2/5; 13/80] END max_depth=1, max_features=40, n_estimators=50;, score=0.904 total time=   0.2s
# [CV 3/5; 13/80] START max_depth=1, max_features=40, n_estimators=50.............
# [CV 3/5; 13/80] END max_depth=1, max_features=40, n_estimators=50;, score=0.920 total time=   0.4s
# [CV 4/5; 13/80] START max_depth=1, max_features=40, n_estimators=50.............
# [CV 4/5; 13/80] END max_depth=1, max_features=40, n_estimators=50;, score=0.910 total time=   0.6s
# [CV 5/5; 13/80] START max_depth=1, max_features=40, n_estimators=50.............
# [CV 5/5; 13/80] END max_depth=1, max_features=40, n_estimators=50;, score=0.913 total time=   0.3s
# [CV 1/5; 14/80] START max_depth=1, max_features=40, n_estimators=100............
# [CV 1/5; 14/80] END max_depth=1, max_features=40, n_estimators=100;, score=0.932 total time=   0.7s
# [CV 2/5; 14/80] START max_depth=1, max_features=40, n_estimators=100............
# [CV 2/5; 14/80] END max_depth=1, max_features=40, n_estimators=100;, score=0.912 total time=   0.6s
# [CV 3/5; 14/80] START max_depth=1, max_features=40, n_estimators=100............
# [CV 3/5; 14/80] END max_depth=1, max_features=40, n_estimators=100;, score=0.933 total time=   0.7s
# [CV 4/5; 14/80] START max_depth=1, max_features=40, n_estimators=100............
# [CV 4/5; 14/80] END max_depth=1, max_features=40, n_estimators=100;, score=0.927 total time=   0.8s
# [CV 5/5; 14/80] START max_depth=1, max_features=40, n_estimators=100............
# [CV 5/5; 14/80] END max_depth=1, max_features=40, n_estimators=100;, score=0.927 total time=   0.6s
# [CV 1/5; 15/80] START max_depth=1, max_features=40, n_estimators=150............
# [CV 1/5; 15/80] END max_depth=1, max_features=40, n_estimators=150;, score=0.940 total time=   0.9s
# [CV 2/5; 15/80] START max_depth=1, max_features=40, n_estimators=150............
# [CV 2/5; 15/80] END max_depth=1, max_features=40, n_estimators=150;, score=0.924 total time=   0.9s
# [CV 3/5; 15/80] START max_depth=1, max_features=40, n_estimators=150............
# [CV 3/5; 15/80] END max_depth=1, max_features=40, n_estimators=150;, score=0.944 total time=   0.8s
# [CV 4/5; 15/80] START max_depth=1, max_features=40, n_estimators=150............
# [CV 4/5; 15/80] END max_depth=1, max_features=40, n_estimators=150;, score=0.931 total time=   0.6s
# [CV 5/5; 15/80] START max_depth=1, max_features=40, n_estimators=150............
# [CV 5/5; 15/80] END max_depth=1, max_features=40, n_estimators=150;, score=0.936 total time=   0.6s
# [CV 1/5; 16/80] START max_depth=1, max_features=40, n_estimators=200............
# [CV 1/5; 16/80] END max_depth=1, max_features=40, n_estimators=200;, score=0.946 total time=   0.8s
# [CV 2/5; 16/80] START max_depth=1, max_features=40, n_estimators=200............
# [CV 2/5; 16/80] END max_depth=1, max_features=40, n_estimators=200;, score=0.924 total time=   0.8s
# [CV 3/5; 16/80] START max_depth=1, max_features=40, n_estimators=200............
# [CV 3/5; 16/80] END max_depth=1, max_features=40, n_estimators=200;, score=0.948 total time=   0.8s
# [CV 4/5; 16/80] START max_depth=1, max_features=40, n_estimators=200............
# [CV 4/5; 16/80] END max_depth=1, max_features=40, n_estimators=200;, score=0.938 total time=   0.8s
# [CV 5/5; 16/80] START max_depth=1, max_features=40, n_estimators=200............
# [CV 5/5; 16/80] END max_depth=1, max_features=40, n_estimators=200;, score=0.942 total time=   0.8s
# [CV 1/5; 17/80] START max_depth=1, max_features=57, n_estimators=50.............
# [CV 1/5; 17/80] END max_depth=1, max_features=57, n_estimators=50;, score=0.920 total time=   0.3s
# [CV 2/5; 17/80] START max_depth=1, max_features=57, n_estimators=50.............
# [CV 2/5; 17/80] END max_depth=1, max_features=57, n_estimators=50;, score=0.904 total time=   0.3s
# [CV 3/5; 17/80] START max_depth=1, max_features=57, n_estimators=50.............
# [CV 3/5; 17/80] END max_depth=1, max_features=57, n_estimators=50;, score=0.921 total time=   0.3s
# [CV 4/5; 17/80] START max_depth=1, max_features=57, n_estimators=50.............
# [CV 4/5; 17/80] END max_depth=1, max_features=57, n_estimators=50;, score=0.912 total time=   0.3s
# [CV 5/5; 17/80] START max_depth=1, max_features=57, n_estimators=50.............
# [CV 5/5; 17/80] END max_depth=1, max_features=57, n_estimators=50;, score=0.914 total time=   0.3s
# [CV 1/5; 18/80] START max_depth=1, max_features=57, n_estimators=100............
# [CV 1/5; 18/80] END max_depth=1, max_features=57, n_estimators=100;, score=0.932 total time=   0.5s
# [CV 2/5; 18/80] START max_depth=1, max_features=57, n_estimators=100............
# [CV 2/5; 18/80] END max_depth=1, max_features=57, n_estimators=100;, score=0.910 total time=   0.5s
# [CV 3/5; 18/80] START max_depth=1, max_features=57, n_estimators=100............
# [CV 3/5; 18/80] END max_depth=1, max_features=57, n_estimators=100;, score=0.940 total time=   0.5s
# [CV 4/5; 18/80] START max_depth=1, max_features=57, n_estimators=100............
# [CV 4/5; 18/80] END max_depth=1, max_features=57, n_estimators=100;, score=0.927 total time=   0.5s
# [CV 5/5; 18/80] START max_depth=1, max_features=57, n_estimators=100............
# [CV 5/5; 18/80] END max_depth=1, max_features=57, n_estimators=100;, score=0.925 total time=   0.5s
# [CV 1/5; 19/80] START max_depth=1, max_features=57, n_estimators=150............
# [CV 1/5; 19/80] END max_depth=1, max_features=57, n_estimators=150;, score=0.942 total time=   0.9s
# [CV 2/5; 19/80] START max_depth=1, max_features=57, n_estimators=150............
# [CV 2/5; 19/80] END max_depth=1, max_features=57, n_estimators=150;, score=0.924 total time=   1.1s
# [CV 3/5; 19/80] START max_depth=1, max_features=57, n_estimators=150............
# [CV 3/5; 19/80] END max_depth=1, max_features=57, n_estimators=150;, score=0.944 total time=   1.1s
# [CV 4/5; 19/80] START max_depth=1, max_features=57, n_estimators=150............
# [CV 4/5; 19/80] END max_depth=1, max_features=57, n_estimators=150;, score=0.933 total time=   1.0s
# [CV 5/5; 19/80] START max_depth=1, max_features=57, n_estimators=150............
# [CV 5/5; 19/80] END max_depth=1, max_features=57, n_estimators=150;, score=0.938 total time=   0.8s
# [CV 1/5; 20/80] START max_depth=1, max_features=57, n_estimators=200............
# [CV 1/5; 20/80] END max_depth=1, max_features=57, n_estimators=200;, score=0.944 total time=   1.1s
# [CV 2/5; 20/80] START max_depth=1, max_features=57, n_estimators=200............
# [CV 2/5; 20/80] END max_depth=1, max_features=57, n_estimators=200;, score=0.929 total time=   1.0s
# [CV 3/5; 20/80] START max_depth=1, max_features=57, n_estimators=200............
# [CV 3/5; 20/80] END max_depth=1, max_features=57, n_estimators=200;, score=0.950 total time=   1.0s
# [CV 4/5; 20/80] START max_depth=1, max_features=57, n_estimators=200............
# [CV 4/5; 20/80] END max_depth=1, max_features=57, n_estimators=200;, score=0.939 total time=   1.0s
# [CV 5/5; 20/80] START max_depth=1, max_features=57, n_estimators=200............
# [CV 5/5; 20/80] END max_depth=1, max_features=57, n_estimators=200;, score=0.940 total time=   1.1s
# [CV 1/5; 21/80] START max_depth=2, max_features=10, n_estimators=50.............
# [CV 1/5; 21/80] END max_depth=2, max_features=10, n_estimators=50;, score=0.939 total time=   0.1s
# [CV 2/5; 21/80] START max_depth=2, max_features=10, n_estimators=50.............
# [CV 2/5; 21/80] END max_depth=2, max_features=10, n_estimators=50;, score=0.920 total time=   0.1s
# [CV 3/5; 21/80] START max_depth=2, max_features=10, n_estimators=50.............
# [CV 3/5; 21/80] END max_depth=2, max_features=10, n_estimators=50;, score=0.938 total time=   0.1s
# [CV 4/5; 21/80] START max_depth=2, max_features=10, n_estimators=50.............
# [CV 4/5; 21/80] END max_depth=2, max_features=10, n_estimators=50;, score=0.933 total time=   0.1s
# [CV 5/5; 21/80] START max_depth=2, max_features=10, n_estimators=50.............
# [CV 5/5; 21/80] END max_depth=2, max_features=10, n_estimators=50;, score=0.923 total time=   0.1s
# [CV 1/5; 22/80] START max_depth=2, max_features=10, n_estimators=100............
# [CV 1/5; 22/80] END max_depth=2, max_features=10, n_estimators=100;, score=0.943 total time=   0.3s
# [CV 2/5; 22/80] START max_depth=2, max_features=10, n_estimators=100............
# [CV 2/5; 22/80] END max_depth=2, max_features=10, n_estimators=100;, score=0.925 total time=   0.3s
# [CV 3/5; 22/80] START max_depth=2, max_features=10, n_estimators=100............
# [CV 3/5; 22/80] END max_depth=2, max_features=10, n_estimators=100;, score=0.948 total time=   0.3s
# [CV 4/5; 22/80] START max_depth=2, max_features=10, n_estimators=100............
# [CV 4/5; 22/80] END max_depth=2, max_features=10, n_estimators=100;, score=0.936 total time=   0.3s
# [CV 5/5; 22/80] START max_depth=2, max_features=10, n_estimators=100............
# [CV 5/5; 22/80] END max_depth=2, max_features=10, n_estimators=100;, score=0.940 total time=   0.3s
# [CV 1/5; 23/80] START max_depth=2, max_features=10, n_estimators=150............
# [CV 1/5; 23/80] END max_depth=2, max_features=10, n_estimators=150;, score=0.947 total time=   0.4s
# [CV 2/5; 23/80] START max_depth=2, max_features=10, n_estimators=150............
# [CV 2/5; 23/80] END max_depth=2, max_features=10, n_estimators=150;, score=0.935 total time=   0.4s
# [CV 3/5; 23/80] START max_depth=2, max_features=10, n_estimators=150............
# [CV 3/5; 23/80] END max_depth=2, max_features=10, n_estimators=150;, score=0.955 total time=   0.4s
# [CV 4/5; 23/80] START max_depth=2, max_features=10, n_estimators=150............
# [CV 4/5; 23/80] END max_depth=2, max_features=10, n_estimators=150;, score=0.938 total time=   0.4s
# [CV 5/5; 23/80] START max_depth=2, max_features=10, n_estimators=150............
# [CV 5/5; 23/80] END max_depth=2, max_features=10, n_estimators=150;, score=0.948 total time=   0.6s
# [CV 1/5; 24/80] START max_depth=2, max_features=10, n_estimators=200............
# [CV 1/5; 24/80] END max_depth=2, max_features=10, n_estimators=200;, score=0.944 total time=   0.8s
# [CV 2/5; 24/80] START max_depth=2, max_features=10, n_estimators=200............
# [CV 2/5; 24/80] END max_depth=2, max_features=10, n_estimators=200;, score=0.940 total time=   0.8s
# [CV 3/5; 24/80] START max_depth=2, max_features=10, n_estimators=200............
# [CV 3/5; 24/80] END max_depth=2, max_features=10, n_estimators=200;, score=0.961 total time=   0.8s
# [CV 4/5; 24/80] START max_depth=2, max_features=10, n_estimators=200............
# [CV 4/5; 24/80] END max_depth=2, max_features=10, n_estimators=200;, score=0.942 total time=   0.9s
# [CV 5/5; 24/80] START max_depth=2, max_features=10, n_estimators=200............
# [CV 5/5; 24/80] END max_depth=2, max_features=10, n_estimators=200;, score=0.950 total time=   0.8s
# [CV 1/5; 25/80] START max_depth=2, max_features=20, n_estimators=50.............
# [CV 1/5; 25/80] END max_depth=2, max_features=20, n_estimators=50;, score=0.936 total time=   0.3s
# [CV 2/5; 25/80] START max_depth=2, max_features=20, n_estimators=50.............
# [CV 2/5; 25/80] END max_depth=2, max_features=20, n_estimators=50;, score=0.920 total time=   0.3s
# [CV 3/5; 25/80] START max_depth=2, max_features=20, n_estimators=50.............
# [CV 3/5; 25/80] END max_depth=2, max_features=20, n_estimators=50;, score=0.940 total time=   0.3s
# [CV 4/5; 25/80] START max_depth=2, max_features=20, n_estimators=50.............
# [CV 4/5; 25/80] END max_depth=2, max_features=20, n_estimators=50;, score=0.929 total time=   0.3s
# [CV 5/5; 25/80] START max_depth=2, max_features=20, n_estimators=50.............
# [CV 5/5; 25/80] END max_depth=2, max_features=20, n_estimators=50;, score=0.931 total time=   0.4s
# [CV 1/5; 26/80] START max_depth=2, max_features=20, n_estimators=100............
# [CV 1/5; 26/80] END max_depth=2, max_features=20, n_estimators=100;, score=0.944 total time=   0.5s
# [CV 2/5; 26/80] START max_depth=2, max_features=20, n_estimators=100............
# [CV 2/5; 26/80] END max_depth=2, max_features=20, n_estimators=100;, score=0.929 total time=   0.4s
# [CV 3/5; 26/80] START max_depth=2, max_features=20, n_estimators=100............
# [CV 3/5; 26/80] END max_depth=2, max_features=20, n_estimators=100;, score=0.946 total time=   0.4s
# [CV 4/5; 26/80] START max_depth=2, max_features=20, n_estimators=100............
# [CV 4/5; 26/80] END max_depth=2, max_features=20, n_estimators=100;, score=0.935 total time=   0.4s
# [CV 5/5; 26/80] START max_depth=2, max_features=20, n_estimators=100............
# [CV 5/5; 26/80] END max_depth=2, max_features=20, n_estimators=100;, score=0.944 total time=   0.4s
# [CV 1/5; 27/80] START max_depth=2, max_features=20, n_estimators=150............
# [CV 1/5; 27/80] END max_depth=2, max_features=20, n_estimators=150;, score=0.947 total time=   0.6s
# [CV 2/5; 27/80] START max_depth=2, max_features=20, n_estimators=150............
# [CV 2/5; 27/80] END max_depth=2, max_features=20, n_estimators=150;, score=0.940 total time=   0.6s
# [CV 3/5; 27/80] START max_depth=2, max_features=20, n_estimators=150............
# [CV 3/5; 27/80] END max_depth=2, max_features=20, n_estimators=150;, score=0.955 total time=   0.6s
# [CV 4/5; 27/80] START max_depth=2, max_features=20, n_estimators=150............
# [CV 4/5; 27/80] END max_depth=2, max_features=20, n_estimators=150;, score=0.933 total time=   0.6s
# [CV 5/5; 27/80] START max_depth=2, max_features=20, n_estimators=150............
# [CV 5/5; 27/80] END max_depth=2, max_features=20, n_estimators=150;, score=0.952 total time=   0.6s
# [CV 1/5; 28/80] START max_depth=2, max_features=20, n_estimators=200............
# [CV 1/5; 28/80] END max_depth=2, max_features=20, n_estimators=200;, score=0.948 total time=   0.8s
# [CV 2/5; 28/80] START max_depth=2, max_features=20, n_estimators=200............
# [CV 2/5; 28/80] END max_depth=2, max_features=20, n_estimators=200;, score=0.943 total time=   0.8s
# [CV 3/5; 28/80] START max_depth=2, max_features=20, n_estimators=200............
# [CV 3/5; 28/80] END max_depth=2, max_features=20, n_estimators=200;, score=0.958 total time=   1.1s
# [CV 4/5; 28/80] START max_depth=2, max_features=20, n_estimators=200............
# [CV 4/5; 28/80] END max_depth=2, max_features=20, n_estimators=200;, score=0.940 total time=   1.2s
# [CV 5/5; 28/80] START max_depth=2, max_features=20, n_estimators=200............
# [CV 5/5; 28/80] END max_depth=2, max_features=20, n_estimators=200;, score=0.955 total time=   1.1s
# [CV 1/5; 29/80] START max_depth=2, max_features=30, n_estimators=50.............
# [CV 1/5; 29/80] END max_depth=2, max_features=30, n_estimators=50;, score=0.940 total time=   0.3s
# [CV 2/5; 29/80] START max_depth=2, max_features=30, n_estimators=50.............
# [CV 2/5; 29/80] END max_depth=2, max_features=30, n_estimators=50;, score=0.920 total time=   0.3s
# [CV 3/5; 29/80] START max_depth=2, max_features=30, n_estimators=50.............
# [CV 3/5; 29/80] END max_depth=2, max_features=30, n_estimators=50;, score=0.940 total time=   0.3s
# [CV 4/5; 29/80] START max_depth=2, max_features=30, n_estimators=50.............
# [CV 4/5; 29/80] END max_depth=2, max_features=30, n_estimators=50;, score=0.931 total time=   0.3s
# [CV 5/5; 29/80] START max_depth=2, max_features=30, n_estimators=50.............
# [CV 5/5; 29/80] END max_depth=2, max_features=30, n_estimators=50;, score=0.931 total time=   0.3s
# [CV 1/5; 30/80] START max_depth=2, max_features=30, n_estimators=100............
# [CV 1/5; 30/80] END max_depth=2, max_features=30, n_estimators=100;, score=0.944 total time=   0.6s
# [CV 2/5; 30/80] START max_depth=2, max_features=30, n_estimators=100............
# [CV 2/5; 30/80] END max_depth=2, max_features=30, n_estimators=100;, score=0.933 total time=   0.6s
# [CV 3/5; 30/80] START max_depth=2, max_features=30, n_estimators=100............
# [CV 3/5; 30/80] END max_depth=2, max_features=30, n_estimators=100;, score=0.946 total time=   0.6s
# [CV 4/5; 30/80] START max_depth=2, max_features=30, n_estimators=100............
# [CV 4/5; 30/80] END max_depth=2, max_features=30, n_estimators=100;, score=0.935 total time=   0.6s
# [CV 5/5; 30/80] START max_depth=2, max_features=30, n_estimators=100............
# [CV 5/5; 30/80] END max_depth=2, max_features=30, n_estimators=100;, score=0.948 total time=   0.6s
# [CV 1/5; 31/80] START max_depth=2, max_features=30, n_estimators=150............
# [CV 1/5; 31/80] END max_depth=2, max_features=30, n_estimators=150;, score=0.944 total time=   0.8s
# [CV 2/5; 31/80] START max_depth=2, max_features=30, n_estimators=150............
# [CV 2/5; 31/80] END max_depth=2, max_features=30, n_estimators=150;, score=0.939 total time=   0.8s
# [CV 3/5; 31/80] START max_depth=2, max_features=30, n_estimators=150............
# [CV 3/5; 31/80] END max_depth=2, max_features=30, n_estimators=150;, score=0.952 total time=   0.8s
# [CV 4/5; 31/80] START max_depth=2, max_features=30, n_estimators=150............
# [CV 4/5; 31/80] END max_depth=2, max_features=30, n_estimators=150;, score=0.938 total time=   0.8s
# [CV 5/5; 31/80] START max_depth=2, max_features=30, n_estimators=150............
# [CV 5/5; 31/80] END max_depth=2, max_features=30, n_estimators=150;, score=0.950 total time=   0.9s
# [CV 1/5; 32/80] START max_depth=2, max_features=30, n_estimators=200............
# [CV 1/5; 32/80] END max_depth=2, max_features=30, n_estimators=200;, score=0.943 total time=   1.1s
# [CV 2/5; 32/80] START max_depth=2, max_features=30, n_estimators=200............
# [CV 2/5; 32/80] END max_depth=2, max_features=30, n_estimators=200;, score=0.943 total time=   1.5s
# [CV 3/5; 32/80] START max_depth=2, max_features=30, n_estimators=200............
# [CV 3/5; 32/80] END max_depth=2, max_features=30, n_estimators=200;, score=0.958 total time=   1.6s
# [CV 4/5; 32/80] START max_depth=2, max_features=30, n_estimators=200............
# [CV 4/5; 32/80] END max_depth=2, max_features=30, n_estimators=200;, score=0.942 total time=   1.3s
# [CV 5/5; 32/80] START max_depth=2, max_features=30, n_estimators=200............
# [CV 5/5; 32/80] END max_depth=2, max_features=30, n_estimators=200;, score=0.954 total time=   1.1s
# [CV 1/5; 33/80] START max_depth=2, max_features=40, n_estimators=50.............
# [CV 1/5; 33/80] END max_depth=2, max_features=40, n_estimators=50;, score=0.935 total time=   0.4s
# [CV 2/5; 33/80] START max_depth=2, max_features=40, n_estimators=50.............
# [CV 2/5; 33/80] END max_depth=2, max_features=40, n_estimators=50;, score=0.920 total time=   0.4s
# [CV 3/5; 33/80] START max_depth=2, max_features=40, n_estimators=50.............
# [CV 3/5; 33/80] END max_depth=2, max_features=40, n_estimators=50;, score=0.936 total time=   0.4s
# [CV 4/5; 33/80] START max_depth=2, max_features=40, n_estimators=50.............
# [CV 4/5; 33/80] END max_depth=2, max_features=40, n_estimators=50;, score=0.931 total time=   0.4s
# [CV 5/5; 33/80] START max_depth=2, max_features=40, n_estimators=50.............
# [CV 5/5; 33/80] END max_depth=2, max_features=40, n_estimators=50;, score=0.928 total time=   0.4s
# [CV 1/5; 34/80] START max_depth=2, max_features=40, n_estimators=100............
# [CV 1/5; 34/80] END max_depth=2, max_features=40, n_estimators=100;, score=0.939 total time=   0.7s
# [CV 2/5; 34/80] START max_depth=2, max_features=40, n_estimators=100............
# [CV 2/5; 34/80] END max_depth=2, max_features=40, n_estimators=100;, score=0.932 total time=   0.7s
# [CV 3/5; 34/80] START max_depth=2, max_features=40, n_estimators=100............
# [CV 3/5; 34/80] END max_depth=2, max_features=40, n_estimators=100;, score=0.948 total time=   0.7s
# [CV 4/5; 34/80] START max_depth=2, max_features=40, n_estimators=100............
# [CV 4/5; 34/80] END max_depth=2, max_features=40, n_estimators=100;, score=0.933 total time=   0.7s
# [CV 5/5; 34/80] START max_depth=2, max_features=40, n_estimators=100............
# [CV 5/5; 34/80] END max_depth=2, max_features=40, n_estimators=100;, score=0.948 total time=   0.7s
# [CV 1/5; 35/80] START max_depth=2, max_features=40, n_estimators=150............
# [CV 1/5; 35/80] END max_depth=2, max_features=40, n_estimators=150;, score=0.950 total time=   1.0s
# [CV 2/5; 35/80] START max_depth=2, max_features=40, n_estimators=150............
# [CV 2/5; 35/80] END max_depth=2, max_features=40, n_estimators=150;, score=0.943 total time=   1.0s
# [CV 3/5; 35/80] START max_depth=2, max_features=40, n_estimators=150............
# [CV 3/5; 35/80] END max_depth=2, max_features=40, n_estimators=150;, score=0.952 total time=   1.2s
# [CV 4/5; 35/80] START max_depth=2, max_features=40, n_estimators=150............
# [CV 4/5; 35/80] END max_depth=2, max_features=40, n_estimators=150;, score=0.938 total time=   1.4s
# [CV 5/5; 35/80] START max_depth=2, max_features=40, n_estimators=150............
# [CV 5/5; 35/80] END max_depth=2, max_features=40, n_estimators=150;, score=0.951 total time=   1.5s
# [CV 1/5; 36/80] START max_depth=2, max_features=40, n_estimators=200............
# [CV 1/5; 36/80] END max_depth=2, max_features=40, n_estimators=200;, score=0.947 total time=   1.4s
# [CV 2/5; 36/80] START max_depth=2, max_features=40, n_estimators=200............
# [CV 2/5; 36/80] END max_depth=2, max_features=40, n_estimators=200;, score=0.950 total time=   1.4s
# [CV 3/5; 36/80] START max_depth=2, max_features=40, n_estimators=200............
# [CV 3/5; 36/80] END max_depth=2, max_features=40, n_estimators=200;, score=0.955 total time=   1.4s
# [CV 4/5; 36/80] START max_depth=2, max_features=40, n_estimators=200............
# [CV 4/5; 36/80] END max_depth=2, max_features=40, n_estimators=200;, score=0.936 total time=   1.4s
# [CV 5/5; 36/80] START max_depth=2, max_features=40, n_estimators=200............
# [CV 5/5; 36/80] END max_depth=2, max_features=40, n_estimators=200;, score=0.958 total time=   1.4s
# [CV 1/5; 37/80] START max_depth=2, max_features=57, n_estimators=50.............
# [CV 1/5; 37/80] END max_depth=2, max_features=57, n_estimators=50;, score=0.938 total time=   0.5s
# [CV 2/5; 37/80] START max_depth=2, max_features=57, n_estimators=50.............
# [CV 2/5; 37/80] END max_depth=2, max_features=57, n_estimators=50;, score=0.918 total time=   0.5s
# [CV 3/5; 37/80] START max_depth=2, max_features=57, n_estimators=50.............
# [CV 3/5; 37/80] END max_depth=2, max_features=57, n_estimators=50;, score=0.935 total time=   0.5s
# [CV 4/5; 37/80] START max_depth=2, max_features=57, n_estimators=50.............
# [CV 4/5; 37/80] END max_depth=2, max_features=57, n_estimators=50;, score=0.933 total time=   0.5s
# [CV 5/5; 37/80] START max_depth=2, max_features=57, n_estimators=50.............
# [CV 5/5; 37/80] END max_depth=2, max_features=57, n_estimators=50;, score=0.933 total time=   0.5s
# [CV 1/5; 38/80] START max_depth=2, max_features=57, n_estimators=100............
# [CV 1/5; 38/80] END max_depth=2, max_features=57, n_estimators=100;, score=0.940 total time=   1.1s
# [CV 2/5; 38/80] START max_depth=2, max_features=57, n_estimators=100............
# [CV 2/5; 38/80] END max_depth=2, max_features=57, n_estimators=100;, score=0.933 total time=   1.3s
# [CV 3/5; 38/80] START max_depth=2, max_features=57, n_estimators=100............
# [CV 3/5; 38/80] END max_depth=2, max_features=57, n_estimators=100;, score=0.952 total time=   1.5s
# [CV 4/5; 38/80] START max_depth=2, max_features=57, n_estimators=100............
# [CV 4/5; 38/80] END max_depth=2, max_features=57, n_estimators=100;, score=0.933 total time=   1.3s
# [CV 5/5; 38/80] START max_depth=2, max_features=57, n_estimators=100............
# [CV 5/5; 38/80] END max_depth=2, max_features=57, n_estimators=100;, score=0.950 total time=   1.3s
# [CV 1/5; 39/80] START max_depth=2, max_features=57, n_estimators=150............
# [CV 1/5; 39/80] END max_depth=2, max_features=57, n_estimators=150;, score=0.948 total time=   2.2s
# [CV 2/5; 39/80] START max_depth=2, max_features=57, n_estimators=150............
# [CV 2/5; 39/80] END max_depth=2, max_features=57, n_estimators=150;, score=0.943 total time=   1.4s
# [CV 3/5; 39/80] START max_depth=2, max_features=57, n_estimators=150............
# [CV 3/5; 39/80] END max_depth=2, max_features=57, n_estimators=150;, score=0.955 total time=   1.4s
# [CV 4/5; 39/80] START max_depth=2, max_features=57, n_estimators=150............
# [CV 4/5; 39/80] END max_depth=2, max_features=57, n_estimators=150;, score=0.938 total time=   1.4s
# [CV 5/5; 39/80] START max_depth=2, max_features=57, n_estimators=150............
# [CV 5/5; 39/80] END max_depth=2, max_features=57, n_estimators=150;, score=0.952 total time=   1.4s
# [CV 1/5; 40/80] START max_depth=2, max_features=57, n_estimators=200............
# [CV 1/5; 40/80] END max_depth=2, max_features=57, n_estimators=200;, score=0.947 total time=   2.6s
# [CV 2/5; 40/80] START max_depth=2, max_features=57, n_estimators=200............
# [CV 2/5; 40/80] END max_depth=2, max_features=57, n_estimators=200;, score=0.946 total time=   2.0s
# [CV 3/5; 40/80] START max_depth=2, max_features=57, n_estimators=200............
# [CV 3/5; 40/80] END max_depth=2, max_features=57, n_estimators=200;, score=0.952 total time=   1.8s
# [CV 4/5; 40/80] START max_depth=2, max_features=57, n_estimators=200............
# [CV 4/5; 40/80] END max_depth=2, max_features=57, n_estimators=200;, score=0.940 total time=   1.8s
# [CV 5/5; 40/80] START max_depth=2, max_features=57, n_estimators=200............
# [CV 5/5; 40/80] END max_depth=2, max_features=57, n_estimators=200;, score=0.957 total time=   1.8s
# [CV 1/5; 41/80] START max_depth=3, max_features=10, n_estimators=50.............
# [CV 1/5; 41/80] END max_depth=3, max_features=10, n_estimators=50;, score=0.929 total time=   0.2s
# [CV 2/5; 41/80] START max_depth=3, max_features=10, n_estimators=50.............
# [CV 2/5; 41/80] END max_depth=3, max_features=10, n_estimators=50;, score=0.927 total time=   0.2s
# [CV 3/5; 41/80] START max_depth=3, max_features=10, n_estimators=50.............
# [CV 3/5; 41/80] END max_depth=3, max_features=10, n_estimators=50;, score=0.943 total time=   0.2s
# [CV 4/5; 41/80] START max_depth=3, max_features=10, n_estimators=50.............
# [CV 4/5; 41/80] END max_depth=3, max_features=10, n_estimators=50;, score=0.931 total time=   0.2s
# [CV 5/5; 41/80] START max_depth=3, max_features=10, n_estimators=50.............
# [CV 5/5; 41/80] END max_depth=3, max_features=10, n_estimators=50;, score=0.936 total time=   0.2s
# [CV 1/5; 42/80] START max_depth=3, max_features=10, n_estimators=100............
# [CV 1/5; 42/80] END max_depth=3, max_features=10, n_estimators=100;, score=0.948 total time=   0.4s
# [CV 2/5; 42/80] START max_depth=3, max_features=10, n_estimators=100............
# [CV 2/5; 42/80] END max_depth=3, max_features=10, n_estimators=100;, score=0.943 total time=   0.4s
# [CV 3/5; 42/80] START max_depth=3, max_features=10, n_estimators=100............
# [CV 3/5; 42/80] END max_depth=3, max_features=10, n_estimators=100;, score=0.958 total time=   0.4s
# [CV 4/5; 42/80] START max_depth=3, max_features=10, n_estimators=100............
# [CV 4/5; 42/80] END max_depth=3, max_features=10, n_estimators=100;, score=0.942 total time=   0.4s
# [CV 5/5; 42/80] START max_depth=3, max_features=10, n_estimators=100............
# [CV 5/5; 42/80] END max_depth=3, max_features=10, n_estimators=100;, score=0.955 total time=   0.4s
# [CV 1/5; 43/80] START max_depth=3, max_features=10, n_estimators=150............
# [CV 1/5; 43/80] END max_depth=3, max_features=10, n_estimators=150;, score=0.942 total time=   0.7s
# [CV 2/5; 43/80] START max_depth=3, max_features=10, n_estimators=150............
# [CV 2/5; 43/80] END max_depth=3, max_features=10, n_estimators=150;, score=0.946 total time=   0.8s
# [CV 3/5; 43/80] START max_depth=3, max_features=10, n_estimators=150............
# [CV 3/5; 43/80] END max_depth=3, max_features=10, n_estimators=150;, score=0.961 total time=   0.8s
# [CV 4/5; 43/80] START max_depth=3, max_features=10, n_estimators=150............
# [CV 4/5; 43/80] END max_depth=3, max_features=10, n_estimators=150;, score=0.943 total time=   0.8s
# [CV 5/5; 43/80] START max_depth=3, max_features=10, n_estimators=150............
# [CV 5/5; 43/80] END max_depth=3, max_features=10, n_estimators=150;, score=0.957 total time=   0.7s
# [CV 1/5; 44/80] START max_depth=3, max_features=10, n_estimators=200............
# [CV 1/5; 44/80] END max_depth=3, max_features=10, n_estimators=200;, score=0.947 total time=   0.7s
# [CV 2/5; 44/80] START max_depth=3, max_features=10, n_estimators=200............
# [CV 2/5; 44/80] END max_depth=3, max_features=10, n_estimators=200;, score=0.947 total time=   0.7s
# [CV 3/5; 44/80] START max_depth=3, max_features=10, n_estimators=200............
# [CV 3/5; 44/80] END max_depth=3, max_features=10, n_estimators=200;, score=0.962 total time=   0.7s
# [CV 4/5; 44/80] START max_depth=3, max_features=10, n_estimators=200............
# [CV 4/5; 44/80] END max_depth=3, max_features=10, n_estimators=200;, score=0.944 total time=   0.7s
# [CV 5/5; 44/80] START max_depth=3, max_features=10, n_estimators=200............
# [CV 5/5; 44/80] END max_depth=3, max_features=10, n_estimators=200;, score=0.957 total time=   0.7s
# [CV 1/5; 45/80] START max_depth=3, max_features=20, n_estimators=50.............
# [CV 1/5; 45/80] END max_depth=3, max_features=20, n_estimators=50;, score=0.939 total time=   0.3s
# [CV 2/5; 45/80] START max_depth=3, max_features=20, n_estimators=50.............
# [CV 2/5; 45/80] END max_depth=3, max_features=20, n_estimators=50;, score=0.925 total time=   0.3s
# [CV 3/5; 45/80] START max_depth=3, max_features=20, n_estimators=50.............
# [CV 3/5; 45/80] END max_depth=3, max_features=20, n_estimators=50;, score=0.948 total time=   0.3s
# [CV 4/5; 45/80] START max_depth=3, max_features=20, n_estimators=50.............
# [CV 4/5; 45/80] END max_depth=3, max_features=20, n_estimators=50;, score=0.931 total time=   0.3s
# [CV 5/5; 45/80] START max_depth=3, max_features=20, n_estimators=50.............
# [CV 5/5; 45/80] END max_depth=3, max_features=20, n_estimators=50;, score=0.943 total time=   0.3s
# [CV 1/5; 46/80] START max_depth=3, max_features=20, n_estimators=100............
# [CV 1/5; 46/80] END max_depth=3, max_features=20, n_estimators=100;, score=0.947 total time=   0.6s
# [CV 2/5; 46/80] START max_depth=3, max_features=20, n_estimators=100............
# [CV 2/5; 46/80] END max_depth=3, max_features=20, n_estimators=100;, score=0.939 total time=   0.6s
# [CV 3/5; 46/80] START max_depth=3, max_features=20, n_estimators=100............
# [CV 3/5; 46/80] END max_depth=3, max_features=20, n_estimators=100;, score=0.958 total time=   0.6s
# [CV 4/5; 46/80] START max_depth=3, max_features=20, n_estimators=100............
# [CV 4/5; 46/80] END max_depth=3, max_features=20, n_estimators=100;, score=0.940 total time=   0.6s
# [CV 5/5; 46/80] START max_depth=3, max_features=20, n_estimators=100............
# [CV 5/5; 46/80] END max_depth=3, max_features=20, n_estimators=100;, score=0.952 total time=   0.6s
# [CV 1/5; 47/80] START max_depth=3, max_features=20, n_estimators=150............
# [CV 1/5; 47/80] END max_depth=3, max_features=20, n_estimators=150;, score=0.947 total time=   0.9s
# [CV 2/5; 47/80] START max_depth=3, max_features=20, n_estimators=150............
# [CV 2/5; 47/80] END max_depth=3, max_features=20, n_estimators=150;, score=0.946 total time=   0.9s
# [CV 3/5; 47/80] START max_depth=3, max_features=20, n_estimators=150............
# [CV 3/5; 47/80] END max_depth=3, max_features=20, n_estimators=150;, score=0.958 total time=   1.2s
# [CV 4/5; 47/80] START max_depth=3, max_features=20, n_estimators=150............
# [CV 4/5; 47/80] END max_depth=3, max_features=20, n_estimators=150;, score=0.939 total time=   1.2s
# [CV 5/5; 47/80] START max_depth=3, max_features=20, n_estimators=150............
# [CV 5/5; 47/80] END max_depth=3, max_features=20, n_estimators=150;, score=0.958 total time=   1.1s
# [CV 1/5; 48/80] START max_depth=3, max_features=20, n_estimators=200............
# [CV 1/5; 48/80] END max_depth=3, max_features=20, n_estimators=200;, score=0.947 total time=   1.1s
# [CV 2/5; 48/80] START max_depth=3, max_features=20, n_estimators=200............
# [CV 2/5; 48/80] END max_depth=3, max_features=20, n_estimators=200;, score=0.940 total time=   1.1s
# [CV 3/5; 48/80] START max_depth=3, max_features=20, n_estimators=200............
# [CV 3/5; 48/80] END max_depth=3, max_features=20, n_estimators=200;, score=0.961 total time=   1.2s
# [CV 4/5; 48/80] START max_depth=3, max_features=20, n_estimators=200............
# [CV 4/5; 48/80] END max_depth=3, max_features=20, n_estimators=200;, score=0.942 total time=   1.3s
# [CV 5/5; 48/80] START max_depth=3, max_features=20, n_estimators=200............
# [CV 5/5; 48/80] END max_depth=3, max_features=20, n_estimators=200;, score=0.961 total time=   1.1s
# [CV 1/5; 49/80] START max_depth=3, max_features=30, n_estimators=50.............
# [CV 1/5; 49/80] END max_depth=3, max_features=30, n_estimators=50;, score=0.935 total time=   0.4s
# [CV 2/5; 49/80] START max_depth=3, max_features=30, n_estimators=50.............
# [CV 2/5; 49/80] END max_depth=3, max_features=30, n_estimators=50;, score=0.928 total time=   0.4s
# [CV 3/5; 49/80] START max_depth=3, max_features=30, n_estimators=50.............
# [CV 3/5; 49/80] END max_depth=3, max_features=30, n_estimators=50;, score=0.948 total time=   0.4s
# [CV 4/5; 49/80] START max_depth=3, max_features=30, n_estimators=50.............
# [CV 4/5; 49/80] END max_depth=3, max_features=30, n_estimators=50;, score=0.933 total time=   0.4s
# [CV 5/5; 49/80] START max_depth=3, max_features=30, n_estimators=50.............
# [CV 5/5; 49/80] END max_depth=3, max_features=30, n_estimators=50;, score=0.943 total time=   0.4s
# [CV 1/5; 50/80] START max_depth=3, max_features=30, n_estimators=100............
# [CV 1/5; 50/80] END max_depth=3, max_features=30, n_estimators=100;, score=0.939 total time=   0.8s
# [CV 2/5; 50/80] START max_depth=3, max_features=30, n_estimators=100............
# [CV 2/5; 50/80] END max_depth=3, max_features=30, n_estimators=100;, score=0.942 total time=   0.8s
# [CV 3/5; 50/80] START max_depth=3, max_features=30, n_estimators=100............
# [CV 3/5; 50/80] END max_depth=3, max_features=30, n_estimators=100;, score=0.955 total time=   1.0s
# [CV 4/5; 50/80] START max_depth=3, max_features=30, n_estimators=100............
# [CV 4/5; 50/80] END max_depth=3, max_features=30, n_estimators=100;, score=0.936 total time=   1.1s
# [CV 5/5; 50/80] START max_depth=3, max_features=30, n_estimators=100............
# [CV 5/5; 50/80] END max_depth=3, max_features=30, n_estimators=100;, score=0.951 total time=   1.1s
# [CV 1/5; 51/80] START max_depth=3, max_features=30, n_estimators=150............
# [CV 1/5; 51/80] END max_depth=3, max_features=30, n_estimators=150;, score=0.947 total time=   1.2s
# [CV 2/5; 51/80] START max_depth=3, max_features=30, n_estimators=150............
# [CV 2/5; 51/80] END max_depth=3, max_features=30, n_estimators=150;, score=0.950 total time=   1.2s
# [CV 3/5; 51/80] START max_depth=3, max_features=30, n_estimators=150............
# [CV 3/5; 51/80] END max_depth=3, max_features=30, n_estimators=150;, score=0.954 total time=   1.2s
# [CV 4/5; 51/80] START max_depth=3, max_features=30, n_estimators=150............
# [CV 4/5; 51/80] END max_depth=3, max_features=30, n_estimators=150;, score=0.938 total time=   1.2s
# [CV 5/5; 51/80] START max_depth=3, max_features=30, n_estimators=150............
# [CV 5/5; 51/80] END max_depth=3, max_features=30, n_estimators=150;, score=0.957 total time=   1.2s
# [CV 1/5; 52/80] START max_depth=3, max_features=30, n_estimators=200............
# [CV 1/5; 52/80] END max_depth=3, max_features=30, n_estimators=200;, score=0.942 total time=   1.5s
# [CV 2/5; 52/80] START max_depth=3, max_features=30, n_estimators=200............
# [CV 2/5; 52/80] END max_depth=3, max_features=30, n_estimators=200;, score=0.946 total time=   1.5s
# [CV 3/5; 52/80] START max_depth=3, max_features=30, n_estimators=200............
# [CV 3/5; 52/80] END max_depth=3, max_features=30, n_estimators=200;, score=0.951 total time=   1.7s
# [CV 4/5; 52/80] START max_depth=3, max_features=30, n_estimators=200............
# [CV 4/5; 52/80] END max_depth=3, max_features=30, n_estimators=200;, score=0.942 total time=   2.2s
# [CV 5/5; 52/80] START max_depth=3, max_features=30, n_estimators=200............
# [CV 5/5; 52/80] END max_depth=3, max_features=30, n_estimators=200;, score=0.959 total time=   1.8s
# [CV 1/5; 53/80] START max_depth=3, max_features=40, n_estimators=50.............
# [CV 1/5; 53/80] END max_depth=3, max_features=40, n_estimators=50;, score=0.940 total time=   0.5s
# [CV 2/5; 53/80] START max_depth=3, max_features=40, n_estimators=50.............
# [CV 2/5; 53/80] END max_depth=3, max_features=40, n_estimators=50;, score=0.927 total time=   0.5s
# [CV 3/5; 53/80] START max_depth=3, max_features=40, n_estimators=50.............
# [CV 3/5; 53/80] END max_depth=3, max_features=40, n_estimators=50;, score=0.940 total time=   0.5s
# [CV 4/5; 53/80] START max_depth=3, max_features=40, n_estimators=50.............
# [CV 4/5; 53/80] END max_depth=3, max_features=40, n_estimators=50;, score=0.929 total time=   0.5s
# [CV 5/5; 53/80] START max_depth=3, max_features=40, n_estimators=50.............
# [CV 5/5; 53/80] END max_depth=3, max_features=40, n_estimators=50;, score=0.942 total time=   0.5s
# [CV 1/5; 54/80] START max_depth=3, max_features=40, n_estimators=100............
# ...
# [CV 3/5; 63/80] START max_depth=4, max_features=10, n_estimators=150............
# [CV 3/5; 63/80] END max_depth=4, max_features=10, n_estimators=150;, score=0.963 total time=   0.7s
# [CV 4/5; 63/80] START max_depth=4, max_features=10, n_estimators=150............
# [CV 4/5; 63/80] END max_depth=4, max_features=10, n_estimators=150;, score=0.950 total time=   0.7s
# [CV 5/5; 63/80] START max_depth=4, max_features=10, n_estimators=150............
# [CV 5/5; 63/80] END max_depth=4, max_features=10, n_estimators=150;, score=0.958 total time=   0.7s
# [CV 1/5; 64/80] START max_depth=4, max_features=10, n_estimators=200............
# [CV 1/5; 64/80] END max_depth=4, max_features=10, n_estimators=200;, score=0.944 total time=   1.3s
# [CV 2/5; 64/80] START max_depth=4, max_features=10, n_estimators=200............
# [CV 2/5; 64/80] END max_depth=4, max_features=10, n_estimators=200;, score=0.947 total time=   1.3s
# [CV 3/5; 64/80] START max_depth=4, max_features=10, n_estimators=200............
# [CV 3/5; 64/80] END max_depth=4, max_features=10, n_estimators=200;, score=0.959 total time=   1.2s
# [CV 4/5; 64/80] START max_depth=4, max_features=10, n_estimators=200............
# [CV 4/5; 64/80] END max_depth=4, max_features=10, n_estimators=200;, score=0.948 total time=   0.9s
# [CV 5/5; 64/80] START max_depth=4, max_features=10, n_estimators=200............
# [CV 5/5; 64/80] END max_depth=4, max_features=10, n_estimators=200;, score=0.963 total time=   0.9s
# [CV 1/5; 65/80] START max_depth=4, max_features=20, n_estimators=50.............
# [CV 1/5; 65/80] END max_depth=4, max_features=20, n_estimators=50;, score=0.943 total time=   0.4s
# [CV 2/5; 65/80] START max_depth=4, max_features=20, n_estimators=50.............
# [CV 2/5; 65/80] END max_depth=4, max_features=20, n_estimators=50;, score=0.933 total time=   0.4s
# [CV 3/5; 65/80] START max_depth=4, max_features=20, n_estimators=50.............
# [CV 3/5; 65/80] END max_depth=4, max_features=20, n_estimators=50;, score=0.946 total time=   0.4s
# [CV 4/5; 65/80] START max_depth=4, max_features=20, n_estimators=50.............
# [CV 4/5; 65/80] END max_depth=4, max_features=20, n_estimators=50;, score=0.938 total time=   0.4s
# [CV 5/5; 65/80] START max_depth=4, max_features=20, n_estimators=50.............
# [CV 5/5; 65/80] END max_depth=4, max_features=20, n_estimators=50;, score=0.951 total time=   0.4s
# [CV 1/5; 66/80] START max_depth=4, max_features=20, n_estimators=100............
# [CV 1/5; 66/80] END max_depth=4, max_features=20, n_estimators=100;, score=0.947 total time=   0.7s
# [CV 2/5; 66/80] START max_depth=4, max_features=20, n_estimators=100............
# [CV 2/5; 66/80] END max_depth=4, max_features=20, n_estimators=100;, score=0.946 total time=   0.8s
# [CV 3/5; 66/80] START max_depth=4, max_features=20, n_estimators=100............
# [CV 3/5; 66/80] END max_depth=4, max_features=20, n_estimators=100;, score=0.954 total time=   0.7s
# [CV 4/5; 66/80] START max_depth=4, max_features=20, n_estimators=100............
# [CV 4/5; 66/80] END max_depth=4, max_features=20, n_estimators=100;, score=0.946 total time=   0.7s
# [CV 5/5; 66/80] START max_depth=4, max_features=20, n_estimators=100............
# [CV 5/5; 66/80] END max_depth=4, max_features=20, n_estimators=100;, score=0.959 total time=   0.7s
# [CV 1/5; 67/80] START max_depth=4, max_features=20, n_estimators=150............
# [CV 1/5; 67/80] END max_depth=4, max_features=20, n_estimators=150;, score=0.948 total time=   1.1s
# [CV 2/5; 67/80] START max_depth=4, max_features=20, n_estimators=150............
# [CV 2/5; 67/80] END max_depth=4, max_features=20, n_estimators=150;, score=0.952 total time=   1.1s
# [CV 3/5; 67/80] START max_depth=4, max_features=20, n_estimators=150............
# [CV 3/5; 67/80] END max_depth=4, max_features=20, n_estimators=150;, score=0.961 total time=   1.5s
# [CV 4/5; 67/80] START max_depth=4, max_features=20, n_estimators=150............
# [CV 4/5; 67/80] END max_depth=4, max_features=20, n_estimators=150;, score=0.947 total time=   1.6s
# [CV 5/5; 67/80] START max_depth=4, max_features=20, n_estimators=150............
# [CV 5/5; 67/80] END max_depth=4, max_features=20, n_estimators=150;, score=0.961 total time=   1.1s
# [CV 1/5; 68/80] START max_depth=4, max_features=20, n_estimators=200............
# [CV 1/5; 68/80] END max_depth=4, max_features=20, n_estimators=200;, score=0.950 total time=   1.5s
# [CV 2/5; 68/80] START max_depth=4, max_features=20, n_estimators=200............
# [CV 2/5; 68/80] END max_depth=4, max_features=20, n_estimators=200;, score=0.947 total time=   1.5s
# [CV 3/5; 68/80] START max_depth=4, max_features=20, n_estimators=200............
# [CV 3/5; 68/80] END max_depth=4, max_features=20, n_estimators=200;, score=0.957 total time=   1.4s
# [CV 4/5; 68/80] START max_depth=4, max_features=20, n_estimators=200............
# [CV 4/5; 68/80] END max_depth=4, max_features=20, n_estimators=200;, score=0.942 total time=   1.4s
# [CV 5/5; 68/80] START max_depth=4, max_features=20, n_estimators=200............
# [CV 5/5; 68/80] END max_depth=4, max_features=20, n_estimators=200;, score=0.961 total time=   1.5s
# [CV 1/5; 69/80] START max_depth=4, max_features=30, n_estimators=50.............
# [CV 1/5; 69/80] END max_depth=4, max_features=30, n_estimators=50;, score=0.946 total time=   0.5s
# [CV 2/5; 69/80] START max_depth=4, max_features=30, n_estimators=50.............
# [CV 2/5; 69/80] END max_depth=4, max_features=30, n_estimators=50;, score=0.932 total time=   0.5s
# [CV 3/5; 69/80] START max_depth=4, max_features=30, n_estimators=50.............
# [CV 3/5; 69/80] END max_depth=4, max_features=30, n_estimators=50;, score=0.947 total time=   0.5s
# [CV 4/5; 69/80] START max_depth=4, max_features=30, n_estimators=50.............
# [CV 4/5; 69/80] END max_depth=4, max_features=30, n_estimators=50;, score=0.932 total time=   0.7s
# [CV 5/5; 69/80] START max_depth=4, max_features=30, n_estimators=50.............
# [CV 5/5; 69/80] END max_depth=4, max_features=30, n_estimators=50;, score=0.948 total time=   0.7s
# [CV 1/5; 70/80] START max_depth=4, max_features=30, n_estimators=100............
# [CV 1/5; 70/80] END max_depth=4, max_features=30, n_estimators=100;, score=0.947 total time=   1.4s
# [CV 2/5; 70/80] START max_depth=4, max_features=30, n_estimators=100............
# [CV 2/5; 70/80] END max_depth=4, max_features=30, n_estimators=100;, score=0.944 total time=   1.2s
# [CV 3/5; 70/80] START max_depth=4, max_features=30, n_estimators=100............
# [CV 3/5; 70/80] END max_depth=4, max_features=30, n_estimators=100;, score=0.958 total time=   1.0s
# [CV 4/5; 70/80] START max_depth=4, max_features=30, n_estimators=100............
# [CV 4/5; 70/80] END max_depth=4, max_features=30, n_estimators=100;, score=0.936 total time=   1.0s
# [CV 5/5; 70/80] START max_depth=4, max_features=30, n_estimators=100............
# [CV 5/5; 70/80] END max_depth=4, max_features=30, n_estimators=100;, score=0.958 total time=   1.0s
# [CV 1/5; 71/80] START max_depth=4, max_features=30, n_estimators=150............
# [CV 1/5; 71/80] END max_depth=4, max_features=30, n_estimators=150;, score=0.948 total time=   1.5s
# [CV 2/5; 71/80] START max_depth=4, max_features=30, n_estimators=150............
# [CV 2/5; 71/80] END max_depth=4, max_features=30, n_estimators=150;, score=0.948 total time=   1.5s
# [CV 3/5; 71/80] START max_depth=4, max_features=30, n_estimators=150............
# [CV 3/5; 71/80] END max_depth=4, max_features=30, n_estimators=150;, score=0.961 total time=   1.5s
# [CV 4/5; 71/80] START max_depth=4, max_features=30, n_estimators=150............
# [CV 4/5; 71/80] END max_depth=4, max_features=30, n_estimators=150;, score=0.946 total time=   1.5s
# [CV 5/5; 71/80] START max_depth=4, max_features=30, n_estimators=150............
# [CV 5/5; 71/80] END max_depth=4, max_features=30, n_estimators=150;, score=0.959 total time=   2.5s
# [CV 1/5; 72/80] START max_depth=4, max_features=30, n_estimators=200............
# [CV 1/5; 72/80] END max_depth=4, max_features=30, n_estimators=200;, score=0.951 total time=   3.7s
# [CV 2/5; 72/80] START max_depth=4, max_features=30, n_estimators=200............
# [CV 2/5; 72/80] END max_depth=4, max_features=30, n_estimators=200;, score=0.948 total time=   2.0s
# [CV 3/5; 72/80] START max_depth=4, max_features=30, n_estimators=200............
# [CV 3/5; 72/80] END max_depth=4, max_features=30, n_estimators=200;, score=0.963 total time=   2.7s
# [CV 4/5; 72/80] START max_depth=4, max_features=30, n_estimators=200............
# [CV 4/5; 72/80] END max_depth=4, max_features=30, n_estimators=200;, score=0.943 total time=   2.6s
# [CV 5/5; 72/80] START max_depth=4, max_features=30, n_estimators=200............
# [CV 5/5; 72/80] END max_depth=4, max_features=30, n_estimators=200;, score=0.957 total time=   2.5s
# [CV 1/5; 73/80] START max_depth=4, max_features=40, n_estimators=50.............
# [CV 1/5; 73/80] END max_depth=4, max_features=40, n_estimators=50;, score=0.939 total time=   0.9s
# [CV 2/5; 73/80] START max_depth=4, max_features=40, n_estimators=50.............
# [CV 2/5; 73/80] END max_depth=4, max_features=40, n_estimators=50;, score=0.935 total time=   0.8s
# [CV 3/5; 73/80] START max_depth=4, max_features=40, n_estimators=50.............
# [CV 3/5; 73/80] END max_depth=4, max_features=40, n_estimators=50;, score=0.947 total time=   0.7s
# [CV 4/5; 73/80] START max_depth=4, max_features=40, n_estimators=50.............
# [CV 4/5; 73/80] END max_depth=4, max_features=40, n_estimators=50;, score=0.935 total time=   0.6s
# [CV 5/5; 73/80] START max_depth=4, max_features=40, n_estimators=50.............
# [CV 5/5; 73/80] END max_depth=4, max_features=40, n_estimators=50;, score=0.947 total time=   0.6s
# [CV 1/5; 74/80] START max_depth=4, max_features=40, n_estimators=100............
# [CV 1/5; 74/80] END max_depth=4, max_features=40, n_estimators=100;, score=0.948 total time=   1.3s
# [CV 2/5; 74/80] START max_depth=4, max_features=40, n_estimators=100............
# [CV 2/5; 74/80] END max_depth=4, max_features=40, n_estimators=100;, score=0.943 total time=   1.3s
# [CV 3/5; 74/80] START max_depth=4, max_features=40, n_estimators=100............
# [CV 3/5; 74/80] END max_depth=4, max_features=40, n_estimators=100;, score=0.955 total time=   1.3s
# [CV 4/5; 74/80] START max_depth=4, max_features=40, n_estimators=100............
# [CV 4/5; 74/80] END max_depth=4, max_features=40, n_estimators=100;, score=0.939 total time=   1.3s
# [CV 5/5; 74/80] START max_depth=4, max_features=40, n_estimators=100............
# [CV 5/5; 74/80] END max_depth=4, max_features=40, n_estimators=100;, score=0.957 total time=   1.3s
# [CV 1/5; 75/80] START max_depth=4, max_features=40, n_estimators=150............
# [CV 1/5; 75/80] END max_depth=4, max_features=40, n_estimators=150;, score=0.948 total time=   2.2s
# [CV 2/5; 75/80] START max_depth=4, max_features=40, n_estimators=150............
# [CV 2/5; 75/80] END max_depth=4, max_features=40, n_estimators=150;, score=0.947 total time=   2.6s
# [CV 3/5; 75/80] START max_depth=4, max_features=40, n_estimators=150............
# [CV 3/5; 75/80] END max_depth=4, max_features=40, n_estimators=150;, score=0.951 total time=   1.9s
# [CV 4/5; 75/80] START max_depth=4, max_features=40, n_estimators=150............
# [CV 4/5; 75/80] END max_depth=4, max_features=40, n_estimators=150;, score=0.948 total time=   1.9s
# [CV 5/5; 75/80] START max_depth=4, max_features=40, n_estimators=150............
# [CV 5/5; 75/80] END max_depth=4, max_features=40, n_estimators=150;, score=0.958 total time=   1.9s
# [CV 1/5; 76/80] START max_depth=4, max_features=40, n_estimators=200............
# [CV 1/5; 76/80] END max_depth=4, max_features=40, n_estimators=200;, score=0.948 total time=   2.5s
# [CV 2/5; 76/80] START max_depth=4, max_features=40, n_estimators=200............
# [CV 2/5; 76/80] END max_depth=4, max_features=40, n_estimators=200;, score=0.950 total time=   2.9s
# [CV 3/5; 76/80] START max_depth=4, max_features=40, n_estimators=200............
# [CV 3/5; 76/80] END max_depth=4, max_features=40, n_estimators=200;, score=0.957 total time=   3.0s
# [CV 4/5; 76/80] START max_depth=4, max_features=40, n_estimators=200............
# [CV 4/5; 76/80] END max_depth=4, max_features=40, n_estimators=200;, score=0.950 total time=   2.5s
# [CV 5/5; 76/80] START max_depth=4, max_features=40, n_estimators=200............
# [CV 5/5; 76/80] END max_depth=4, max_features=40, n_estimators=200;, score=0.959 total time=   2.5s
# [CV 1/5; 77/80] START max_depth=4, max_features=57, n_estimators=50.............
# [CV 1/5; 77/80] END max_depth=4, max_features=57, n_estimators=50;, score=0.947 total time=   0.9s
# [CV 2/5; 77/80] START max_depth=4, max_features=57, n_estimators=50.............
# [CV 2/5; 77/80] END max_depth=4, max_features=57, n_estimators=50;, score=0.935 total time=   0.9s
# [CV 3/5; 77/80] START max_depth=4, max_features=57, n_estimators=50.............
# [CV 3/5; 77/80] END max_depth=4, max_features=57, n_estimators=50;, score=0.948 total time=   0.9s
# [CV 4/5; 77/80] START max_depth=4, max_features=57, n_estimators=50.............
# [CV 4/5; 77/80] END max_depth=4, max_features=57, n_estimators=50;, score=0.935 total time=   0.9s
# [CV 5/5; 77/80] START max_depth=4, max_features=57, n_estimators=50.............
# [CV 5/5; 77/80] END max_depth=4, max_features=57, n_estimators=50;, score=0.943 total time=   1.2s
# [CV 1/5; 78/80] START max_depth=4, max_features=57, n_estimators=100............
# [CV 1/5; 78/80] END max_depth=4, max_features=57, n_estimators=100;, score=0.947 total time=   2.4s
# [CV 2/5; 78/80] START max_depth=4, max_features=57, n_estimators=100............
# [CV 2/5; 78/80] END max_depth=4, max_features=57, n_estimators=100;, score=0.944 total time=   1.8s
# [CV 3/5; 78/80] START max_depth=4, max_features=57, n_estimators=100............
# [CV 3/5; 78/80] END max_depth=4, max_features=57, n_estimators=100;, score=0.955 total time=   2.1s
# [CV 4/5; 78/80] START max_depth=4, max_features=57, n_estimators=100............
# [CV 4/5; 78/80] END max_depth=4, max_features=57, n_estimators=100;, score=0.942 total time=   2.2s
# [CV 5/5; 78/80] START max_depth=4, max_features=57, n_estimators=100............
# [CV 5/5; 78/80] END max_depth=4, max_features=57, n_estimators=100;, score=0.954 total time=   2.7s
# [CV 1/5; 79/80] START max_depth=4, max_features=57, n_estimators=150............
# [CV 1/5; 79/80] END max_depth=4, max_features=57, n_estimators=150;, score=0.952 total time=   5.3s
# [CV 2/5; 79/80] START max_depth=4, max_features=57, n_estimators=150............
# [CV 2/5; 79/80] END max_depth=4, max_features=57, n_estimators=150;, score=0.939 total time=   2.8s
# [CV 3/5; 79/80] START max_depth=4, max_features=57, n_estimators=150............
# [CV 3/5; 79/80] END max_depth=4, max_features=57, n_estimators=150;, score=0.957 total time=   2.9s
# [CV 4/5; 79/80] START max_depth=4, max_features=57, n_estimators=150............
# [CV 4/5; 79/80] END max_depth=4, max_features=57, n_estimators=150;, score=0.943 total time=   2.9s
# [CV 5/5; 79/80] START max_depth=4, max_features=57, n_estimators=150............
# [CV 5/5; 79/80] END max_depth=4, max_features=57, n_estimators=150;, score=0.955 total time=   5.4s
# [CV 1/5; 80/80] START max_depth=4, max_features=57, n_estimators=200............
# [CV 1/5; 80/80] END max_depth=4, max_features=57, n_estimators=200;, score=0.952 total time=   3.9s
# [CV 2/5; 80/80] START max_depth=4, max_features=57, n_estimators=200............
# [CV 2/5; 80/80] END max_depth=4, max_features=57, n_estimators=200;, score=0.948 total time=   3.4s
# [CV 3/5; 80/80] START max_depth=4, max_features=57, n_estimators=200............
# [CV 3/5; 80/80] END max_depth=4, max_features=57, n_estimators=200;, score=0.957 total time=   4.0s
# [CV 4/5; 80/80] START max_depth=4, max_features=57, n_estimators=200............
# [CV 4/5; 80/80] END max_depth=4, max_features=57, n_estimators=200;, score=0.944 total time=   3.9s
# [CV 5/5; 80/80] START max_depth=4, max_features=57, n_estimators=200............
# [CV 5/5; 80/80] END max_depth=4, max_features=57, n_estimators=200;, score=0.961 total time=   3.4s
# Precisión: 95.4% con {'max_depth': 4, 'max_features': 20, 'n_estimators': 150}

# %% [markdown]
# ### Acelerar la búsqueda de parámetros: RandomizedSearch
#
# Un problema recurrente que tenemos en estos experimentos es el coste temporal de encontrar los mejores parámetros mediante GridSearch. Una alternativa que reduce dicho coste temporal es el [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# **Ejercicio** Implementa la misma búsqueda de valores que has realizado con GridSearch pero ahora con RandomizedSearch con n_iter=10 para limitar el número de pruebas a 10.

# %%
## Solución

from sklearn.model_selection import RandomizedSearchCV

G = {"max_depth": [1,2,3,4,5],"n_estimators":[50,100,150,200],"max_features":[10,20,30,40,57]}

# Probar sólo 10 combinaciones de parámetros, n_iter=10
RS = RandomizedSearchCV(GradientBoostingClassifier(), G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc = RS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {RS.best_params_}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START max_depth=4, max_features=30, n_estimators=200.............
# [CV 1/5; 1/10] END max_depth=4, max_features=30, n_estimators=200;, score=0.951 total time=   2.1s
# [CV 2/5; 1/10] START max_depth=4, max_features=30, n_estimators=200.............
# [CV 2/5; 1/10] END max_depth=4, max_features=30, n_estimators=200;, score=0.950 total time=   2.0s
# [CV 3/5; 1/10] START max_depth=4, max_features=30, n_estimators=200.............
# [CV 3/5; 1/10] END max_depth=4, max_features=30, n_estimators=200;, score=0.963 total time=   2.0s
# [CV 4/5; 1/10] START max_depth=4, max_features=30, n_estimators=200.............
# [CV 4/5; 1/10] END max_depth=4, max_features=30, n_estimators=200;, score=0.946 total time=   2.0s
# [CV 5/5; 1/10] START max_depth=4, max_features=30, n_estimators=200.............
# [CV 5/5; 1/10] END max_depth=4, max_features=30, n_estimators=200;, score=0.958 total time=   2.7s
# [CV 1/5; 2/10] START max_depth=4, max_features=10, n_estimators=200.............
# [CV 1/5; 2/10] END max_depth=4, max_features=10, n_estimators=200;, score=0.946 total time=   1.2s
# [CV 2/5; 2/10] START max_depth=4, max_features=10, n_estimators=200.............
# [CV 2/5; 2/10] END max_depth=4, max_features=10, n_estimators=200;, score=0.950 total time=   0.9s
# [CV 3/5; 2/10] START max_depth=4, max_features=10, n_estimators=200.............
# [CV 3/5; 2/10] END max_depth=4, max_features=10, n_estimators=200;, score=0.962 total time=   0.9s
# [CV 4/5; 2/10] START max_depth=4, max_features=10, n_estimators=200.............
# [CV 4/5; 2/10] END max_depth=4, max_features=10, n_estimators=200;, score=0.947 total time=   0.9s
# [CV 5/5; 2/10] START max_depth=4, max_features=10, n_estimators=200.............
# [CV 5/5; 2/10] END max_depth=4, max_features=10, n_estimators=200;, score=0.959 total time=   0.9s
# [CV 1/5; 3/10] START max_depth=4, max_features=20, n_estimators=100.............
# [CV 1/5; 3/10] END max_depth=4, max_features=20, n_estimators=100;, score=0.946 total time=   0.8s
# [CV 2/5; 3/10] START max_depth=4, max_features=20, n_estimators=100.............
# [CV 2/5; 3/10] END max_depth=4, max_features=20, n_estimators=100;, score=0.943 total time=   0.8s
# [CV 3/5; 3/10] START max_depth=4, max_features=20, n_estimators=100.............
# [CV 3/5; 3/10] END max_depth=4, max_features=20, n_estimators=100;, score=0.955 total time=   0.7s
# [CV 4/5; 3/10] START max_depth=4, max_features=20, n_estimators=100.............
# [CV 4/5; 3/10] END max_depth=4, max_features=20, n_estimators=100;, score=0.938 total time=   0.7s
# [CV 5/5; 3/10] START max_depth=4, max_features=20, n_estimators=100.............
# [CV 5/5; 3/10] END max_depth=4, max_features=20, n_estimators=100;, score=0.954 total time=   0.8s
# [CV 1/5; 4/10] START max_depth=5, max_features=57, n_estimators=50..............
# [CV 1/5; 4/10] END max_depth=5, max_features=57, n_estimators=50;, score=0.947 total time=   1.1s
# [CV 2/5; 4/10] START max_depth=5, max_features=57, n_estimators=50..............
# [CV 2/5; 4/10] END max_depth=5, max_features=57, n_estimators=50;, score=0.944 total time=   1.1s
# [CV 3/5; 4/10] START max_depth=5, max_features=57, n_estimators=50..............
# [CV 3/5; 4/10] END max_depth=5, max_features=57, n_estimators=50;, score=0.954 total time=   1.5s
# [CV 4/5; 4/10] START max_depth=5, max_features=57, n_estimators=50..............
# [CV 4/5; 4/10] END max_depth=5, max_features=57, n_estimators=50;, score=0.940 total time=   1.5s
# [CV 5/5; 4/10] START max_depth=5, max_features=57, n_estimators=50..............
# [CV 5/5; 4/10] END max_depth=5, max_features=57, n_estimators=50;, score=0.947 total time=   1.2s
# [CV 1/5; 5/10] START max_depth=4, max_features=20, n_estimators=50..............
# [CV 1/5; 5/10] END max_depth=4, max_features=20, n_estimators=50;, score=0.947 total time=   0.4s
# [CV 2/5; 5/10] START max_depth=4, max_features=20, n_estimators=50..............
# [CV 2/5; 5/10] END max_depth=4, max_features=20, n_estimators=50;, score=0.928 total time=   0.4s
# [CV 3/5; 5/10] START max_depth=4, max_features=20, n_estimators=50..............
# [CV 3/5; 5/10] END max_depth=4, max_features=20, n_estimators=50;, score=0.947 total time=   0.4s
# [CV 4/5; 5/10] START max_depth=4, max_features=20, n_estimators=50..............
# [CV 4/5; 5/10] END max_depth=4, max_features=20, n_estimators=50;, score=0.936 total time=   0.4s
# [CV 5/5; 5/10] START max_depth=4, max_features=20, n_estimators=50..............
# [CV 5/5; 5/10] END max_depth=4, max_features=20, n_estimators=50;, score=0.950 total time=   0.4s
# [CV 1/5; 6/10] START max_depth=3, max_features=40, n_estimators=50..............
# [CV 1/5; 6/10] END max_depth=3, max_features=40, n_estimators=50;, score=0.936 total time=   0.5s
# [CV 2/5; 6/10] START max_depth=3, max_features=40, n_estimators=50..............
# [CV 2/5; 6/10] END max_depth=3, max_features=40, n_estimators=50;, score=0.923 total time=   0.5s
# [CV 3/5; 6/10] START max_depth=3, max_features=40, n_estimators=50..............
# [CV 3/5; 6/10] END max_depth=3, max_features=40, n_estimators=50;, score=0.946 total time=   0.5s
# [CV 4/5; 6/10] START max_depth=3, max_features=40, n_estimators=50..............
# [CV 4/5; 6/10] END max_depth=3, max_features=40, n_estimators=50;, score=0.931 total time=   0.5s
# [CV 5/5; 6/10] START max_depth=3, max_features=40, n_estimators=50..............
# [CV 5/5; 6/10] END max_depth=3, max_features=40, n_estimators=50;, score=0.943 total time=   0.5s
# [CV 1/5; 7/10] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 1/5; 7/10] END max_depth=1, max_features=10, n_estimators=150;, score=0.942 total time=   0.3s
# [CV 2/5; 7/10] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 2/5; 7/10] END max_depth=1, max_features=10, n_estimators=150;, score=0.918 total time=   0.3s
# [CV 3/5; 7/10] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 3/5; 7/10] END max_depth=1, max_features=10, n_estimators=150;, score=0.942 total time=   0.3s
# [CV 4/5; 7/10] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 4/5; 7/10] END max_depth=1, max_features=10, n_estimators=150;, score=0.931 total time=   0.3s
# [CV 5/5; 7/10] START max_depth=1, max_features=10, n_estimators=150.............
# [CV 5/5; 7/10] END max_depth=1, max_features=10, n_estimators=150;, score=0.936 total time=   0.3s
# [CV 1/5; 8/10] START max_depth=4, max_features=57, n_estimators=100.............
# [CV 1/5; 8/10] END max_depth=4, max_features=57, n_estimators=100;, score=0.947 total time=   1.7s
# [CV 2/5; 8/10] START max_depth=4, max_features=57, n_estimators=100.............
# [CV 2/5; 8/10] END max_depth=4, max_features=57, n_estimators=100;, score=0.944 total time=   1.8s
# [CV 3/5; 8/10] START max_depth=4, max_features=57, n_estimators=100.............
# [CV 3/5; 8/10] END max_depth=4, max_features=57, n_estimators=100;, score=0.954 total time=   2.6s
# [CV 4/5; 8/10] START max_depth=4, max_features=57, n_estimators=100.............
# [CV 4/5; 8/10] END max_depth=4, max_features=57, n_estimators=100;, score=0.938 total time=   2.6s
# [CV 5/5; 8/10] START max_depth=4, max_features=57, n_estimators=100.............
# [CV 5/5; 8/10] END max_depth=4, max_features=57, n_estimators=100;, score=0.952 total time=   2.0s
# [CV 1/5; 9/10] START max_depth=5, max_features=20, n_estimators=200.............
# [CV 1/5; 9/10] END max_depth=5, max_features=20, n_estimators=200;, score=0.950 total time=   1.8s
# [CV 2/5; 9/10] START max_depth=5, max_features=20, n_estimators=200.............
# [CV 2/5; 9/10] END max_depth=5, max_features=20, n_estimators=200;, score=0.952 total time=   1.8s
# [CV 3/5; 9/10] START max_depth=5, max_features=20, n_estimators=200.............
# [CV 3/5; 9/10] END max_depth=5, max_features=20, n_estimators=200;, score=0.961 total time=   1.8s
# [CV 4/5; 9/10] START max_depth=5, max_features=20, n_estimators=200.............
# [CV 4/5; 9/10] END max_depth=5, max_features=20, n_estimators=200;, score=0.947 total time=   2.0s
# [CV 5/5; 9/10] START max_depth=5, max_features=20, n_estimators=200.............
# [CV 5/5; 9/10] END max_depth=5, max_features=20, n_estimators=200;, score=0.961 total time=   2.6s
# [CV 1/5; 10/10] START max_depth=2, max_features=40, n_estimators=100............
# [CV 1/5; 10/10] END max_depth=2, max_features=40, n_estimators=100;, score=0.946 total time=   0.7s
# [CV 2/5; 10/10] START max_depth=2, max_features=40, n_estimators=100............
# [CV 2/5; 10/10] END max_depth=2, max_features=40, n_estimators=100;, score=0.932 total time=   0.7s
# [CV 3/5; 10/10] START max_depth=2, max_features=40, n_estimators=100............
# [CV 3/5; 10/10] END max_depth=2, max_features=40, n_estimators=100;, score=0.947 total time=   0.7s
# [CV 4/5; 10/10] START max_depth=2, max_features=40, n_estimators=100............
# [CV 4/5; 10/10] END max_depth=2, max_features=40, n_estimators=100;, score=0.932 total time=   0.7s
# [CV 5/5; 10/10] START max_depth=2, max_features=40, n_estimators=100............
# [CV 5/5; 10/10] END max_depth=2, max_features=40, n_estimators=100;, score=0.946 total time=   0.7s
# Precisión: 95.5% con {'n_estimators': 200, 'max_features': 20, 'max_depth': 5}

# %% [markdown]
# ### Mejorar la búsqueda de parámetros: BayesianOptimization
#
# Optimización Bayesiana es una técnica avanzada de búsqueda de parámetros. Para poder emplearla hay que instalar la librería scikit-optimize. El uso de dicha técnica es similar a las ya empleadas con la diferencia que el rango de los parámetros hay que definirlos teniendo en cuenta además el tipo de los mismos: real, entero o categórico. Además los valores a probar no se listan explícitamente si no que se especifica un rango dentro del cual el algoritmo escogerá los valores.
#
# La ejecución puede resultar más lenta pero se pueden explorar más parámetros, de hecho se especifica un intervalo en lugar de valores concretos.

# %%
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in /usr/local/lib/python3.10/dist-packages (0.10.1)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.4.2)
# Requirement already satisfied: pyaml>=16.9 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (24.4.0)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.25.2)
# Requirement already satisfied: scipy>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (1.2.2)
# Requirement already satisfied: packaging>=21.3 in /usr/local/lib/python3.10/dist-packages (from scikit-optimize) (24.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.10/dist-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=1.0.0->scikit-optimize) (3.5.0)

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer

# Ponemos rangos (mínimo, máximo)
G = {"max_depth": Integer(1,5),"n_estimators":Integer(50,400),"max_features":Integer(5,57)}

# Probar sólo 10 combinaciones de parámetros, n_iter=10
BS = BayesSearchCV(GradientBoostingClassifier(), G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=45, n_estimators=116..............
# [CV 1/5; 1/1] END max_depth=4, max_features=45, n_estimators=116;, score=0.943 total time=   4.9s
# [CV 2/5; 1/1] START max_depth=4, max_features=45, n_estimators=116..............
# [CV 2/5; 1/1] END max_depth=4, max_features=45, n_estimators=116;, score=0.944 total time=   4.1s
# [CV 3/5; 1/1] START max_depth=4, max_features=45, n_estimators=116..............
# [CV 3/5; 1/1] END max_depth=4, max_features=45, n_estimators=116;, score=0.958 total time=   2.7s
# [CV 4/5; 1/1] START max_depth=4, max_features=45, n_estimators=116..............
# [CV 4/5; 1/1] END max_depth=4, max_features=45, n_estimators=116;, score=0.940 total time=   1.6s
# [CV 5/5; 1/1] START max_depth=4, max_features=45, n_estimators=116..............
# [CV 5/5; 1/1] END max_depth=4, max_features=45, n_estimators=116;, score=0.955 total time=   1.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=1, max_features=50, n_estimators=197..............
# [CV 1/5; 1/1] END max_depth=1, max_features=50, n_estimators=197;, score=0.944 total time=   0.9s
# [CV 2/5; 1/1] START max_depth=1, max_features=50, n_estimators=197..............
# [CV 2/5; 1/1] END max_depth=1, max_features=50, n_estimators=197;, score=0.929 total time=   0.9s
# [CV 3/5; 1/1] START max_depth=1, max_features=50, n_estimators=197..............
# [CV 3/5; 1/1] END max_depth=1, max_features=50, n_estimators=197;, score=0.950 total time=   1.0s
# [CV 4/5; 1/1] START max_depth=1, max_features=50, n_estimators=197..............
# [CV 4/5; 1/1] END max_depth=1, max_features=50, n_estimators=197;, score=0.939 total time=   1.3s
# [CV 5/5; 1/1] START max_depth=1, max_features=50, n_estimators=197..............
# [CV 5/5; 1/1] END max_depth=1, max_features=50, n_estimators=197;, score=0.940 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=7, n_estimators=397...............
# [CV 1/5; 1/1] END max_depth=4, max_features=7, n_estimators=397;, score=0.952 total time=   1.6s
# [CV 2/5; 1/1] START max_depth=4, max_features=7, n_estimators=397...............
# [CV 2/5; 1/1] END max_depth=4, max_features=7, n_estimators=397;, score=0.954 total time=   1.5s
# [CV 3/5; 1/1] START max_depth=4, max_features=7, n_estimators=397...............
# [CV 3/5; 1/1] END max_depth=4, max_features=7, n_estimators=397;, score=0.970 total time=   1.5s
# [CV 4/5; 1/1] START max_depth=4, max_features=7, n_estimators=397...............
# [CV 4/5; 1/1] END max_depth=4, max_features=7, n_estimators=397;, score=0.952 total time=   1.4s
# [CV 5/5; 1/1] START max_depth=4, max_features=7, n_estimators=397...............
# [CV 5/5; 1/1] END max_depth=4, max_features=7, n_estimators=397;, score=0.965 total time=   1.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=54, n_estimators=232..............
# [CV 1/5; 1/1] END max_depth=4, max_features=54, n_estimators=232;, score=0.951 total time=   4.2s
# [CV 2/5; 1/1] START max_depth=4, max_features=54, n_estimators=232..............
# [CV 2/5; 1/1] END max_depth=4, max_features=54, n_estimators=232;, score=0.954 total time=   4.4s
# [CV 3/5; 1/1] START max_depth=4, max_features=54, n_estimators=232..............
# [CV 3/5; 1/1] END max_depth=4, max_features=54, n_estimators=232;, score=0.959 total time=   3.8s
# [CV 4/5; 1/1] START max_depth=4, max_features=54, n_estimators=232..............
# [CV 4/5; 1/1] END max_depth=4, max_features=54, n_estimators=232;, score=0.942 total time=   3.8s
# [CV 5/5; 1/1] START max_depth=4, max_features=54, n_estimators=232..............
# [CV 5/5; 1/1] END max_depth=4, max_features=54, n_estimators=232;, score=0.959 total time=   4.7s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=3, max_features=13, n_estimators=121..............
# [CV 1/5; 1/1] END max_depth=3, max_features=13, n_estimators=121;, score=0.948 total time=   0.5s
# [CV 2/5; 1/1] START max_depth=3, max_features=13, n_estimators=121..............
# [CV 2/5; 1/1] END max_depth=3, max_features=13, n_estimators=121;, score=0.940 total time=   0.5s
# [CV 3/5; 1/1] START max_depth=3, max_features=13, n_estimators=121..............
# [CV 3/5; 1/1] END max_depth=3, max_features=13, n_estimators=121;, score=0.962 total time=   0.5s
# [CV 4/5; 1/1] START max_depth=3, max_features=13, n_estimators=121..............
# [CV 4/5; 1/1] END max_depth=3, max_features=13, n_estimators=121;, score=0.938 total time=   0.5s
# [CV 5/5; 1/1] START max_depth=3, max_features=13, n_estimators=121..............
# [CV 5/5; 1/1] END max_depth=3, max_features=13, n_estimators=121;, score=0.952 total time=   0.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=2, max_features=33, n_estimators=292..............
# [CV 1/5; 1/1] END max_depth=2, max_features=33, n_estimators=292;, score=0.943 total time=   1.7s
# [CV 2/5; 1/1] START max_depth=2, max_features=33, n_estimators=292..............
# [CV 2/5; 1/1] END max_depth=2, max_features=33, n_estimators=292;, score=0.943 total time=   1.8s
# [CV 3/5; 1/1] START max_depth=2, max_features=33, n_estimators=292..............
# [CV 3/5; 1/1] END max_depth=2, max_features=33, n_estimators=292;, score=0.959 total time=   1.8s
# [CV 4/5; 1/1] START max_depth=2, max_features=33, n_estimators=292..............
# [CV 4/5; 1/1] END max_depth=2, max_features=33, n_estimators=292;, score=0.943 total time=   2.2s
# [CV 5/5; 1/1] START max_depth=2, max_features=33, n_estimators=292..............
# [CV 5/5; 1/1] END max_depth=2, max_features=33, n_estimators=292;, score=0.955 total time=   2.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=3, max_features=46, n_estimators=205..............
# [CV 1/5; 1/1] END max_depth=3, max_features=46, n_estimators=205;, score=0.944 total time=   2.3s
# [CV 2/5; 1/1] START max_depth=3, max_features=46, n_estimators=205..............
# [CV 2/5; 1/1] END max_depth=3, max_features=46, n_estimators=205;, score=0.947 total time=   2.3s
# [CV 3/5; 1/1] START max_depth=3, max_features=46, n_estimators=205..............
# [CV 3/5; 1/1] END max_depth=3, max_features=46, n_estimators=205;, score=0.950 total time=   2.3s
# [CV 4/5; 1/1] START max_depth=3, max_features=46, n_estimators=205..............
# [CV 4/5; 1/1] END max_depth=3, max_features=46, n_estimators=205;, score=0.939 total time=   2.3s
# [CV 5/5; 1/1] START max_depth=3, max_features=46, n_estimators=205..............
# [CV 5/5; 1/1] END max_depth=3, max_features=46, n_estimators=205;, score=0.958 total time=   3.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=29, n_estimators=150..............
# [CV 1/5; 1/1] END max_depth=4, max_features=29, n_estimators=150;, score=0.951 total time=   1.6s
# [CV 2/5; 1/1] START max_depth=4, max_features=29, n_estimators=150..............
# [CV 2/5; 1/1] END max_depth=4, max_features=29, n_estimators=150;, score=0.946 total time=   1.5s
# [CV 3/5; 1/1] START max_depth=4, max_features=29, n_estimators=150..............
# [CV 3/5; 1/1] END max_depth=4, max_features=29, n_estimators=150;, score=0.957 total time=   1.5s
# [CV 4/5; 1/1] START max_depth=4, max_features=29, n_estimators=150..............
# [CV 4/5; 1/1] END max_depth=4, max_features=29, n_estimators=150;, score=0.940 total time=   1.4s
# [CV 5/5; 1/1] START max_depth=4, max_features=29, n_estimators=150..............
# [CV 5/5; 1/1] END max_depth=4, max_features=29, n_estimators=150;, score=0.959 total time=   1.5s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=3, max_features=13, n_estimators=130..............
# [CV 1/5; 1/1] END max_depth=3, max_features=13, n_estimators=130;, score=0.943 total time=   0.6s
# [CV 2/5; 1/1] START max_depth=3, max_features=13, n_estimators=130..............
# [CV 2/5; 1/1] END max_depth=3, max_features=13, n_estimators=130;, score=0.946 total time=   0.6s
# [CV 3/5; 1/1] START max_depth=3, max_features=13, n_estimators=130..............
# [CV 3/5; 1/1] END max_depth=3, max_features=13, n_estimators=130;, score=0.955 total time=   0.6s
# [CV 4/5; 1/1] START max_depth=3, max_features=13, n_estimators=130..............
# [CV 4/5; 1/1] END max_depth=3, max_features=13, n_estimators=130;, score=0.932 total time=   0.5s
# [CV 5/5; 1/1] START max_depth=3, max_features=13, n_estimators=130..............
# [CV 5/5; 1/1] END max_depth=3, max_features=13, n_estimators=130;, score=0.948 total time=   0.6s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=49, n_estimators=72...............
# [CV 1/5; 1/1] END max_depth=4, max_features=49, n_estimators=72;, score=0.947 total time=   1.6s
# [CV 2/5; 1/1] START max_depth=4, max_features=49, n_estimators=72...............
# [CV 2/5; 1/1] END max_depth=4, max_features=49, n_estimators=72;, score=0.939 total time=   1.6s
# [CV 3/5; 1/1] START max_depth=4, max_features=49, n_estimators=72...............
# [CV 3/5; 1/1] END max_depth=4, max_features=49, n_estimators=72;, score=0.952 total time=   1.1s
# [CV 4/5; 1/1] START max_depth=4, max_features=49, n_estimators=72...............
# [CV 4/5; 1/1] END max_depth=4, max_features=49, n_estimators=72;, score=0.940 total time=   1.1s
# [CV 5/5; 1/1] START max_depth=4, max_features=49, n_estimators=72...............
# [CV 5/5; 1/1] END max_depth=4, max_features=49, n_estimators=72;, score=0.955 total time=   1.1s
# Precisión: 95.4% con OrderedDict([('max_depth', 4), ('max_features', 7), ('n_estimators', 397)])

# %% [markdown]
# ## HistGradientBoostingClassifier
# Un problema del clasificador GradientBoosting implementado en sklearn es su velocidad. Es un clasificador muy lento de entrenar. Por ello sklearn propone otro tipo de algoritmo de GradientBoosting que soporta paralelismo con OMP además de otras mejoras computacionales basadas en la discretización de las componentes mediante un histograma.
#
# Este otro algoritmo se denomina **HistGradientBoostingClassifier**. Su tiempo de ejecución es mucho mejor. Además se pueden obtener mejores resultados.

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier()

acc=hgb.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 95.5%

# %% [markdown]
# **Ejercicio** Analiza en la documentación [HistGradientBoosting](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingClassifier.html) los parámetros más relevantes y realiza una búsqueda de parámetros para obtener el mejor clasificador. A la hora de establecer los valores de los parámetros sería interesante fijarnos en los valores por defecto que se han empleado en el ejercicio anterior y poder explorar alrededor de dichos valores por defecto para conseguir mejores resultados.

# %%
## Solución

G = {"max_iter":Integer(50,400),"max_bins":Integer(10,255)}
# max_depth no está limitado por defecto y es mejor dejarlo así

# Probar sólo 10 combinaciones de parámetros, n_iter=10
BS = BayesSearchCV(HistGradientBoostingClassifier(), G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=49, max_iter=222...................................
# [CV 1/5; 1/1] END ....max_bins=49, max_iter=222;, score=0.951 total time=   1.4s
# [CV 2/5; 1/1] START max_bins=49, max_iter=222...................................
# [CV 2/5; 1/1] END ....max_bins=49, max_iter=222;, score=0.951 total time=   1.3s
# [CV 3/5; 1/1] START max_bins=49, max_iter=222...................................
# [CV 3/5; 1/1] END ....max_bins=49, max_iter=222;, score=0.973 total time=   3.7s
# [CV 4/5; 1/1] START max_bins=49, max_iter=222...................................
# [CV 4/5; 1/1] END ....max_bins=49, max_iter=222;, score=0.952 total time=   1.3s
# [CV 5/5; 1/1] START max_bins=49, max_iter=222...................................
# [CV 5/5; 1/1] END ....max_bins=49, max_iter=222;, score=0.955 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=252, max_iter=386..................................
# [CV 1/5; 1/1] END ...max_bins=252, max_iter=386;, score=0.952 total time=   4.2s
# [CV 2/5; 1/1] START max_bins=252, max_iter=386..................................
# [CV 2/5; 1/1] END ...max_bins=252, max_iter=386;, score=0.955 total time=   5.4s
# [CV 3/5; 1/1] START max_bins=252, max_iter=386..................................
# [CV 3/5; 1/1] END ...max_bins=252, max_iter=386;, score=0.969 total time=   3.5s
# [CV 4/5; 1/1] START max_bins=252, max_iter=386..................................
# [CV 4/5; 1/1] END ...max_bins=252, max_iter=386;, score=0.948 total time=   3.4s
# [CV 5/5; 1/1] START max_bins=252, max_iter=386..................................
# [CV 5/5; 1/1] END ...max_bins=252, max_iter=386;, score=0.952 total time=   3.4s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=207, max_iter=150..................................
# [CV 1/5; 1/1] END ...max_bins=207, max_iter=150;, score=0.946 total time=   5.0s
# [CV 2/5; 1/1] START max_bins=207, max_iter=150..................................
# [CV 2/5; 1/1] END ...max_bins=207, max_iter=150;, score=0.958 total time=   7.2s
# [CV 3/5; 1/1] START max_bins=207, max_iter=150..................................
# [CV 3/5; 1/1] END ...max_bins=207, max_iter=150;, score=0.967 total time=   9.2s
# [CV 4/5; 1/1] START max_bins=207, max_iter=150..................................
# [CV 4/5; 1/1] END ...max_bins=207, max_iter=150;, score=0.948 total time=  10.0s
# [CV 5/5; 1/1] START max_bins=207, max_iter=150..................................
# [CV 5/5; 1/1] END ...max_bins=207, max_iter=150;, score=0.954 total time=   1.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=48, max_iter=283...................................
# [CV 1/5; 1/1] END ....max_bins=48, max_iter=283;, score=0.954 total time=   1.6s
# [CV 2/5; 1/1] START max_bins=48, max_iter=283...................................
# [CV 2/5; 1/1] END ....max_bins=48, max_iter=283;, score=0.958 total time=   1.6s
# [CV 3/5; 1/1] START max_bins=48, max_iter=283...................................
# [CV 3/5; 1/1] END ....max_bins=48, max_iter=283;, score=0.966 total time=   1.6s
# [CV 4/5; 1/1] START max_bins=48, max_iter=283...................................
# [CV 4/5; 1/1] END ....max_bins=48, max_iter=283;, score=0.946 total time=   1.6s
# [CV 5/5; 1/1] START max_bins=48, max_iter=283...................................
# [CV 5/5; 1/1] END ....max_bins=48, max_iter=283;, score=0.958 total time=   3.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=195, max_iter=373..................................
# [CV 1/5; 1/1] END ...max_bins=195, max_iter=373;, score=0.951 total time=   3.8s
# [CV 2/5; 1/1] START max_bins=195, max_iter=373..................................
# [CV 2/5; 1/1] END ...max_bins=195, max_iter=373;, score=0.957 total time=   3.0s
# [CV 3/5; 1/1] START max_bins=195, max_iter=373..................................
# [CV 3/5; 1/1] END ...max_bins=195, max_iter=373;, score=0.966 total time=   3.0s
# [CV 4/5; 1/1] START max_bins=195, max_iter=373..................................
# [CV 4/5; 1/1] END ...max_bins=195, max_iter=373;, score=0.950 total time=   8.8s
# [CV 5/5; 1/1] START max_bins=195, max_iter=373..................................
# [CV 5/5; 1/1] END ...max_bins=195, max_iter=373;, score=0.954 total time=   3.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=221, max_iter=271..................................
# [CV 1/5; 1/1] END ...max_bins=221, max_iter=271;, score=0.948 total time=   2.4s
# [CV 2/5; 1/1] START max_bins=221, max_iter=271..................................
# [CV 2/5; 1/1] END ...max_bins=221, max_iter=271;, score=0.959 total time=   4.7s
# [CV 3/5; 1/1] START max_bins=221, max_iter=271..................................
# [CV 3/5; 1/1] END ...max_bins=221, max_iter=271;, score=0.966 total time=   2.3s
# [CV 4/5; 1/1] START max_bins=221, max_iter=271..................................
# [CV 4/5; 1/1] END ...max_bins=221, max_iter=271;, score=0.950 total time=   2.3s
# [CV 5/5; 1/1] START max_bins=221, max_iter=271..................................
# [CV 5/5; 1/1] END ...max_bins=221, max_iter=271;, score=0.952 total time=   2.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=234, max_iter=228..................................
# [CV 1/5; 1/1] END ...max_bins=234, max_iter=228;, score=0.951 total time=   2.2s
# [CV 2/5; 1/1] START max_bins=234, max_iter=228..................................
# [CV 2/5; 1/1] END ...max_bins=234, max_iter=228;, score=0.958 total time=   4.2s
# [CV 3/5; 1/1] START max_bins=234, max_iter=228..................................
# [CV 3/5; 1/1] END ...max_bins=234, max_iter=228;, score=0.965 total time=   2.0s
# [CV 4/5; 1/1] START max_bins=234, max_iter=228..................................
# [CV 4/5; 1/1] END ...max_bins=234, max_iter=228;, score=0.951 total time=   2.0s
# [CV 5/5; 1/1] START max_bins=234, max_iter=228..................................
# [CV 5/5; 1/1] END ...max_bins=234, max_iter=228;, score=0.957 total time=   2.0s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=86, max_iter=283...................................
# [CV 1/5; 1/1] END ....max_bins=86, max_iter=283;, score=0.946 total time=   1.8s
# [CV 2/5; 1/1] START max_bins=86, max_iter=283...................................
# [CV 2/5; 1/1] END ....max_bins=86, max_iter=283;, score=0.954 total time=   4.2s
# [CV 3/5; 1/1] START max_bins=86, max_iter=283...................................
# [CV 3/5; 1/1] END ....max_bins=86, max_iter=283;, score=0.971 total time=   1.9s
# [CV 4/5; 1/1] START max_bins=86, max_iter=283...................................
# [CV 4/5; 1/1] END ....max_bins=86, max_iter=283;, score=0.950 total time=   4.2s
# [CV 5/5; 1/1] START max_bins=86, max_iter=283...................................
# [CV 5/5; 1/1] END ....max_bins=86, max_iter=283;, score=0.950 total time=   1.9s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=141, max_iter=384..................................
# [CV 1/5; 1/1] END ...max_bins=141, max_iter=384;, score=0.946 total time=   5.2s
# [CV 2/5; 1/1] START max_bins=141, max_iter=384..................................
# [CV 2/5; 1/1] END ...max_bins=141, max_iter=384;, score=0.954 total time=   3.3s
# [CV 3/5; 1/1] START max_bins=141, max_iter=384..................................
# [CV 3/5; 1/1] END ...max_bins=141, max_iter=384;, score=0.967 total time=   2.9s
# [CV 4/5; 1/1] START max_bins=141, max_iter=384..................................
# [CV 4/5; 1/1] END ...max_bins=141, max_iter=384;, score=0.948 total time=   2.8s
# [CV 5/5; 1/1] START max_bins=141, max_iter=384..................................
# [CV 5/5; 1/1] END ...max_bins=141, max_iter=384;, score=0.955 total time=   5.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_bins=185, max_iter=364..................................
# [CV 1/5; 1/1] END ...max_bins=185, max_iter=364;, score=0.951 total time=   3.1s
# [CV 2/5; 1/1] START max_bins=185, max_iter=364..................................
# [CV 2/5; 1/1] END ...max_bins=185, max_iter=364;, score=0.955 total time=   2.9s
# [CV 3/5; 1/1] START max_bins=185, max_iter=364..................................
# [CV 3/5; 1/1] END ...max_bins=185, max_iter=364;, score=0.971 total time=   5.3s
# [CV 4/5; 1/1] START max_bins=185, max_iter=364..................................
# [CV 4/5; 1/1] END ...max_bins=185, max_iter=364;, score=0.954 total time=   2.9s
# [CV 5/5; 1/1] START max_bins=185, max_iter=364..................................
# [CV 5/5; 1/1] END ...max_bins=185, max_iter=364;, score=0.954 total time=   2.9s
# Precisión: 96.0% con OrderedDict([('max_bins', 185), ('max_iter', 364)])
