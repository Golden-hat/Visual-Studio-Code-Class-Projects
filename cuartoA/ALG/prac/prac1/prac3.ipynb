# %% [markdown]
# <h1 align="center">Práctica 3. Búsqueda con retroceso o <em>backtracking</em></h1>
# <h3 style="display:block; margin-top:5px;" align="center">Algorítmica</h3>
# <h3 style="display:block; margin-top:5px;" align="center">Grado en Informática</h3>
# <h3 style="display:block; margin-top:5px;" align="center">2024-2025</h3>
# <h3 style="display:block; margin-top:5px;" align="center">Universitat Politècnica de València</h3>
# <br>

# %% [markdown]
# **Pon/poned aquí tú/vuestros nombre(s):**
# Yassin Pellicer Lamla

# %% [markdown]
# ## Índice
# 1. ### [Introducción](#introduccion)
# 1. ### [Actividad 1: Permutaciones](#permutaciones)
# 1. ### [Actividad 2: Combinaciones](#combinaciones)
# 1. ### [Actividad 3: Cubrimiento exacto de un conjunto](#exactcover)
# 1. ### [Actividad 4: Secuencias de Langford](#langford)
# 1. ### [Actividad 5: Langford vía exact cover](#langford_exactcover)

# %% [markdown]
# <a id='introduccion'></a>
# ## Introducción
#
# Para realizar las siguientes actividades primero has de mirar las *slides* en formado pdf que hemos dejado en poliformat. Una vez llegues a las actividades explicadas en esas *slides* puedes completarlas en el siguiente *notebook*.

# %% [markdown]
# <a id='permutaciones'></a>
# ## Actividad 1: Permutaciones
#
# Vamos a empezar con las **variaciones con repetición:** El siguiente ejemplo muestra todas las posibles formas de elegir 2 ingredientes para una pizza incluyendo la posibilidad de (seguramente es tontería) **repetir ingredientes**:

# %%
def variacionesRepeticion(elementos, cantidad):

    def backtracking(sol):
        if len(sol) == cantidad:
            yield sol.copy()
        else:
            for opcion in elementos:
                sol.append(opcion)
                yield from backtracking(sol)
                sol.pop()

    yield from backtracking([])

# %%
ingredientes = ['mozzarella','pepperoni','champiñón','aceitunas','anchoa','tomate']
for pizza in variacionesRepeticion(ingredientes, 2):
    print(pizza)
# Out:
# ['mozzarella', 'mozzarella']
# ['mozzarella', 'pepperoni']
# ['mozzarella', 'champiñón']
# ['mozzarella', 'aceitunas']
# ['mozzarella', 'anchoa']
# ['mozzarella', 'tomate']
# ['pepperoni', 'mozzarella']
# ['pepperoni', 'pepperoni']
# ['pepperoni', 'champiñón']
# ['pepperoni', 'aceitunas']
# ['pepperoni', 'anchoa']
# ['pepperoni', 'tomate']
# ['champiñón', 'mozzarella']
# ['champiñón', 'pepperoni']
# ['champiñón', 'champiñón']
# ['champiñón', 'aceitunas']
# ['champiñón', 'anchoa']
# ['champiñón', 'tomate']
# ['aceitunas', 'mozzarella']
# ['aceitunas', 'pepperoni']
# ['aceitunas', 'champiñón']
# ['aceitunas', 'aceitunas']
# ['aceitunas', 'anchoa']
# ['aceitunas', 'tomate']
# ['anchoa', 'mozzarella']
# ['anchoa', 'pepperoni']
# ['anchoa', 'champiñón']
# ['anchoa', 'aceitunas']
# ['anchoa', 'anchoa']
# ['anchoa', 'tomate']
# ['tomate', 'mozzarella']
# ['tomate', 'pepperoni']
# ['tomate', 'champiñón']
# ['tomate', 'aceitunas']
# ['tomate', 'anchoa']
# ['tomate', 'tomate']

# %% [markdown]
# Adapta el código de variaciones con repetición para que ahora genere permutaciones. En las permutaciones no se pueden repetir los elementos y han de aparecer todos:

# %%
def permutaciones(elementos):

    def backtracking(sol):
        if len(sol) == len(elementos):
            yield sol.copy()
        else:
            for opcion in elementos:
                if opcion in sol: continue
                sol.append(opcion)
                yield from backtracking(sol)
                sol.pop()

    yield from backtracking([])

# %% [markdown]
# El resultado de ejecutar:
#
# ```python
# ingredientes = ['mozzarella','aceitunas','tomate']
# for pizza in permutaciones(ingredientes):
#     print(pizza)
# ```
#
# debe ser:
#
# ```
# ['mozzarella', 'aceitunas', 'tomate']
# ['mozzarella', 'tomate', 'aceitunas']
# ['aceitunas', 'mozzarella', 'tomate']
# ['aceitunas', 'tomate', 'mozzarella']
# ['tomate', 'mozzarella', 'aceitunas']
# ['tomate', 'aceitunas', 'mozzarella']
# ```

# %%
ingredientes = ['mozzarella','aceitunas','tomate']
for pizza in permutaciones(ingredientes):
    print(pizza)
# Out:
# ['mozzarella', 'aceitunas', 'tomate']
# ['mozzarella', 'tomate', 'aceitunas']
# ['aceitunas', 'mozzarella', 'tomate']
# ['aceitunas', 'tomate', 'mozzarella']
# ['tomate', 'mozzarella', 'aceitunas']
# ['tomate', 'aceitunas', 'mozzarella']

# %% [markdown]
# Realiza algún experimento más para comprobar que el nº permutaciones con n elementos es el factorial de n.

# %%
import math
ingredientes = ['mozzarella','aceitunas','tomate','pepperonni','rucula','salmon','pesto']
nCounter = 0
for pizza in permutaciones(ingredientes):
    nCounter += 1
    print(pizza)
    
if(nCounter == math.factorial(len(ingredientes))) : print("\npermutaciones coincide con num. factorial de elementos, "+str(math.factorial(len(ingredientes))))
# Out:
# ['mozzarella', 'aceitunas', 'tomate', 'pepperonni', 'rucula', 'salmon', 'pesto']
# ['mozzarella', 'aceitunas', 'tomate', 'pepperonni', 'rucula', 'pesto', 'salmon']
# ['mozzarella', 'aceitunas', 'tomate', 'pepperonni', 'salmon', 'rucula', 'pesto']
# ['mozzarella', 'aceitunas', 'tomate', 'pepperonni', 'salmon', 'pesto', 'rucula']
# ['mozzarella', 'aceitunas', 'tomate', 'pepperonni', 'pesto', 'rucula', 'salmon']
# ['mozzarella', 'aceitunas', 'tomate', 'pepperonni', 'pesto', 'salmon', 'rucula']
# ['mozzarella', 'aceitunas', 'tomate', 'rucula', 'pepperonni', 'salmon', 'pesto']
# ['mozzarella', 'aceitunas', 'tomate', 'rucula', 'pepperonni', 'pesto', 'salmon']
# ['mozzarella', 'aceitunas', 'tomate', 'rucula', 'salmon', 'pepperonni', 'pesto']
# ['mozzarella', 'aceitunas', 'tomate', 'rucula', 'salmon', 'pesto', 'pepperonni']
# ['mozzarella', 'aceitunas', 'tomate', 'rucula', 'pesto', 'pepperonni', 'salmon']
# ['mozzarella', 'aceitunas', 'tomate', 'rucula', 'pesto', 'salmon', 'pepperonni']
# ['mozzarella', 'aceitunas', 'tomate', 'salmon', 'pepperonni', 'rucula', 'pesto']
# ['mozzarella', 'aceitunas', 'tomate', 'salmon', 'pepperonni', 'pesto', 'rucula']
# ['mozzarella', 'aceitunas', 'tomate', 'salmon', 'rucula', 'pepperonni', 'pesto']
# ['mozzarella', 'aceitunas', 'tomate', 'salmon', 'rucula', 'pesto', 'pepperonni']
# ['mozzarella', 'aceitunas', 'tomate', 'salmon', 'pesto', 'pepperonni', 'rucula']
# ['mozzarella', 'aceitunas', 'tomate', 'salmon', 'pesto', 'rucula', 'pepperonni']
# ['mozzarella', 'aceitunas', 'tomate', 'pesto', 'pepperonni', 'rucula', 'salmon']
# ['mozzarella', 'aceitunas', 'tomate', 'pesto', 'pepperonni', 'salmon', 'rucula']
# ['mozzarella', 'aceitunas', 'tomate', 'pesto', 'rucula', 'pepperonni', 'salmon']
# ['mozzarella', 'aceitunas', 'tomate', 'pesto', 'rucula', 'salmon', 'pepperonni']
# ['mozzarella', 'aceitunas', 'tomate', 'pesto', 'salmon', 'pepperonni', 'rucula']
# ['mozzarella', 'aceitunas', 'tomate', 'pesto', 'salmon', 'rucula', 'pepperonni']
# ['mozzarella', 'aceitunas', 'pepperonni', 'tomate', 'rucula', 'salmon', 'pesto']
# ['mozzarella', 'aceitunas', 'pepperonni', 'tomate', 'rucula', 'pesto', 'salmon']
# ['mozzarella', 'aceitunas', 'pepperonni', 'tomate', 'salmon', 'rucula', 'pesto']
# ['mozzarella', 'aceitunas', 'pepperonni', 'tomate', 'salmon', 'pesto', 'rucula']
# ['mozzarella', 'aceitunas', 'pepperonni', 'tomate', 'pesto', 'rucula', 'salmon']
# ['mozzarella', 'aceitunas', 'pepperonni', 'tomate', 'pesto', 'salmon', 'rucula']
# ['mozzarella', 'aceitunas', 'pepperonni', 'rucula', 'tomate', 'salmon', 'pesto']
# ['mozzarella', 'aceitunas', 'pepperonni', 'rucula', 'tomate', 'pesto', 'salmon']
# ['mozzarella', 'aceitunas', 'pepperonni', 'rucula', 'salmon', 'tomate', 'pesto']
# ['mozzarella', 'aceitunas', 'pepperonni', 'rucula', 'salmon', 'pesto', 'tomate']
# ['mozzarella', 'aceitunas', 'pepperonni', 'rucula', 'pesto', 'tomate', 'salmon']
# ['mozzarella', 'aceitunas', 'pepperonni', 'rucula', 'pesto', 'salmon', 'tomate']
# ['mozzarella', 'aceitunas', 'pepperonni', 'salmon', 'tomate', 'rucula', 'pesto']
# ['mozzarella', 'aceitunas', 'pepperonni', 'salmon', 'tomate', 'pesto', 'rucula']
# ['mozzarella', 'aceitunas', 'pepperonni', 'salmon', 'rucula', 'tomate', 'pesto']
# ['mozzarella', 'aceitunas', 'pepperonni', 'salmon', 'rucula', 'pesto', 'tomate']
# ['mozzarella', 'aceitunas', 'pepperonni', 'salmon', 'pesto', 'tomate', 'rucula']
# ['mozzarella', 'aceitunas', 'pepperonni', 'salmon', 'pesto', 'rucula', 'tomate']
# ['mozzarella', 'aceitunas', 'pepperonni', 'pesto', 'tomate', 'rucula', 'salmon']
# ['mozzarella', 'aceitunas', 'pepperonni', 'pesto', 'tomate', 'salmon', 'rucula']
# ['mozzarella', 'aceitunas', 'pepperonni', 'pesto', 'rucula', 'tomate', 'salmon']
# ['mozzarella', 'aceitunas', 'pepperonni', 'pesto', 'rucula', 'salmon', 'tomate']
# ['mozzarella', 'aceitunas', 'pepperonni', 'pesto', 'salmon', 'tomate', 'rucula']
# ['mozzarella', 'aceitunas', 'pepperonni', 'pesto', 'salmon', 'rucula', 'tomate']
# ['mozzarella', 'aceitunas', 'rucula', 'tomate', 'pepperonni', 'salmon', 'pesto']
# ['mozzarella', 'aceitunas', 'rucula', 'tomate', 'pepperonni', 'pesto', 'salmon']
# ['mozzarella', 'aceitunas', 'rucula', 'tomate', 'salmon', 'pepperonni', 'pesto']
# ['mozzarella', 'aceitunas', 'rucula', 'tomate', 'salmon', 'pesto', 'pepperonni']
# ['mozzarella', 'aceitunas', 'rucula', 'tomate', 'pesto', 'pepperonni', 'salmon']
# ['mozzarella', 'aceitunas', 'rucula', 'tomate', 'pesto', 'salmon', 'pepperonni']
# ['mozzarella', 'aceitunas', 'rucula', 'pepperonni', 'tomate', 'salmon', 'pesto']
# ['mozzarella', 'aceitunas', 'rucula', 'pepperonni', 'tomate', 'pesto', 'salmon']
# ['mozzarella', 'aceitunas', 'rucula', 'pepperonni', 'salmon', 'tomate', 'pesto']
# ['mozzarella', 'aceitunas', 'rucula', 'pepperonni', 'salmon', 'pesto', 'tomate']
# ['mozzarella', 'aceitunas', 'rucula', 'pepperonni', 'pesto', 'tomate', 'salmon']
# ['mozzarella', 'aceitunas', 'rucula', 'pepperonni', 'pesto', 'salmon', 'tomate']
# ['mozzarella', 'aceitunas', 'rucula', 'salmon', 'tomate', 'pepperonni', 'pesto']
# ['mozzarella', 'aceitunas', 'rucula', 'salmon', 'tomate', 'pesto', 'pepperonni']
# ['mozzarella', 'aceitunas', 'rucula', 'salmon', 'pepperonni', 'tomate', 'pesto']
# ['mozzarella', 'aceitunas', 'rucula', 'salmon', 'pepperonni', 'pesto', 'tomate']
# ['mozzarella', 'aceitunas', 'rucula', 'salmon', 'pesto', 'tomate', 'pepperonni']
# ['mozzarella', 'aceitunas', 'rucula', 'salmon', 'pesto', 'pepperonni', 'tomate']
# ['mozzarella', 'aceitunas', 'rucula', 'pesto', 'tomate', 'pepperonni', 'salmon']
# ['mozzarella', 'aceitunas', 'rucula', 'pesto', 'tomate', 'salmon', 'pepperonni']
# ['mozzarella', 'aceitunas', 'rucula', 'pesto', 'pepperonni', 'tomate', 'salmon']
# ['mozzarella', 'aceitunas', 'rucula', 'pesto', 'pepperonni', 'salmon', 'tomate']
# ['mozzarella', 'aceitunas', 'rucula', 'pesto', 'salmon', 'tomate', 'pepperonni']
# ['mozzarella', 'aceitunas', 'rucula', 'pesto', 'salmon', 'pepperonni', 'tomate']
# ['mozzarella', 'aceitunas', 'salmon', 'tomate', 'pepperonni', 'rucula', 'pesto']
# ['mozzarella', 'aceitunas', 'salmon', 'tomate', 'pepperonni', 'pesto', 'rucula']
# ['mozzarella', 'aceitunas', 'salmon', 'tomate', 'rucula', 'pepperonni', 'pesto']
# ['mozzarella', 'aceitunas', 'salmon', 'tomate', 'rucula', 'pesto', 'pepperonni']
# ['mozzarella', 'aceitunas', 'salmon', 'tomate', 'pesto', 'pepperonni', 'rucula']
# ['mozzarella', 'aceitunas', 'salmon', 'tomate', 'pesto', 'rucula', 'pepperonni']
# ['mozzarella', 'aceitunas', 'salmon', 'pepperonni', 'tomate', 'rucula', 'pesto']
# ['mozzarella', 'aceitunas', 'salmon', 'pepperonni', 'tomate', 'pesto', 'rucula']
# ['mozzarella', 'aceitunas', 'salmon', 'pepperonni', 'rucula', 'tomate', 'pesto']
# ['mozzarella', 'aceitunas', 'salmon', 'pepperonni', 'rucula', 'pesto', 'tomate']
# ['mozzarella', 'aceitunas', 'salmon', 'pepperonni', 'pesto', 'tomate', 'rucula']
# ['mozzarella', 'aceitunas', 'salmon', 'pepperonni', 'pesto', 'rucula', 'tomate']
# ['mozzarella', 'aceitunas', 'salmon', 'rucula', 'tomate', 'pepperonni', 'pesto']
# ['mozzarella', 'aceitunas', 'salmon', 'rucula', 'tomate', 'pesto', 'pepperonni']
# ['mozzarella', 'aceitunas', 'salmon', 'rucula', 'pepperonni', 'tomate', 'pesto']
# ['mozzarella', 'aceitunas', 'salmon', 'rucula', 'pepperonni', 'pesto', 'tomate']
# ['mozzarella', 'aceitunas', 'salmon', 'rucula', 'pesto', 'tomate', 'pepperonni']
# ['mozzarella', 'aceitunas', 'salmon', 'rucula', 'pesto', 'pepperonni', 'tomate']
# ['mozzarella', 'aceitunas', 'salmon', 'pesto', 'tomate', 'pepperonni', 'rucula']
# ['mozzarella', 'aceitunas', 'salmon', 'pesto', 'tomate', 'rucula', 'pepperonni']
# ['mozzarella', 'aceitunas', 'salmon', 'pesto', 'pepperonni', 'tomate', 'rucula']
# ['mozzarella', 'aceitunas', 'salmon', 'pesto', 'pepperonni', 'rucula', 'tomate']
# ['mozzarella', 'aceitunas', 'salmon', 'pesto', 'rucula', 'tomate', 'pepperonni']
# ['mozzarella', 'aceitunas', 'salmon', 'pesto', 'rucula', 'pepperonni', 'tomate']
# ['mozzarella', 'aceitunas', 'pesto', 'tomate', 'pepperonni', 'rucula', 'salmon']
# ['mozzarella', 'aceitunas', 'pesto', 'tomate', 'pepperonni', 'salmon', 'rucula']
# ['mozzarella', 'aceitunas', 'pesto', 'tomate', 'rucula', 'pepperonni', 'salmon']
# ['mozzarella', 'aceitunas', 'pesto', 'tomate', 'rucula', 'salmon', 'pepperonni']
# ['mozzarella', 'aceitunas', 'pesto', 'tomate', 'salmon', 'pepperonni', 'rucula']
# ['mozzarella', 'aceitunas', 'pesto', 'tomate', 'salmon', 'rucula', 'pepperonni']
# ['mozzarella', 'aceitunas', 'pesto', 'pepperonni', 'tomate', 'rucula', 'salmon']
# ['mozzarella', 'aceitunas', 'pesto', 'pepperonni', 'tomate', 'salmon', 'rucula']
# ['mozzarella', 'aceitunas', 'pesto', 'pepperonni', 'rucula', 'tomate', 'salmon']
# ['mozzarella', 'aceitunas', 'pesto', 'pepperonni', 'rucula', 'salmon', 'tomate']
# ['mozzarella', 'aceitunas', 'pesto', 'pepperonni', 'salmon', 'tomate', 'rucula']
# ['mozzarella', 'aceitunas', 'pesto', 'pepperonni', 'salmon', 'rucula', 'tomate']
# ['mozzarella', 'aceitunas', 'pesto', 'rucula', 'tomate', 'pepperonni', 'salmon']
# ['mozzarella', 'aceitunas', 'pesto', 'rucula', 'tomate', 'salmon', 'pepperonni']
# ['mozzarella', 'aceitunas', 'pesto', 'rucula', 'pepperonni', 'tomate', 'salmon']
# ['mozzarella', 'aceitunas', 'pesto', 'rucula', 'pepperonni', 'salmon', 'tomate']
# ['mozzarella', 'aceitunas', 'pesto', 'rucula', 'salmon', 'tomate', 'pepperonni']
# ['mozzarella', 'aceitunas', 'pesto', 'rucula', 'salmon', 'pepperonni', 'tomate']
# ['mozzarella', 'aceitunas', 'pesto', 'salmon', 'tomate', 'pepperonni', 'rucula']
# ['mozzarella', 'aceitunas', 'pesto', 'salmon', 'tomate', 'rucula', 'pepperonni']
# ['mozzarella', 'aceitunas', 'pesto', 'salmon', 'pepperonni', 'tomate', 'rucula']
# ['mozzarella', 'aceitunas', 'pesto', 'salmon', 'pepperonni', 'rucula', 'tomate']
# ['mozzarella', 'aceitunas', 'pesto', 'salmon', 'rucula', 'tomate', 'pepperonni']
# ['mozzarella', 'aceitunas', 'pesto', 'salmon', 'rucula', 'pepperonni', 'tomate']
# ['mozzarella', 'tomate', 'aceitunas', 'pepperonni', 'rucula', 'salmon', 'pesto']
# ['mozzarella', 'tomate', 'aceitunas', 'pepperonni', 'rucula', 'pesto', 'salmon']
# ['mozzarella', 'tomate', 'aceitunas', 'pepperonni', 'salmon', 'rucula', 'pesto']
# ['mozzarella', 'tomate', 'aceitunas', 'pepperonni', 'salmon', 'pesto', 'rucula']
# ['mozzarella', 'tomate', 'aceitunas', 'pepperonni', 'pesto', 'rucula', 'salmon']
# ['mozzarella', 'tomate', 'aceitunas', 'pepperonni', 'pesto', 'salmon', 'rucula']
# ['mozzarella', 'tomate', 'aceitunas', 'rucula', 'pepperonni', 'salmon', 'pesto']
# ['mozzarella', 'tomate', 'aceitunas', 'rucula', 'pepperonni', 'pesto', 'salmon']
# ['mozzarella', 'tomate', 'aceitunas', 'rucula', 'salmon', 'pepperonni', 'pesto']
# ['mozzarella', 'tomate', 'aceitunas', 'rucula', 'salmon', 'pesto', 'pepperonni']
# ['mozzarella', 'tomate', 'aceitunas', 'rucula', 'pesto', 'pepperonni', 'salmon']
# ['mozzarella', 'tomate', 'aceitunas', 'rucula', 'pesto', 'salmon', 'pepperonni']
# ['mozzarella', 'tomate', 'aceitunas', 'salmon', 'pepperonni', 'rucula', 'pesto']
# ['mozzarella', 'tomate', 'aceitunas', 'salmon', 'pepperonni', 'pesto', 'rucula']
# ['mozzarella', 'tomate', 'aceitunas', 'salmon', 'rucula', 'pepperonni', 'pesto']
# ['mozzarella', 'tomate', 'aceitunas', 'salmon', 'rucula', 'pesto', 'pepperonni']
# ['mozzarella', 'tomate', 'aceitunas', 'salmon', 'pesto', 'pepperonni', 'rucula']
# ['mozzarella', 'tomate', 'aceitunas', 'salmon', 'pesto', 'rucula', 'pepperonni']
# ['mozzarella', 'tomate', 'aceitunas', 'pesto', 'pepperonni', 'rucula', 'salmon']
# ['mozzarella', 'tomate', 'aceitunas', 'pesto', 'pepperonni', 'salmon', 'rucula']
# ['mozzarella', 'tomate', 'aceitunas', 'pesto', 'rucula', 'pepperonni', 'salmon']
# ['mozzarella', 'tomate', 'aceitunas', 'pesto', 'rucula', 'salmon', 'pepperonni']
# ['mozzarella', 'tomate', 'aceitunas', 'pesto', 'salmon', 'pepperonni', 'rucula']
# ['mozzarella', 'tomate', 'aceitunas', 'pesto', 'salmon', 'rucula', 'pepperonni']
# ['mozzarella', 'tomate', 'pepperonni', 'aceitunas', 'rucula', 'salmon', 'pesto']
# ['mozzarella', 'tomate', 'pepperonni', 'aceitunas', 'rucula', 'pesto', 'salmon']
# ['mozzarella', 'tomate', 'pepperonni', 'aceitunas', 'salmon', 'rucula', 'pesto']
# ['mozzarella', 'tomate', 'pepperonni', 'aceitunas', 'salmon', 'pesto', 'rucula']
# ['mozzarella', 'tomate', 'pepperonni', 'aceitunas', 'pesto', 'rucula', 'salmon']
# ['mozzarella', 'tomate', 'pepperonni', 'aceitunas', 'pesto', 'salmon', 'rucula']
# ['mozzarella', 'tomate', 'pepperonni', 'rucula', 'aceitunas', 'salmon', 'pesto']
# ['mozzarella', 'tomate', 'pepperonni', 'rucula', 'aceitunas', 'pesto', 'salmon']
# ['mozzarella', 'tomate', 'pepperonni', 'rucula', 'salmon', 'aceitunas', 'pesto']
# ['mozzarella', 'tomate', 'pepperonni', 'rucula', 'salmon', 'pesto', 'aceitunas']
# ['mozzarella', 'tomate', 'pepperonni', 'rucula', 'pesto', 'aceitunas', 'salmon']
# ['mozzarella', 'tomate', 'pepperonni', 'rucula', 'pesto', 'salmon', 'aceitunas']
# ['mozzarella', 'tomate', 'pepperonni', 'salmon', 'aceitunas', 'rucula', 'pesto']
# ['mozzarella', 'tomate', 'pepperonni', 'salmon', 'aceitunas', 'pesto', 'rucula']
# ['mozzarella', 'tomate', 'pepperonni', 'salmon', 'rucula', 'aceitunas', 'pesto']
# ['mozzarella', 'tomate', 'pepperonni', 'salmon', 'rucula', 'pesto', 'aceitunas']
# ['mozzarella', 'tomate', 'pepperonni', 'salmon', 'pesto', 'aceitunas', 'rucula']
# ['mozzarella', 'tomate', 'pepperonni', 'salmon', 'pesto', 'rucula', 'aceitunas']
# ['mozzarella', 'tomate', 'pepperonni', 'pesto', 'aceitunas', 'rucula', 'salmon']
# ['mozzarella', 'tomate', 'pepperonni', 'pesto', 'aceitunas', 'salmon', 'rucula']
# ['mozzarella', 'tomate', 'pepperonni', 'pesto', 'rucula', 'aceitunas', 'salmon']
# ['mozzarella', 'tomate', 'pepperonni', 'pesto', 'rucula', 'salmon', 'aceitunas']
# ['mozzarella', 'tomate', 'pepperonni', 'pesto', 'salmon', 'aceitunas', 'rucula']
# ['mozzarella', 'tomate', 'pepperonni', 'pesto', 'salmon', 'rucula', 'aceitunas']
# ['mozzarella', 'tomate', 'rucula', 'aceitunas', 'pepperonni', 'salmon', 'pesto']
# ['mozzarella', 'tomate', 'rucula', 'aceitunas', 'pepperonni', 'pesto', 'salmon']
# ['mozzarella', 'tomate', 'rucula', 'aceitunas', 'salmon', 'pepperonni', 'pesto']
# ['mozzarella', 'tomate', 'rucula', 'aceitunas', 'salmon', 'pesto', 'pepperonni']
# ['mozzarella', 'tomate', 'rucula', 'aceitunas', 'pesto', 'pepperonni', 'salmon']
# ['mozzarella', 'tomate', 'rucula', 'aceitunas', 'pesto', 'salmon', 'pepperonni']
# ['mozzarella', 'tomate', 'rucula', 'pepperonni', 'aceitunas', 'salmon', 'pesto']
# ['mozzarella', 'tomate', 'rucula', 'pepperonni', 'aceitunas', 'pesto', 'salmon']
# ['mozzarella', 'tomate', 'rucula', 'pepperonni', 'salmon', 'aceitunas', 'pesto']
# ['mozzarella', 'tomate', 'rucula', 'pepperonni', 'salmon', 'pesto', 'aceitunas']
# ['mozzarella', 'tomate', 'rucula', 'pepperonni', 'pesto', 'aceitunas', 'salmon']
# ['mozzarella', 'tomate', 'rucula', 'pepperonni', 'pesto', 'salmon', 'aceitunas']
# ['mozzarella', 'tomate', 'rucula', 'salmon', 'aceitunas', 'pepperonni', 'pesto']
# ['mozzarella', 'tomate', 'rucula', 'salmon', 'aceitunas', 'pesto', 'pepperonni']
# ['mozzarella', 'tomate', 'rucula', 'salmon', 'pepperonni', 'aceitunas', 'pesto']
# ['mozzarella', 'tomate', 'rucula', 'salmon', 'pepperonni', 'pesto', 'aceitunas']
# ['mozzarella', 'tomate', 'rucula', 'salmon', 'pesto', 'aceitunas', 'pepperonni']
# ['mozzarella', 'tomate', 'rucula', 'salmon', 'pesto', 'pepperonni', 'aceitunas']
# ['mozzarella', 'tomate', 'rucula', 'pesto', 'aceitunas', 'pepperonni', 'salmon']
# ['mozzarella', 'tomate', 'rucula', 'pesto', 'aceitunas', 'salmon', 'pepperonni']
# ['mozzarella', 'tomate', 'rucula', 'pesto', 'pepperonni', 'aceitunas', 'salmon']
# ['mozzarella', 'tomate', 'rucula', 'pesto', 'pepperonni', 'salmon', 'aceitunas']
# ['mozzarella', 'tomate', 'rucula', 'pesto', 'salmon', 'aceitunas', 'pepperonni']
# ['mozzarella', 'tomate', 'rucula', 'pesto', 'salmon', 'pepperonni', 'aceitunas']
# ['mozzarella', 'tomate', 'salmon', 'aceitunas', 'pepperonni', 'rucula', 'pesto']
# ['mozzarella', 'tomate', 'salmon', 'aceitunas', 'pepperonni', 'pesto', 'rucula']
# ['mozzarella', 'tomate', 'salmon', 'aceitunas', 'rucula', 'pepperonni', 'pesto']
# ['mozzarella', 'tomate', 'salmon', 'aceitunas', 'rucula', 'pesto', 'pepperonni']
# ['mozzarella', 'tomate', 'salmon', 'aceitunas', 'pesto', 'pepperonni', 'rucula']
# ['mozzarella', 'tomate', 'salmon', 'aceitunas', 'pesto', 'rucula', 'pepperonni']
# ['mozzarella', 'tomate', 'salmon', 'pepperonni', 'aceitunas', 'rucula', 'pesto']
# ['mozzarella', 'tomate', 'salmon', 'pepperonni', 'aceitunas', 'pesto', 'rucula']
# ['mozzarella', 'tomate', 'salmon', 'pepperonni', 'rucula', 'aceitunas', 'pesto']
# ['mozzarella', 'tomate', 'salmon', 'pepperonni', 'rucula', 'pesto', 'aceitunas']
# ['mozzarella', 'tomate', 'salmon', 'pepperonni', 'pesto', 'aceitunas', 'rucula']
# ['mozzarella', 'tomate', 'salmon', 'pepperonni', 'pesto', 'rucula', 'aceitunas']
# ['mozzarella', 'tomate', 'salmon', 'rucula', 'aceitunas', 'pepperonni', 'pesto']
# ['mozzarella', 'tomate', 'salmon', 'rucula', 'aceitunas', 'pesto', 'pepperonni']
# ['mozzarella', 'tomate', 'salmon', 'rucula', 'pepperonni', 'aceitunas', 'pesto']
# ['mozzarella', 'tomate', 'salmon', 'rucula', 'pepperonni', 'pesto', 'aceitunas']
# ['mozzarella', 'tomate', 'salmon', 'rucula', 'pesto', 'aceitunas', 'pepperonni']
# ['mozzarella', 'tomate', 'salmon', 'rucula', 'pesto', 'pepperonni', 'aceitunas']
# ['mozzarella', 'tomate', 'salmon', 'pesto', 'aceitunas', 'pepperonni', 'rucula']
# ['mozzarella', 'tomate', 'salmon', 'pesto', 'aceitunas', 'rucula', 'pepperonni']
# ['mozzarella', 'tomate', 'salmon', 'pesto', 'pepperonni', 'aceitunas', 'rucula']
# ['mozzarella', 'tomate', 'salmon', 'pesto', 'pepperonni', 'rucula', 'aceitunas']
# ['mozzarella', 'tomate', 'salmon', 'pesto', 'rucula', 'aceitunas', 'pepperonni']
# ['mozzarella', 'tomate', 'salmon', 'pesto', 'rucula', 'pepperonni', 'aceitunas']
# ['mozzarella', 'tomate', 'pesto', 'aceitunas', 'pepperonni', 'rucula', 'salmon']
# ['mozzarella', 'tomate', 'pesto', 'aceitunas', 'pepperonni', 'salmon', 'rucula']
# ['mozzarella', 'tomate', 'pesto', 'aceitunas', 'rucula', 'pepperonni', 'salmon']
# ['mozzarella', 'tomate', 'pesto', 'aceitunas', 'rucula', 'salmon', 'pepperonni']
# ['mozzarella', 'tomate', 'pesto', 'aceitunas', 'salmon', 'pepperonni', 'rucula']
# ['mozzarella', 'tomate', 'pesto', 'aceitunas', 'salmon', 'rucula', 'pepperonni']
# ['mozzarella', 'tomate', 'pesto', 'pepperonni', 'aceitunas', 'rucula', 'salmon']
# ['mozzarella', 'tomate', 'pesto', 'pepperonni', 'aceitunas', 'salmon', 'rucula']
# ['mozzarella', 'tomate', 'pesto', 'pepperonni', 'rucula', 'aceitunas', 'salmon']
# ['mozzarella', 'tomate', 'pesto', 'pepperonni', 'rucula', 'salmon', 'aceitunas']
# ['mozzarella', 'tomate', 'pesto', 'pepperonni', 'salmon', 'aceitunas', 'rucula']
# ['mozzarella', 'tomate', 'pesto', 'pepperonni', 'salmon', 'rucula', 'aceitunas']
# ['mozzarella', 'tomate', 'pesto', 'rucula', 'aceitunas', 'pepperonni', 'salmon']
# ['mozzarella', 'tomate', 'pesto', 'rucula', 'aceitunas', 'salmon', 'pepperonni']
# ['mozzarella', 'tomate', 'pesto', 'rucula', 'pepperonni', 'aceitunas', 'salmon']
# ['mozzarella', 'tomate', 'pesto', 'rucula', 'pepperonni', 'salmon', 'aceitunas']
# ['mozzarella', 'tomate', 'pesto', 'rucula', 'salmon', 'aceitunas', 'pepperonni']
# ['mozzarella', 'tomate', 'pesto', 'rucula', 'salmon', 'pepperonni', 'aceitunas']
# ['mozzarella', 'tomate', 'pesto', 'salmon', 'aceitunas', 'pepperonni', 'rucula']
# ['mozzarella', 'tomate', 'pesto', 'salmon', 'aceitunas', 'rucula', 'pepperonni']
# ['mozzarella', 'tomate', 'pesto', 'salmon', 'pepperonni', 'aceitunas', 'rucula']
# ['mozzarella', 'tomate', 'pesto', 'salmon', 'pepperonni', 'rucula', 'aceitunas']
# ['mozzarella', 'tomate', 'pesto', 'salmon', 'rucula', 'aceitunas', 'pepperonni']
# ['mozzarella', 'tomate', 'pesto', 'salmon', 'rucula', 'pepperonni', 'aceitunas']
# ['mozzarella', 'pepperonni', 'aceitunas', 'tomate', 'rucula', 'salmon', 'pesto']
# ['mozzarella', 'pepperonni', 'aceitunas', 'tomate', 'rucula', 'pesto', 'salmon']
# ['mozzarella', 'pepperonni', 'aceitunas', 'tomate', 'salmon', 'rucula', 'pesto']
# ['mozzarella', 'pepperonni', 'aceitunas', 'tomate', 'salmon', 'pesto', 'rucula']
# ['mozzarella', 'pepperonni', 'aceitunas', 'tomate', 'pesto', 'rucula', 'salmon']
# ['mozzarella', 'pepperonni', 'aceitunas', 'tomate', 'pesto', 'salmon', 'rucula']
# ['mozzarella', 'pepperonni', 'aceitunas', 'rucula', 'tomate', 'salmon', 'pesto']
# ['mozzarella', 'pepperonni', 'aceitunas', 'rucula', 'tomate', 'pesto', 'salmon']
# ['mozzarella', 'pepperonni', 'aceitunas', 'rucula', 'salmon', 'tomate', 'pesto']
# ['mozzarella', 'pepperonni', 'aceitunas', 'rucula', 'salmon', 'pesto', 'tomate']
# ['mozzarella', 'pepperonni', 'aceitunas', 'rucula', 'pesto', 'tomate', 'salmon']
# ['mozzarella', 'pepperonni', 'aceitunas', 'rucula', 'pesto', 'salmon', 'tomate']
# ['mozzarella', 'pepperonni', 'aceitunas', 'salmon', 'tomate', 'rucula', 'pesto']
# ['mozzarella', 'pepperonni', 'aceitunas', 'salmon', 'tomate', 'pesto', 'rucula']
# ['mozzarella', 'pepperonni', 'aceitunas', 'salmon', 'rucula', 'tomate', 'pesto']
# ['mozzarella', 'pepperonni', 'aceitunas', 'salmon', 'rucula', 'pesto', 'tomate']
# ['mozzarella', 'pepperonni', 'aceitunas', 'salmon', 'pesto', 'tomate', 'rucula']
# ['mozzarella', 'pepperonni', 'aceitunas', 'salmon', 'pesto', 'rucula', 'tomate']
# ['mozzarella', 'pepperonni', 'aceitunas', 'pesto', 'tomate', 'rucula', 'salmon']
# ['mozzarella', 'pepperonni', 'aceitunas', 'pesto', 'tomate', 'salmon', 'rucula']
# ['mozzarella', 'pepperonni', 'aceitunas', 'pesto', 'rucula', 'tomate', 'salmon']
# ['mozzarella', 'pepperonni', 'aceitunas', 'pesto', 'rucula', 'salmon', 'tomate']
# ['mozzarella', 'pepperonni', 'aceitunas', 'pesto', 'salmon', 'tomate', 'rucula']
# ['mozzarella', 'pepperonni', 'aceitunas', 'pesto', 'salmon', 'rucula', 'tomate']
# ['mozzarella', 'pepperonni', 'tomate', 'aceitunas', 'rucula', 'salmon', 'pesto']
# ['mozzarella', 'pepperonni', 'tomate', 'aceitunas', 'rucula', 'pesto', 'salmon']
# ['mozzarella', 'pepperonni', 'tomate', 'aceitunas', 'salmon', 'rucula', 'pesto']
# ['mozzarella', 'pepperonni', 'tomate', 'aceitunas', 'salmon', 'pesto', 'rucula']
# ['mozzarella', 'pepperonni', 'tomate', 'aceitunas', 'pesto', 'rucula', 'salmon']
# ['mozzarella', 'pepperonni', 'tomate', 'aceitunas', 'pesto', 'salmon', 'rucula']
# ['mozzarella', 'pepperonni', 'tomate', 'rucula', 'aceitunas', 'salmon', 'pesto']
# ['mozzarella', 'pepperonni', 'tomate', 'rucula', 'aceitunas', 'pesto', 'salmon']
# ['mozzarella', 'pepperonni', 'tomate', 'rucula', 'salmon', 'aceitunas', 'pesto']
# ['mozzarella', 'pepperonni', 'tomate', 'rucula', 'salmon', 'pesto', 'aceitunas']
# ['mozzarella', 'pepperonni', 'tomate', 'rucula', 'pesto', 'aceitunas', 'salmon']
# ['mozzarella', 'pepperonni', 'tomate', 'rucula', 'pesto', 'salmon', 'aceitunas']
# ['mozzarella', 'pepperonni', 'tomate', 'salmon', 'aceitunas', 'rucula', 'pesto']
# ['mozzarella', 'pepperonni', 'tomate', 'salmon', 'aceitunas', 'pesto', 'rucula']
# ['mozzarella', 'pepperonni', 'tomate', 'salmon', 'rucula', 'aceitunas', 'pesto']
# ['mozzarella', 'pepperonni', 'tomate', 'salmon', 'rucula', 'pesto', 'aceitunas']
# ['mozzarella', 'pepperonni', 'tomate', 'salmon', 'pesto', 'aceitunas', 'rucula']
# ['mozzarella', 'pepperonni', 'tomate', 'salmon', 'pesto', 'rucula', 'aceitunas']
# ['mozzarella', 'pepperonni', 'tomate', 'pesto', 'aceitunas', 'rucula', 'salmon']
# ['mozzarella', 'pepperonni', 'tomate', 'pesto', 'aceitunas', 'salmon', 'rucula']
# ['mozzarella', 'pepperonni', 'tomate', 'pesto', 'rucula', 'aceitunas', 'salmon']
# ['mozzarella', 'pepperonni', 'tomate', 'pesto', 'rucula', 'salmon', 'aceitunas']
# ['mozzarella', 'pepperonni', 'tomate', 'pesto', 'salmon', 'aceitunas', 'rucula']
# ['mozzarella', 'pepperonni', 'tomate', 'pesto', 'salmon', 'rucula', 'aceitunas']
# ['mozzarella', 'pepperonni', 'rucula', 'aceitunas', 'tomate', 'salmon', 'pesto']
# ['mozzarella', 'pepperonni', 'rucula', 'aceitunas', 'tomate', 'pesto', 'salmon']
# ['mozzarella', 'pepperonni', 'rucula', 'aceitunas', 'salmon', 'tomate', 'pesto']
# ['mozzarella', 'pepperonni', 'rucula', 'aceitunas', 'salmon', 'pesto', 'tomate']
# ['mozzarella', 'pepperonni', 'rucula', 'aceitunas', 'pesto', 'tomate', 'salmon']
# ['mozzarella', 'pepperonni', 'rucula', 'aceitunas', 'pesto', 'salmon', 'tomate']
# ['mozzarella', 'pepperonni', 'rucula', 'tomate', 'aceitunas', 'salmon', 'pesto']
# ['mozzarella', 'pepperonni', 'rucula', 'tomate', 'aceitunas', 'pesto', 'salmon']
# ['mozzarella', 'pepperonni', 'rucula', 'tomate', 'salmon', 'aceitunas', 'pesto']
# ['mozzarella', 'pepperonni', 'rucula', 'tomate', 'salmon', 'pesto', 'aceitunas']
# ['mozzarella', 'pepperonni', 'rucula', 'tomate', 'pesto', 'aceitunas', 'salmon']
# ['mozzarella', 'pepperonni', 'rucula', 'tomate', 'pesto', 'salmon', 'aceitunas']
# ['mozzarella', 'pepperonni', 'rucula', 'salmon', 'aceitunas', 'tomate', 'pesto']
# ['mozzarella', 'pepperonni', 'rucula', 'salmon', 'aceitunas', 'pesto', 'tomate']
# ['mozzarella', 'pepperonni', 'rucula', 'salmon', 'tomate', 'aceitunas', 'pesto']
# ['mozzarella', 'pepperonni', 'rucula', 'salmon', 'tomate', 'pesto', 'aceitunas']
# ['mozzarella', 'pepperonni', 'rucula', 'salmon', 'pesto', 'aceitunas', 'tomate']
# ['mozzarella', 'pepperonni', 'rucula', 'salmon', 'pesto', 'tomate', 'aceitunas']
# ['mozzarella', 'pepperonni', 'rucula', 'pesto', 'aceitunas', 'tomate', 'salmon']
# ['mozzarella', 'pepperonni', 'rucula', 'pesto', 'aceitunas', 'salmon', 'tomate']
# ['mozzarella', 'pepperonni', 'rucula', 'pesto', 'tomate', 'aceitunas', 'salmon']
# ['mozzarella', 'pepperonni', 'rucula', 'pesto', 'tomate', 'salmon', 'aceitunas']
# ['mozzarella', 'pepperonni', 'rucula', 'pesto', 'salmon', 'aceitunas', 'tomate']
# ['mozzarella', 'pepperonni', 'rucula', 'pesto', 'salmon', 'tomate', 'aceitunas']
# ['mozzarella', 'pepperonni', 'salmon', 'aceitunas', 'tomate', 'rucula', 'pesto']
# ['mozzarella', 'pepperonni', 'salmon', 'aceitunas', 'tomate', 'pesto', 'rucula']
# ['mozzarella', 'pepperonni', 'salmon', 'aceitunas', 'rucula', 'tomate', 'pesto']
# ['mozzarella', 'pepperonni', 'salmon', 'aceitunas', 'rucula', 'pesto', 'tomate']
# ['mozzarella', 'pepperonni', 'salmon', 'aceitunas', 'pesto', 'tomate', 'rucula']
# ['mozzarella', 'pepperonni', 'salmon', 'aceitunas', 'pesto', 'rucula', 'tomate']
# ['mozzarella', 'pepperonni', 'salmon', 'tomate', 'aceitunas', 'rucula', 'pesto']
# ['mozzarella', 'pepperonni', 'salmon', 'tomate', 'aceitunas', 'pesto', 'rucula']
# ['mozzarella', 'pepperonni', 'salmon', 'tomate', 'rucula', 'aceitunas', 'pesto']
# ['mozzarella', 'pepperonni', 'salmon', 'tomate', 'rucula', 'pesto', 'aceitunas']
# ['mozzarella', 'pepperonni', 'salmon', 'tomate', 'pesto', 'aceitunas', 'rucula']
# ['mozzarella', 'pepperonni', 'salmon', 'tomate', 'pesto', 'rucula', 'aceitunas']
# ['mozzarella', 'pepperonni', 'salmon', 'rucula', 'aceitunas', 'tomate', 'pesto']
# ['mozzarella', 'pepperonni', 'salmon', 'rucula', 'aceitunas', 'pesto', 'tomate']
# ['mozzarella', 'pepperonni', 'salmon', 'rucula', 'tomate', 'aceitunas', 'pesto']
# ['mozzarella', 'pepperonni', 'salmon', 'rucula', 'tomate', 'pesto', 'aceitunas']
# ['mozzarella', 'pepperonni', 'salmon', 'rucula', 'pesto', 'aceitunas', 'tomate']
# ['mozzarella', 'pepperonni', 'salmon', 'rucula', 'pesto', 'tomate', 'aceitunas']
# ['mozzarella', 'pepperonni', 'salmon', 'pesto', 'aceitunas', 'tomate', 'rucula']
# ['mozzarella', 'pepperonni', 'salmon', 'pesto', 'aceitunas', 'rucula', 'tomate']
# ['mozzarella', 'pepperonni', 'salmon', 'pesto', 'tomate', 'aceitunas', 'rucula']
# ['mozzarella', 'pepperonni', 'salmon', 'pesto', 'tomate', 'rucula', 'aceitunas']
# ['mozzarella', 'pepperonni', 'salmon', 'pesto', 'rucula', 'aceitunas', 'tomate']
# ['mozzarella', 'pepperonni', 'salmon', 'pesto', 'rucula', 'tomate', 'aceitunas']
# ['mozzarella', 'pepperonni', 'pesto', 'aceitunas', 'tomate', 'rucula', 'salmon']
# ['mozzarella', 'pepperonni', 'pesto', 'aceitunas', 'tomate', 'salmon', 'rucula']
# ['mozzarella', 'pepperonni', 'pesto', 'aceitunas', 'rucula', 'tomate', 'salmon']
# ['mozzarella', 'pepperonni', 'pesto', 'aceitunas', 'rucula', 'salmon', 'tomate']
# ['mozzarella', 'pepperonni', 'pesto', 'aceitunas', 'salmon', 'tomate', 'rucula']
# ['mozzarella', 'pepperonni', 'pesto', 'aceitunas', 'salmon', 'rucula', 'tomate']
# ['mozzarella', 'pepperonni', 'pesto', 'tomate', 'aceitunas', 'rucula', 'salmon']
# ['mozzarella', 'pepperonni', 'pesto', 'tomate', 'aceitunas', 'salmon', 'rucula']
# ['mozzarella', 'pepperonni', 'pesto', 'tomate', 'rucula', 'aceitunas', 'salmon']
# ['mozzarella', 'pepperonni', 'pesto', 'tomate', 'rucula', 'salmon', 'aceitunas']
# ['mozzarella', 'pepperonni', 'pesto', 'tomate', 'salmon', 'aceitunas', 'rucula']
# ['mozzarella', 'pepperonni', 'pesto', 'tomate', 'salmon', 'rucula', 'aceitunas']
# ['mozzarella', 'pepperonni', 'pesto', 'rucula', 'aceitunas', 'tomate', 'salmon']
# ['mozzarella', 'pepperonni', 'pesto', 'rucula', 'aceitunas', 'salmon', 'tomate']
# ['mozzarella', 'pepperonni', 'pesto', 'rucula', 'tomate', 'aceitunas', 'salmon']
# ['mozzarella', 'pepperonni', 'pesto', 'rucula', 'tomate', 'salmon', 'aceitunas']
# ['mozzarella', 'pepperonni', 'pesto', 'rucula', 'salmon', 'aceitunas', 'tomate']
# ['mozzarella', 'pepperonni', 'pesto', 'rucula', 'salmon', 'tomate', 'aceitunas']
# ['mozzarella', 'pepperonni', 'pesto', 'salmon', 'aceitunas', 'tomate', 'rucula']
# ['mozzarella', 'pepperonni', 'pesto', 'salmon', 'aceitunas', 'rucula', 'tomate']
# ['mozzarella', 'pepperonni', 'pesto', 'salmon', 'tomate', 'aceitunas', 'rucula']
# ['mozzarella', 'pepperonni', 'pesto', 'salmon', 'tomate', 'rucula', 'aceitunas']
# ['mozzarella', 'pepperonni', 'pesto', 'salmon', 'rucula', 'aceitunas', 'tomate']
# ['mozzarella', 'pepperonni', 'pesto', 'salmon', 'rucula', 'tomate', 'aceitunas']
# ['mozzarella', 'rucula', 'aceitunas', 'tomate', 'pepperonni', 'salmon', 'pesto']
# ['mozzarella', 'rucula', 'aceitunas', 'tomate', 'pepperonni', 'pesto', 'salmon']
# ['mozzarella', 'rucula', 'aceitunas', 'tomate', 'salmon', 'pepperonni', 'pesto']
# ['mozzarella', 'rucula', 'aceitunas', 'tomate', 'salmon', 'pesto', 'pepperonni']
# ['mozzarella', 'rucula', 'aceitunas', 'tomate', 'pesto', 'pepperonni', 'salmon']
# ['mozzarella', 'rucula', 'aceitunas', 'tomate', 'pesto', 'salmon', 'pepperonni']
# ['mozzarella', 'rucula', 'aceitunas', 'pepperonni', 'tomate', 'salmon', 'pesto']
# ['mozzarella', 'rucula', 'aceitunas', 'pepperonni', 'tomate', 'pesto', 'salmon']
# ['mozzarella', 'rucula', 'aceitunas', 'pepperonni', 'salmon', 'tomate', 'pesto']
# ['mozzarella', 'rucula', 'aceitunas', 'pepperonni', 'salmon', 'pesto', 'tomate']
# ['mozzarella', 'rucula', 'aceitunas', 'pepperonni', 'pesto', 'tomate', 'salmon']
# ['mozzarella', 'rucula', 'aceitunas', 'pepperonni', 'pesto', 'salmon', 'tomate']
# ['mozzarella', 'rucula', 'aceitunas', 'salmon', 'tomate', 'pepperonni', 'pesto']
# ['mozzarella', 'rucula', 'aceitunas', 'salmon', 'tomate', 'pesto', 'pepperonni']
# ['mozzarella', 'rucula', 'aceitunas', 'salmon', 'pepperonni', 'tomate', 'pesto']
# ['mozzarella', 'rucula', 'aceitunas', 'salmon', 'pepperonni', 'pesto', 'tomate']
# ['mozzarella', 'rucula', 'aceitunas', 'salmon', 'pesto', 'tomate', 'pepperonni']
# ['mozzarella', 'rucula', 'aceitunas', 'salmon', 'pesto', 'pepperonni', 'tomate']
# ['mozzarella', 'rucula', 'aceitunas', 'pesto', 'tomate', 'pepperonni', 'salmon']
# ['mozzarella', 'rucula', 'aceitunas', 'pesto', 'tomate', 'salmon', 'pepperonni']
# ['mozzarella', 'rucula', 'aceitunas', 'pesto', 'pepperonni', 'tomate', 'salmon']
# ['mozzarella', 'rucula', 'aceitunas', 'pesto', 'pepperonni', 'salmon', 'tomate']
# ['mozzarella', 'rucula', 'aceitunas', 'pesto', 'salmon', 'tomate', 'pepperonni']
# ['mozzarella', 'rucula', 'aceitunas', 'pesto', 'salmon', 'pepperonni', 'tomate']
# ['mozzarella', 'rucula', 'tomate', 'aceitunas', 'pepperonni', 'salmon', 'pesto']
# ['mozzarella', 'rucula', 'tomate', 'aceitunas', 'pepperonni', 'pesto', 'salmon']
# ['mozzarella', 'rucula', 'tomate', 'aceitunas', 'salmon', 'pepperonni', 'pesto']
# ['mozzarella', 'rucula', 'tomate', 'aceitunas', 'salmon', 'pesto', 'pepperonni']
# ['mozzarella', 'rucula', 'tomate', 'aceitunas', 'pesto', 'pepperonni', 'salmon']
# ['mozzarella', 'rucula', 'tomate', 'aceitunas', 'pesto', 'salmon', 'pepperonni']
# ['mozzarella', 'rucula', 'tomate', 'pepperonni', 'aceitunas', 'salmon', 'pesto']
# ['mozzarella', 'rucula', 'tomate', 'pepperonni', 'aceitunas', 'pesto', 'salmon']
# ['mozzarella', 'rucula', 'tomate', 'pepperonni', 'salmon', 'aceitunas', 'pesto']
# ['mozzarella', 'rucula', 'tomate', 'pepperonni', 'salmon', 'pesto', 'aceitunas']
# ['mozzarella', 'rucula', 'tomate', 'pepperonni', 'pesto', 'aceitunas', 'salmon']
# ['mozzarella', 'rucula', 'tomate', 'pepperonni', 'pesto', 'salmon', 'aceitunas']
# ['mozzarella', 'rucula', 'tomate', 'salmon', 'aceitunas', 'pepperonni', 'pesto']
# ['mozzarella', 'rucula', 'tomate', 'salmon', 'aceitunas', 'pesto', 'pepperonni']
# ['mozzarella', 'rucula', 'tomate', 'salmon', 'pepperonni', 'aceitunas', 'pesto']
# ['mozzarella', 'rucula', 'tomate', 'salmon', 'pepperonni', 'pesto', 'aceitunas']
# ['mozzarella', 'rucula', 'tomate', 'salmon', 'pesto', 'aceitunas', 'pepperonni']
# ['mozzarella', 'rucula', 'tomate', 'salmon', 'pesto', 'pepperonni', 'aceitunas']
# ['mozzarella', 'rucula', 'tomate', 'pesto', 'aceitunas', 'pepperonni', 'salmon']
# ['mozzarella', 'rucula', 'tomate', 'pesto', 'aceitunas', 'salmon', 'pepperonni']
# ['mozzarella', 'rucula', 'tomate', 'pesto', 'pepperonni', 'aceitunas', 'salmon']
# ['mozzarella', 'rucula', 'tomate', 'pesto', 'pepperonni', 'salmon', 'aceitunas']
# ['mozzarella', 'rucula', 'tomate', 'pesto', 'salmon', 'aceitunas', 'pepperonni']
# ['mozzarella', 'rucula', 'tomate', 'pesto', 'salmon', 'pepperonni', 'aceitunas']
# ['mozzarella', 'rucula', 'pepperonni', 'aceitunas', 'tomate', 'salmon', 'pesto']
# ['mozzarella', 'rucula', 'pepperonni', 'aceitunas', 'tomate', 'pesto', 'salmon']
# ['mozzarella', 'rucula', 'pepperonni', 'aceitunas', 'salmon', 'tomate', 'pesto']
# ['mozzarella', 'rucula', 'pepperonni', 'aceitunas', 'salmon', 'pesto', 'tomate']
# ['mozzarella', 'rucula', 'pepperonni', 'aceitunas', 'pesto', 'tomate', 'salmon']
# ['mozzarella', 'rucula', 'pepperonni', 'aceitunas', 'pesto', 'salmon', 'tomate']
# ['mozzarella', 'rucula', 'pepperonni', 'tomate', 'aceitunas', 'salmon', 'pesto']
# ['mozzarella', 'rucula', 'pepperonni', 'tomate', 'aceitunas', 'pesto', 'salmon']
# ['mozzarella', 'rucula', 'pepperonni', 'tomate', 'salmon', 'aceitunas', 'pesto']
# ['mozzarella', 'rucula', 'pepperonni', 'tomate', 'salmon', 'pesto', 'aceitunas']
# ['mozzarella', 'rucula', 'pepperonni', 'tomate', 'pesto', 'aceitunas', 'salmon']
# ['mozzarella', 'rucula', 'pepperonni', 'tomate', 'pesto', 'salmon', 'aceitunas']
# ['mozzarella', 'rucula', 'pepperonni', 'salmon', 'aceitunas', 'tomate', 'pesto']
# ['mozzarella', 'rucula', 'pepperonni', 'salmon', 'aceitunas', 'pesto', 'tomate']
# ['mozzarella', 'rucula', 'pepperonni', 'salmon', 'tomate', 'aceitunas', 'pesto']
# ['mozzarella', 'rucula', 'pepperonni', 'salmon', 'tomate', 'pesto', 'aceitunas']
# ['mozzarella', 'rucula', 'pepperonni', 'salmon', 'pesto', 'aceitunas', 'tomate']
# ['mozzarella', 'rucula', 'pepperonni', 'salmon', 'pesto', 'tomate', 'aceitunas']
# ['mozzarella', 'rucula', 'pepperonni', 'pesto', 'aceitunas', 'tomate', 'salmon']
# ['mozzarella', 'rucula', 'pepperonni', 'pesto', 'aceitunas', 'salmon', 'tomate']
# ['mozzarella', 'rucula', 'pepperonni', 'pesto', 'tomate', 'aceitunas', 'salmon']
# ['mozzarella', 'rucula', 'pepperonni', 'pesto', 'tomate', 'salmon', 'aceitunas']
# ['mozzarella', 'rucula', 'pepperonni', 'pesto', 'salmon', 'aceitunas', 'tomate']
# ['mozzarella', 'rucula', 'pepperonni', 'pesto', 'salmon', 'tomate', 'aceitunas']
# ['mozzarella', 'rucula', 'salmon', 'aceitunas', 'tomate', 'pepperonni', 'pesto']
# ['mozzarella', 'rucula', 'salmon', 'aceitunas', 'tomate', 'pesto', 'pepperonni']
# ['mozzarella', 'rucula', 'salmon', 'aceitunas', 'pepperonni', 'tomate', 'pesto']
# ['mozzarella', 'rucula', 'salmon', 'aceitunas', 'pepperonni', 'pesto', 'tomate']
# ['mozzarella', 'rucula', 'salmon', 'aceitunas', 'pesto', 'tomate', 'pepperonni']
# ['mozzarella', 'rucula', 'salmon', 'aceitunas', 'pesto', 'pepperonni', 'tomate']
# ['mozzarella', 'rucula', 'salmon', 'tomate', 'aceitunas', 'pepperonni', 'pesto']
# ['mozzarella', 'rucula', 'salmon', 'tomate', 'aceitunas', 'pesto', 'pepperonni']
# ['mozzarella', 'rucula', 'salmon', 'tomate', 'pepperonni', 'aceitunas', 'pesto']
# ['mozzarella', 'rucula', 'salmon', 'tomate', 'pepperonni', 'pesto', 'aceitunas']
# ['mozzarella', 'rucula', 'salmon', 'tomate', 'pesto', 'aceitunas', 'pepperonni']
# ['mozzarella', 'rucula', 'salmon', 'tomate', 'pesto', 'pepperonni', 'aceitunas']
# ['mozzarella', 'rucula', 'salmon', 'pepperonni', 'aceitunas', 'tomate', 'pesto']
# ['mozzarella', 'rucula', 'salmon', 'pepperonni', 'aceitunas', 'pesto', 'tomate']
# ['mozzarella', 'rucula', 'salmon', 'pepperonni', 'tomate', 'aceitunas', 'pesto']
# ['mozzarella', 'rucula', 'salmon', 'pepperonni', 'tomate', 'pesto', 'aceitunas']
# ['mozzarella', 'rucula', 'salmon', 'pepperonni', 'pesto', 'aceitunas', 'tomate']
# ['mozzarella', 'rucula', 'salmon', 'pepperonni', 'pesto', 'tomate', 'aceitunas']
# ['mozzarella', 'rucula', 'salmon', 'pesto', 'aceitunas', 'tomate', 'pepperonni']
# ['mozzarella', 'rucula', 'salmon', 'pesto', 'aceitunas', 'pepperonni', 'tomate']
# ['mozzarella', 'rucula', 'salmon', 'pesto', 'tomate', 'aceitunas', 'pepperonni']
# ['mozzarella', 'rucula', 'salmon', 'pesto', 'tomate', 'pepperonni', 'aceitunas']
# ['mozzarella', 'rucula', 'salmon', 'pesto', 'pepperonni', 'aceitunas', 'tomate']
# ['mozzarella', 'rucula', 'salmon', 'pesto', 'pepperonni', 'tomate', 'aceitunas']
# ['mozzarella', 'rucula', 'pesto', 'aceitunas', 'tomate', 'pepperonni', 'salmon']
# ['mozzarella', 'rucula', 'pesto', 'aceitunas', 'tomate', 'salmon', 'pepperonni']
# ['mozzarella', 'rucula', 'pesto', 'aceitunas', 'pepperonni', 'tomate', 'salmon']
# ['mozzarella', 'rucula', 'pesto', 'aceitunas', 'pepperonni', 'salmon', 'tomate']
# ['mozzarella', 'rucula', 'pesto', 'aceitunas', 'salmon', 'tomate', 'pepperonni']
# ['mozzarella', 'rucula', 'pesto', 'aceitunas', 'salmon', 'pepperonni', 'tomate']
# ['mozzarella', 'rucula', 'pesto', 'tomate', 'aceitunas', 'pepperonni', 'salmon']
# ['mozzarella', 'rucula', 'pesto', 'tomate', 'aceitunas', 'salmon', 'pepperonni']
# ['mozzarella', 'rucula', 'pesto', 'tomate', 'pepperonni', 'aceitunas', 'salmon']
# ['mozzarella', 'rucula', 'pesto', 'tomate', 'pepperonni', 'salmon', 'aceitunas']
# ['mozzarella', 'rucula', 'pesto', 'tomate', 'salmon', 'aceitunas', 'pepperonni']
# ['mozzarella', 'rucula', 'pesto', 'tomate', 'salmon', 'pepperonni', 'aceitunas']
# ['mozzarella', 'rucula', 'pesto', 'pepperonni', 'aceitunas', 'tomate', 'salmon']
# ['mozzarella', 'rucula', 'pesto', 'pepperonni', 'aceitunas', 'salmon', 'tomate']
# ['mozzarella', 'rucula', 'pesto', 'pepperonni', 'tomate', 'aceitunas', 'salmon']
# ['mozzarella', 'rucula', 'pesto', 'pepperonni', 'tomate', 'salmon', 'aceitunas']
# ['mozzarella', 'rucula', 'pesto', 'pepperonni', 'salmon', 'aceitunas', 'tomate']
# ['mozzarella', 'rucula', 'pesto', 'pepperonni', 'salmon', 'tomate', 'aceitunas']
# ['mozzarella', 'rucula', 'pesto', 'salmon', 'aceitunas', 'tomate', 'pepperonni']
# ['mozzarella', 'rucula', 'pesto', 'salmon', 'aceitunas', 'pepperonni', 'tomate']
# ['mozzarella', 'rucula', 'pesto', 'salmon', 'tomate', 'aceitunas', 'pepperonni']
# ['mozzarella', 'rucula', 'pesto', 'salmon', 'tomate', 'pepperonni', 'aceitunas']
# ['mozzarella', 'rucula', 'pesto', 'salmon', 'pepperonni', 'aceitunas', 'tomate']
# ['mozzarella', 'rucula', 'pesto', 'salmon', 'pepperonni', 'tomate', 'aceitunas']
# ['mozzarella', 'salmon', 'aceitunas', 'tomate', 'pepperonni', 'rucula', 'pesto']
# ['mozzarella', 'salmon', 'aceitunas', 'tomate', 'pepperonni', 'pesto', 'rucula']
# ['mozzarella', 'salmon', 'aceitunas', 'tomate', 'rucula', 'pepperonni', 'pesto']
# ['mozzarella', 'salmon', 'aceitunas', 'tomate', 'rucula', 'pesto', 'pepperonni']
# ['mozzarella', 'salmon', 'aceitunas', 'tomate', 'pesto', 'pepperonni', 'rucula']
# ['mozzarella', 'salmon', 'aceitunas', 'tomate', 'pesto', 'rucula', 'pepperonni']
# ['mozzarella', 'salmon', 'aceitunas', 'pepperonni', 'tomate', 'rucula', 'pesto']
# ['mozzarella', 'salmon', 'aceitunas', 'pepperonni', 'tomate', 'pesto', 'rucula']
# ['mozzarella', 'salmon', 'aceitunas', 'pepperonni', 'rucula', 'tomate', 'pesto']
# ['mozzarella', 'salmon', 'aceitunas', 'pepperonni', 'rucula', 'pesto', 'tomate']
# ['mozzarella', 'salmon', 'aceitunas', 'pepperonni', 'pesto', 'tomate', 'rucula']
# ['mozzarella', 'salmon', 'aceitunas', 'pepperonni', 'pesto', 'rucula', 'tomate']
# ['mozzarella', 'salmon', 'aceitunas', 'rucula', 'tomate', 'pepperonni', 'pesto']
# ['mozzarella', 'salmon', 'aceitunas', 'rucula', 'tomate', 'pesto', 'pepperonni']
# ['mozzarella', 'salmon', 'aceitunas', 'rucula', 'pepperonni', 'tomate', 'pesto']
# ['mozzarella', 'salmon', 'aceitunas', 'rucula', 'pepperonni', 'pesto', 'tomate']
# ['mozzarella', 'salmon', 'aceitunas', 'rucula', 'pesto', 'tomate', 'pepperonni']
# ['mozzarella', 'salmon', 'aceitunas', 'rucula', 'pesto', 'pepperonni', 'tomate']
# ['mozzarella', 'salmon', 'aceitunas', 'pesto', 'tomate', 'pepperonni', 'rucula']
# ['mozzarella', 'salmon', 'aceitunas', 'pesto', 'tomate', 'rucula', 'pepperonni']
# ['mozzarella', 'salmon', 'aceitunas', 'pesto', 'pepperonni', 'tomate', 'rucula']
# ['mozzarella', 'salmon', 'aceitunas', 'pesto', 'pepperonni', 'rucula', 'tomate']
# ['mozzarella', 'salmon', 'aceitunas', 'pesto', 'rucula', 'tomate', 'pepperonni']
# ['mozzarella', 'salmon', 'aceitunas', 'pesto', 'rucula', 'pepperonni', 'tomate']
# ['mozzarella', 'salmon', 'tomate', 'aceitunas', 'pepperonni', 'rucula', 'pesto']
# ['mozzarella', 'salmon', 'tomate', 'aceitunas', 'pepperonni', 'pesto', 'rucula']
# ['mozzarella', 'salmon', 'tomate', 'aceitunas', 'rucula', 'pepperonni', 'pesto']
# ['mozzarella', 'salmon', 'tomate', 'aceitunas', 'rucula', 'pesto', 'pepperonni']
# ['mozzarella', 'salmon', 'tomate', 'aceitunas', 'pesto', 'pepperonni', 'rucula']
# ['mozzarella', 'salmon', 'tomate', 'aceitunas', 'pesto', 'rucula', 'pepperonni']
# ['mozzarella', 'salmon', 'tomate', 'pepperonni', 'aceitunas', 'rucula', 'pesto']
# ['mozzarella', 'salmon', 'tomate', 'pepperonni', 'aceitunas', 'pesto', 'rucula']
# ['mozzarella', 'salmon', 'tomate', 'pepperonni', 'rucula', 'aceitunas', 'pesto']
# ['mozzarella', 'salmon', 'tomate', 'pepperonni', 'rucula', 'pesto', 'aceitunas']
# ['mozzarella', 'salmon', 'tomate', 'pepperonni', 'pesto', 'aceitunas', 'rucula']
# ['mozzarella', 'salmon', 'tomate', 'pepperonni', 'pesto', 'rucula', 'aceitunas']
# ['mozzarella', 'salmon', 'tomate', 'rucula', 'aceitunas', 'pepperonni', 'pesto']
# ['mozzarella', 'salmon', 'tomate', 'rucula', 'aceitunas', 'pesto', 'pepperonni']
# ['mozzarella', 'salmon', 'tomate', 'rucula', 'pepperonni', 'aceitunas', 'pesto']
# ['mozzarella', 'salmon', 'tomate', 'rucula', 'pepperonni', 'pesto', 'aceitunas']
# ['mozzarella', 'salmon', 'tomate', 'rucula', 'pesto', 'aceitunas', 'pepperonni']
# ['mozzarella', 'salmon', 'tomate', 'rucula', 'pesto', 'pepperonni', 'aceitunas']
# ['mozzarella', 'salmon', 'tomate', 'pesto', 'aceitunas', 'pepperonni', 'rucula']
# ['mozzarella', 'salmon', 'tomate', 'pesto', 'aceitunas', 'rucula', 'pepperonni']
# ['mozzarella', 'salmon', 'tomate', 'pesto', 'pepperonni', 'aceitunas', 'rucula']
# ['mozzarella', 'salmon', 'tomate', 'pesto', 'pepperonni', 'rucula', 'aceitunas']
# ['mozzarella', 'salmon', 'tomate', 'pesto', 'rucula', 'aceitunas', 'pepperonni']
# ['mozzarella', 'salmon', 'tomate', 'pesto', 'rucula', 'pepperonni', 'aceitunas']
# ['mozzarella', 'salmon', 'pepperonni', 'aceitunas', 'tomate', 'rucula', 'pesto']
# ['mozzarella', 'salmon', 'pepperonni', 'aceitunas', 'tomate', 'pesto', 'rucula']
# ['mozzarella', 'salmon', 'pepperonni', 'aceitunas', 'rucula', 'tomate', 'pesto']
# ['mozzarella', 'salmon', 'pepperonni', 'aceitunas', 'rucula', 'pesto', 'tomate']
# ['mozzarella', 'salmon', 'pepperonni', 'aceitunas', 'pesto', 'tomate', 'rucula']
# ['mozzarella', 'salmon', 'pepperonni', 'aceitunas', 'pesto', 'rucula', 'tomate']
# ['mozzarella', 'salmon', 'pepperonni', 'tomate', 'aceitunas', 'rucula', 'pesto']
# ['mozzarella', 'salmon', 'pepperonni', 'tomate', 'aceitunas', 'pesto', 'rucula']
# ['mozzarella', 'salmon', 'pepperonni', 'tomate', 'rucula', 'aceitunas', 'pesto']
# ['mozzarella', 'salmon', 'pepperonni', 'tomate', 'rucula', 'pesto', 'aceitunas']
# ['mozzarella', 'salmon', 'pepperonni', 'tomate', 'pesto', 'aceitunas', 'rucula']
# ['mozzarella', 'salmon', 'pepperonni', 'tomate', 'pesto', 'rucula', 'aceitunas']
# ['mozzarella', 'salmon', 'pepperonni', 'rucula', 'aceitunas', 'tomate', 'pesto']
# ['mozzarella', 'salmon', 'pepperonni', 'rucula', 'aceitunas', 'pesto', 'tomate']
# ['mozzarella', 'salmon', 'pepperonni', 'rucula', 'tomate', 'aceitunas', 'pesto']
# ['mozzarella', 'salmon', 'pepperonni', 'rucula', 'tomate', 'pesto', 'aceitunas']
# ['mozzarella', 'salmon', 'pepperonni', 'rucula', 'pesto', 'aceitunas', 'tomate']
# ['mozzarella', 'salmon', 'pepperonni', 'rucula', 'pesto', 'tomate', 'aceitunas']
# ['mozzarella', 'salmon', 'pepperonni', 'pesto', 'aceitunas', 'tomate', 'rucula']
# ['mozzarella', 'salmon', 'pepperonni', 'pesto', 'aceitunas', 'rucula', 'tomate']
# ['mozzarella', 'salmon', 'pepperonni', 'pesto', 'tomate', 'aceitunas', 'rucula']
# ['mozzarella', 'salmon', 'pepperonni', 'pesto', 'tomate', 'rucula', 'aceitunas']
# ['mozzarella', 'salmon', 'pepperonni', 'pesto', 'rucula', 'aceitunas', 'tomate']
# ['mozzarella', 'salmon', 'pepperonni', 'pesto', 'rucula', 'tomate', 'aceitunas']
# ['mozzarella', 'salmon', 'rucula', 'aceitunas', 'tomate', 'pepperonni', 'pesto']
# ['mozzarella', 'salmon', 'rucula', 'aceitunas', 'tomate', 'pesto', 'pepperonni']
# ['mozzarella', 'salmon', 'rucula', 'aceitunas', 'pepperonni', 'tomate', 'pesto']
# ['mozzarella', 'salmon', 'rucula', 'aceitunas', 'pepperonni', 'pesto', 'tomate']
# ['mozzarella', 'salmon', 'rucula', 'aceitunas', 'pesto', 'tomate', 'pepperonni']
# ['mozzarella', 'salmon', 'rucula', 'aceitunas', 'pesto', 'pepperonni', 'tomate']
# ['mozzarella', 'salmon', 'rucula', 'tomate', 'aceitunas', 'pepperonni', 'pesto']
# ['mozzarella', 'salmon', 'rucula', 'tomate', 'aceitunas', 'pesto', 'pepperonni']
# ['mozzarella', 'salmon', 'rucula', 'tomate', 'pepperonni', 'aceitunas', 'pesto']
# ['mozzarella', 'salmon', 'rucula', 'tomate', 'pepperonni', 'pesto', 'aceitunas']
# ['mozzarella', 'salmon', 'rucula', 'tomate', 'pesto', 'aceitunas', 'pepperonni']
# ['mozzarella', 'salmon', 'rucula', 'tomate', 'pesto', 'pepperonni', 'aceitunas']
# ['mozzarella', 'salmon', 'rucula', 'pepperonni', 'aceitunas', 'tomate', 'pesto']
# ['mozzarella', 'salmon', 'rucula', 'pepperonni', 'aceitunas', 'pesto', 'tomate']
# ['mozzarella', 'salmon', 'rucula', 'pepperonni', 'tomate', 'aceitunas', 'pesto']
# ['mozzarella', 'salmon', 'rucula', 'pepperonni', 'tomate', 'pesto', 'aceitunas']
# ['mozzarella', 'salmon', 'rucula', 'pepperonni', 'pesto', 'aceitunas', 'tomate']
# ['mozzarella', 'salmon', 'rucula', 'pepperonni', 'pesto', 'tomate', 'aceitunas']
# ['mozzarella', 'salmon', 'rucula', 'pesto', 'aceitunas', 'tomate', 'pepperonni']
# ['mozzarella', 'salmon', 'rucula', 'pesto', 'aceitunas', 'pepperonni', 'tomate']
# ['mozzarella', 'salmon', 'rucula', 'pesto', 'tomate', 'aceitunas', 'pepperonni']
# ['mozzarella', 'salmon', 'rucula', 'pesto', 'tomate', 'pepperonni', 'aceitunas']
# ['mozzarella', 'salmon', 'rucula', 'pesto', 'pepperonni', 'aceitunas', 'tomate']
# ['mozzarella', 'salmon', 'rucula', 'pesto', 'pepperonni', 'tomate', 'aceitunas']
# ['mozzarella', 'salmon', 'pesto', 'aceitunas', 'tomate', 'pepperonni', 'rucula']
# ['mozzarella', 'salmon', 'pesto', 'aceitunas', 'tomate', 'rucula', 'pepperonni']
# ['mozzarella', 'salmon', 'pesto', 'aceitunas', 'pepperonni', 'tomate', 'rucula']
# ['mozzarella', 'salmon', 'pesto', 'aceitunas', 'pepperonni', 'rucula', 'tomate']
# ['mozzarella', 'salmon', 'pesto', 'aceitunas', 'rucula', 'tomate', 'pepperonni']
# ['mozzarella', 'salmon', 'pesto', 'aceitunas', 'rucula', 'pepperonni', 'tomate']
# ['mozzarella', 'salmon', 'pesto', 'tomate', 'aceitunas', 'pepperonni', 'rucula']
# ['mozzarella', 'salmon', 'pesto', 'tomate', 'aceitunas', 'rucula', 'pepperonni']
# ['mozzarella', 'salmon', 'pesto', 'tomate', 'pepperonni', 'aceitunas', 'rucula']
# ['mozzarella', 'salmon', 'pesto', 'tomate', 'pepperonni', 'rucula', 'aceitunas']
# ['mozzarella', 'salmon', 'pesto', 'tomate', 'rucula', 'aceitunas', 'pepperonni']
# ['mozzarella', 'salmon', 'pesto', 'tomate', 'rucula', 'pepperonni', 'aceitunas']
# ['mozzarella', 'salmon', 'pesto', 'pepperonni', 'aceitunas', 'tomate', 'rucula']
# ['mozzarella', 'salmon', 'pesto', 'pepperonni', 'aceitunas', 'rucula', 'tomate']
# ['mozzarella', 'salmon', 'pesto', 'pepperonni', 'tomate', 'aceitunas', 'rucula']
# ['mozzarella', 'salmon', 'pesto', 'pepperonni', 'tomate', 'rucula', 'aceitunas']
# ...
# ['pesto', 'rucula', 'aceitunas', 'salmon', 'tomate', 'mozzarella', 'pepperonni']
# ['pesto', 'rucula', 'aceitunas', 'salmon', 'tomate', 'pepperonni', 'mozzarella']
# ['pesto', 'rucula', 'aceitunas', 'salmon', 'pepperonni', 'mozzarella', 'tomate']
# ['pesto', 'rucula', 'aceitunas', 'salmon', 'pepperonni', 'tomate', 'mozzarella']
# ['pesto', 'rucula', 'tomate', 'mozzarella', 'aceitunas', 'pepperonni', 'salmon']
# ['pesto', 'rucula', 'tomate', 'mozzarella', 'aceitunas', 'salmon', 'pepperonni']
# ['pesto', 'rucula', 'tomate', 'mozzarella', 'pepperonni', 'aceitunas', 'salmon']
# ['pesto', 'rucula', 'tomate', 'mozzarella', 'pepperonni', 'salmon', 'aceitunas']
# ['pesto', 'rucula', 'tomate', 'mozzarella', 'salmon', 'aceitunas', 'pepperonni']
# ['pesto', 'rucula', 'tomate', 'mozzarella', 'salmon', 'pepperonni', 'aceitunas']
# ['pesto', 'rucula', 'tomate', 'aceitunas', 'mozzarella', 'pepperonni', 'salmon']
# ['pesto', 'rucula', 'tomate', 'aceitunas', 'mozzarella', 'salmon', 'pepperonni']
# ['pesto', 'rucula', 'tomate', 'aceitunas', 'pepperonni', 'mozzarella', 'salmon']
# ['pesto', 'rucula', 'tomate', 'aceitunas', 'pepperonni', 'salmon', 'mozzarella']
# ['pesto', 'rucula', 'tomate', 'aceitunas', 'salmon', 'mozzarella', 'pepperonni']
# ['pesto', 'rucula', 'tomate', 'aceitunas', 'salmon', 'pepperonni', 'mozzarella']
# ['pesto', 'rucula', 'tomate', 'pepperonni', 'mozzarella', 'aceitunas', 'salmon']
# ['pesto', 'rucula', 'tomate', 'pepperonni', 'mozzarella', 'salmon', 'aceitunas']
# ['pesto', 'rucula', 'tomate', 'pepperonni', 'aceitunas', 'mozzarella', 'salmon']
# ['pesto', 'rucula', 'tomate', 'pepperonni', 'aceitunas', 'salmon', 'mozzarella']
# ['pesto', 'rucula', 'tomate', 'pepperonni', 'salmon', 'mozzarella', 'aceitunas']
# ['pesto', 'rucula', 'tomate', 'pepperonni', 'salmon', 'aceitunas', 'mozzarella']
# ['pesto', 'rucula', 'tomate', 'salmon', 'mozzarella', 'aceitunas', 'pepperonni']
# ['pesto', 'rucula', 'tomate', 'salmon', 'mozzarella', 'pepperonni', 'aceitunas']
# ['pesto', 'rucula', 'tomate', 'salmon', 'aceitunas', 'mozzarella', 'pepperonni']
# ['pesto', 'rucula', 'tomate', 'salmon', 'aceitunas', 'pepperonni', 'mozzarella']
# ['pesto', 'rucula', 'tomate', 'salmon', 'pepperonni', 'mozzarella', 'aceitunas']
# ['pesto', 'rucula', 'tomate', 'salmon', 'pepperonni', 'aceitunas', 'mozzarella']
# ['pesto', 'rucula', 'pepperonni', 'mozzarella', 'aceitunas', 'tomate', 'salmon']
# ['pesto', 'rucula', 'pepperonni', 'mozzarella', 'aceitunas', 'salmon', 'tomate']
# ['pesto', 'rucula', 'pepperonni', 'mozzarella', 'tomate', 'aceitunas', 'salmon']
# ['pesto', 'rucula', 'pepperonni', 'mozzarella', 'tomate', 'salmon', 'aceitunas']
# ['pesto', 'rucula', 'pepperonni', 'mozzarella', 'salmon', 'aceitunas', 'tomate']
# ['pesto', 'rucula', 'pepperonni', 'mozzarella', 'salmon', 'tomate', 'aceitunas']
# ['pesto', 'rucula', 'pepperonni', 'aceitunas', 'mozzarella', 'tomate', 'salmon']
# ['pesto', 'rucula', 'pepperonni', 'aceitunas', 'mozzarella', 'salmon', 'tomate']
# ['pesto', 'rucula', 'pepperonni', 'aceitunas', 'tomate', 'mozzarella', 'salmon']
# ['pesto', 'rucula', 'pepperonni', 'aceitunas', 'tomate', 'salmon', 'mozzarella']
# ['pesto', 'rucula', 'pepperonni', 'aceitunas', 'salmon', 'mozzarella', 'tomate']
# ['pesto', 'rucula', 'pepperonni', 'aceitunas', 'salmon', 'tomate', 'mozzarella']
# ['pesto', 'rucula', 'pepperonni', 'tomate', 'mozzarella', 'aceitunas', 'salmon']
# ['pesto', 'rucula', 'pepperonni', 'tomate', 'mozzarella', 'salmon', 'aceitunas']
# ['pesto', 'rucula', 'pepperonni', 'tomate', 'aceitunas', 'mozzarella', 'salmon']
# ['pesto', 'rucula', 'pepperonni', 'tomate', 'aceitunas', 'salmon', 'mozzarella']
# ['pesto', 'rucula', 'pepperonni', 'tomate', 'salmon', 'mozzarella', 'aceitunas']
# ['pesto', 'rucula', 'pepperonni', 'tomate', 'salmon', 'aceitunas', 'mozzarella']
# ['pesto', 'rucula', 'pepperonni', 'salmon', 'mozzarella', 'aceitunas', 'tomate']
# ['pesto', 'rucula', 'pepperonni', 'salmon', 'mozzarella', 'tomate', 'aceitunas']
# ['pesto', 'rucula', 'pepperonni', 'salmon', 'aceitunas', 'mozzarella', 'tomate']
# ['pesto', 'rucula', 'pepperonni', 'salmon', 'aceitunas', 'tomate', 'mozzarella']
# ['pesto', 'rucula', 'pepperonni', 'salmon', 'tomate', 'mozzarella', 'aceitunas']
# ['pesto', 'rucula', 'pepperonni', 'salmon', 'tomate', 'aceitunas', 'mozzarella']
# ['pesto', 'rucula', 'salmon', 'mozzarella', 'aceitunas', 'tomate', 'pepperonni']
# ['pesto', 'rucula', 'salmon', 'mozzarella', 'aceitunas', 'pepperonni', 'tomate']
# ['pesto', 'rucula', 'salmon', 'mozzarella', 'tomate', 'aceitunas', 'pepperonni']
# ['pesto', 'rucula', 'salmon', 'mozzarella', 'tomate', 'pepperonni', 'aceitunas']
# ['pesto', 'rucula', 'salmon', 'mozzarella', 'pepperonni', 'aceitunas', 'tomate']
# ['pesto', 'rucula', 'salmon', 'mozzarella', 'pepperonni', 'tomate', 'aceitunas']
# ['pesto', 'rucula', 'salmon', 'aceitunas', 'mozzarella', 'tomate', 'pepperonni']
# ['pesto', 'rucula', 'salmon', 'aceitunas', 'mozzarella', 'pepperonni', 'tomate']
# ['pesto', 'rucula', 'salmon', 'aceitunas', 'tomate', 'mozzarella', 'pepperonni']
# ['pesto', 'rucula', 'salmon', 'aceitunas', 'tomate', 'pepperonni', 'mozzarella']
# ['pesto', 'rucula', 'salmon', 'aceitunas', 'pepperonni', 'mozzarella', 'tomate']
# ['pesto', 'rucula', 'salmon', 'aceitunas', 'pepperonni', 'tomate', 'mozzarella']
# ['pesto', 'rucula', 'salmon', 'tomate', 'mozzarella', 'aceitunas', 'pepperonni']
# ['pesto', 'rucula', 'salmon', 'tomate', 'mozzarella', 'pepperonni', 'aceitunas']
# ['pesto', 'rucula', 'salmon', 'tomate', 'aceitunas', 'mozzarella', 'pepperonni']
# ['pesto', 'rucula', 'salmon', 'tomate', 'aceitunas', 'pepperonni', 'mozzarella']
# ['pesto', 'rucula', 'salmon', 'tomate', 'pepperonni', 'mozzarella', 'aceitunas']
# ['pesto', 'rucula', 'salmon', 'tomate', 'pepperonni', 'aceitunas', 'mozzarella']
# ['pesto', 'rucula', 'salmon', 'pepperonni', 'mozzarella', 'aceitunas', 'tomate']
# ['pesto', 'rucula', 'salmon', 'pepperonni', 'mozzarella', 'tomate', 'aceitunas']
# ['pesto', 'rucula', 'salmon', 'pepperonni', 'aceitunas', 'mozzarella', 'tomate']
# ['pesto', 'rucula', 'salmon', 'pepperonni', 'aceitunas', 'tomate', 'mozzarella']
# ['pesto', 'rucula', 'salmon', 'pepperonni', 'tomate', 'mozzarella', 'aceitunas']
# ['pesto', 'rucula', 'salmon', 'pepperonni', 'tomate', 'aceitunas', 'mozzarella']
# ['pesto', 'salmon', 'mozzarella', 'aceitunas', 'tomate', 'pepperonni', 'rucula']
# ['pesto', 'salmon', 'mozzarella', 'aceitunas', 'tomate', 'rucula', 'pepperonni']
# ['pesto', 'salmon', 'mozzarella', 'aceitunas', 'pepperonni', 'tomate', 'rucula']
# ['pesto', 'salmon', 'mozzarella', 'aceitunas', 'pepperonni', 'rucula', 'tomate']
# ['pesto', 'salmon', 'mozzarella', 'aceitunas', 'rucula', 'tomate', 'pepperonni']
# ['pesto', 'salmon', 'mozzarella', 'aceitunas', 'rucula', 'pepperonni', 'tomate']
# ['pesto', 'salmon', 'mozzarella', 'tomate', 'aceitunas', 'pepperonni', 'rucula']
# ['pesto', 'salmon', 'mozzarella', 'tomate', 'aceitunas', 'rucula', 'pepperonni']
# ['pesto', 'salmon', 'mozzarella', 'tomate', 'pepperonni', 'aceitunas', 'rucula']
# ['pesto', 'salmon', 'mozzarella', 'tomate', 'pepperonni', 'rucula', 'aceitunas']
# ['pesto', 'salmon', 'mozzarella', 'tomate', 'rucula', 'aceitunas', 'pepperonni']
# ['pesto', 'salmon', 'mozzarella', 'tomate', 'rucula', 'pepperonni', 'aceitunas']
# ['pesto', 'salmon', 'mozzarella', 'pepperonni', 'aceitunas', 'tomate', 'rucula']
# ['pesto', 'salmon', 'mozzarella', 'pepperonni', 'aceitunas', 'rucula', 'tomate']
# ['pesto', 'salmon', 'mozzarella', 'pepperonni', 'tomate', 'aceitunas', 'rucula']
# ['pesto', 'salmon', 'mozzarella', 'pepperonni', 'tomate', 'rucula', 'aceitunas']
# ['pesto', 'salmon', 'mozzarella', 'pepperonni', 'rucula', 'aceitunas', 'tomate']
# ['pesto', 'salmon', 'mozzarella', 'pepperonni', 'rucula', 'tomate', 'aceitunas']
# ['pesto', 'salmon', 'mozzarella', 'rucula', 'aceitunas', 'tomate', 'pepperonni']
# ['pesto', 'salmon', 'mozzarella', 'rucula', 'aceitunas', 'pepperonni', 'tomate']
# ['pesto', 'salmon', 'mozzarella', 'rucula', 'tomate', 'aceitunas', 'pepperonni']
# ['pesto', 'salmon', 'mozzarella', 'rucula', 'tomate', 'pepperonni', 'aceitunas']
# ['pesto', 'salmon', 'mozzarella', 'rucula', 'pepperonni', 'aceitunas', 'tomate']
# ['pesto', 'salmon', 'mozzarella', 'rucula', 'pepperonni', 'tomate', 'aceitunas']
# ['pesto', 'salmon', 'aceitunas', 'mozzarella', 'tomate', 'pepperonni', 'rucula']
# ['pesto', 'salmon', 'aceitunas', 'mozzarella', 'tomate', 'rucula', 'pepperonni']
# ['pesto', 'salmon', 'aceitunas', 'mozzarella', 'pepperonni', 'tomate', 'rucula']
# ['pesto', 'salmon', 'aceitunas', 'mozzarella', 'pepperonni', 'rucula', 'tomate']
# ['pesto', 'salmon', 'aceitunas', 'mozzarella', 'rucula', 'tomate', 'pepperonni']
# ['pesto', 'salmon', 'aceitunas', 'mozzarella', 'rucula', 'pepperonni', 'tomate']
# ['pesto', 'salmon', 'aceitunas', 'tomate', 'mozzarella', 'pepperonni', 'rucula']
# ['pesto', 'salmon', 'aceitunas', 'tomate', 'mozzarella', 'rucula', 'pepperonni']
# ['pesto', 'salmon', 'aceitunas', 'tomate', 'pepperonni', 'mozzarella', 'rucula']
# ['pesto', 'salmon', 'aceitunas', 'tomate', 'pepperonni', 'rucula', 'mozzarella']
# ['pesto', 'salmon', 'aceitunas', 'tomate', 'rucula', 'mozzarella', 'pepperonni']
# ['pesto', 'salmon', 'aceitunas', 'tomate', 'rucula', 'pepperonni', 'mozzarella']
# ['pesto', 'salmon', 'aceitunas', 'pepperonni', 'mozzarella', 'tomate', 'rucula']
# ['pesto', 'salmon', 'aceitunas', 'pepperonni', 'mozzarella', 'rucula', 'tomate']
# ['pesto', 'salmon', 'aceitunas', 'pepperonni', 'tomate', 'mozzarella', 'rucula']
# ['pesto', 'salmon', 'aceitunas', 'pepperonni', 'tomate', 'rucula', 'mozzarella']
# ['pesto', 'salmon', 'aceitunas', 'pepperonni', 'rucula', 'mozzarella', 'tomate']
# ['pesto', 'salmon', 'aceitunas', 'pepperonni', 'rucula', 'tomate', 'mozzarella']
# ['pesto', 'salmon', 'aceitunas', 'rucula', 'mozzarella', 'tomate', 'pepperonni']
# ['pesto', 'salmon', 'aceitunas', 'rucula', 'mozzarella', 'pepperonni', 'tomate']
# ['pesto', 'salmon', 'aceitunas', 'rucula', 'tomate', 'mozzarella', 'pepperonni']
# ['pesto', 'salmon', 'aceitunas', 'rucula', 'tomate', 'pepperonni', 'mozzarella']
# ['pesto', 'salmon', 'aceitunas', 'rucula', 'pepperonni', 'mozzarella', 'tomate']
# ['pesto', 'salmon', 'aceitunas', 'rucula', 'pepperonni', 'tomate', 'mozzarella']
# ['pesto', 'salmon', 'tomate', 'mozzarella', 'aceitunas', 'pepperonni', 'rucula']
# ['pesto', 'salmon', 'tomate', 'mozzarella', 'aceitunas', 'rucula', 'pepperonni']
# ['pesto', 'salmon', 'tomate', 'mozzarella', 'pepperonni', 'aceitunas', 'rucula']
# ['pesto', 'salmon', 'tomate', 'mozzarella', 'pepperonni', 'rucula', 'aceitunas']
# ['pesto', 'salmon', 'tomate', 'mozzarella', 'rucula', 'aceitunas', 'pepperonni']
# ['pesto', 'salmon', 'tomate', 'mozzarella', 'rucula', 'pepperonni', 'aceitunas']
# ['pesto', 'salmon', 'tomate', 'aceitunas', 'mozzarella', 'pepperonni', 'rucula']
# ['pesto', 'salmon', 'tomate', 'aceitunas', 'mozzarella', 'rucula', 'pepperonni']
# ['pesto', 'salmon', 'tomate', 'aceitunas', 'pepperonni', 'mozzarella', 'rucula']
# ['pesto', 'salmon', 'tomate', 'aceitunas', 'pepperonni', 'rucula', 'mozzarella']
# ['pesto', 'salmon', 'tomate', 'aceitunas', 'rucula', 'mozzarella', 'pepperonni']
# ['pesto', 'salmon', 'tomate', 'aceitunas', 'rucula', 'pepperonni', 'mozzarella']
# ['pesto', 'salmon', 'tomate', 'pepperonni', 'mozzarella', 'aceitunas', 'rucula']
# ['pesto', 'salmon', 'tomate', 'pepperonni', 'mozzarella', 'rucula', 'aceitunas']
# ['pesto', 'salmon', 'tomate', 'pepperonni', 'aceitunas', 'mozzarella', 'rucula']
# ['pesto', 'salmon', 'tomate', 'pepperonni', 'aceitunas', 'rucula', 'mozzarella']
# ['pesto', 'salmon', 'tomate', 'pepperonni', 'rucula', 'mozzarella', 'aceitunas']
# ['pesto', 'salmon', 'tomate', 'pepperonni', 'rucula', 'aceitunas', 'mozzarella']
# ['pesto', 'salmon', 'tomate', 'rucula', 'mozzarella', 'aceitunas', 'pepperonni']
# ['pesto', 'salmon', 'tomate', 'rucula', 'mozzarella', 'pepperonni', 'aceitunas']
# ['pesto', 'salmon', 'tomate', 'rucula', 'aceitunas', 'mozzarella', 'pepperonni']
# ['pesto', 'salmon', 'tomate', 'rucula', 'aceitunas', 'pepperonni', 'mozzarella']
# ['pesto', 'salmon', 'tomate', 'rucula', 'pepperonni', 'mozzarella', 'aceitunas']
# ['pesto', 'salmon', 'tomate', 'rucula', 'pepperonni', 'aceitunas', 'mozzarella']
# ['pesto', 'salmon', 'pepperonni', 'mozzarella', 'aceitunas', 'tomate', 'rucula']
# ['pesto', 'salmon', 'pepperonni', 'mozzarella', 'aceitunas', 'rucula', 'tomate']
# ['pesto', 'salmon', 'pepperonni', 'mozzarella', 'tomate', 'aceitunas', 'rucula']
# ['pesto', 'salmon', 'pepperonni', 'mozzarella', 'tomate', 'rucula', 'aceitunas']
# ['pesto', 'salmon', 'pepperonni', 'mozzarella', 'rucula', 'aceitunas', 'tomate']
# ['pesto', 'salmon', 'pepperonni', 'mozzarella', 'rucula', 'tomate', 'aceitunas']
# ['pesto', 'salmon', 'pepperonni', 'aceitunas', 'mozzarella', 'tomate', 'rucula']
# ['pesto', 'salmon', 'pepperonni', 'aceitunas', 'mozzarella', 'rucula', 'tomate']
# ['pesto', 'salmon', 'pepperonni', 'aceitunas', 'tomate', 'mozzarella', 'rucula']
# ['pesto', 'salmon', 'pepperonni', 'aceitunas', 'tomate', 'rucula', 'mozzarella']
# ['pesto', 'salmon', 'pepperonni', 'aceitunas', 'rucula', 'mozzarella', 'tomate']
# ['pesto', 'salmon', 'pepperonni', 'aceitunas', 'rucula', 'tomate', 'mozzarella']
# ['pesto', 'salmon', 'pepperonni', 'tomate', 'mozzarella', 'aceitunas', 'rucula']
# ['pesto', 'salmon', 'pepperonni', 'tomate', 'mozzarella', 'rucula', 'aceitunas']
# ['pesto', 'salmon', 'pepperonni', 'tomate', 'aceitunas', 'mozzarella', 'rucula']
# ['pesto', 'salmon', 'pepperonni', 'tomate', 'aceitunas', 'rucula', 'mozzarella']
# ['pesto', 'salmon', 'pepperonni', 'tomate', 'rucula', 'mozzarella', 'aceitunas']
# ['pesto', 'salmon', 'pepperonni', 'tomate', 'rucula', 'aceitunas', 'mozzarella']
# ['pesto', 'salmon', 'pepperonni', 'rucula', 'mozzarella', 'aceitunas', 'tomate']
# ['pesto', 'salmon', 'pepperonni', 'rucula', 'mozzarella', 'tomate', 'aceitunas']
# ['pesto', 'salmon', 'pepperonni', 'rucula', 'aceitunas', 'mozzarella', 'tomate']
# ['pesto', 'salmon', 'pepperonni', 'rucula', 'aceitunas', 'tomate', 'mozzarella']
# ['pesto', 'salmon', 'pepperonni', 'rucula', 'tomate', 'mozzarella', 'aceitunas']
# ['pesto', 'salmon', 'pepperonni', 'rucula', 'tomate', 'aceitunas', 'mozzarella']
# ['pesto', 'salmon', 'rucula', 'mozzarella', 'aceitunas', 'tomate', 'pepperonni']
# ['pesto', 'salmon', 'rucula', 'mozzarella', 'aceitunas', 'pepperonni', 'tomate']
# ['pesto', 'salmon', 'rucula', 'mozzarella', 'tomate', 'aceitunas', 'pepperonni']
# ['pesto', 'salmon', 'rucula', 'mozzarella', 'tomate', 'pepperonni', 'aceitunas']
# ['pesto', 'salmon', 'rucula', 'mozzarella', 'pepperonni', 'aceitunas', 'tomate']
# ['pesto', 'salmon', 'rucula', 'mozzarella', 'pepperonni', 'tomate', 'aceitunas']
# ['pesto', 'salmon', 'rucula', 'aceitunas', 'mozzarella', 'tomate', 'pepperonni']
# ['pesto', 'salmon', 'rucula', 'aceitunas', 'mozzarella', 'pepperonni', 'tomate']
# ['pesto', 'salmon', 'rucula', 'aceitunas', 'tomate', 'mozzarella', 'pepperonni']
# ['pesto', 'salmon', 'rucula', 'aceitunas', 'tomate', 'pepperonni', 'mozzarella']
# ['pesto', 'salmon', 'rucula', 'aceitunas', 'pepperonni', 'mozzarella', 'tomate']
# ['pesto', 'salmon', 'rucula', 'aceitunas', 'pepperonni', 'tomate', 'mozzarella']
# ['pesto', 'salmon', 'rucula', 'tomate', 'mozzarella', 'aceitunas', 'pepperonni']
# ['pesto', 'salmon', 'rucula', 'tomate', 'mozzarella', 'pepperonni', 'aceitunas']
# ['pesto', 'salmon', 'rucula', 'tomate', 'aceitunas', 'mozzarella', 'pepperonni']
# ['pesto', 'salmon', 'rucula', 'tomate', 'aceitunas', 'pepperonni', 'mozzarella']
# ['pesto', 'salmon', 'rucula', 'tomate', 'pepperonni', 'mozzarella', 'aceitunas']
# ['pesto', 'salmon', 'rucula', 'tomate', 'pepperonni', 'aceitunas', 'mozzarella']
# ['pesto', 'salmon', 'rucula', 'pepperonni', 'mozzarella', 'aceitunas', 'tomate']
# ['pesto', 'salmon', 'rucula', 'pepperonni', 'mozzarella', 'tomate', 'aceitunas']
# ['pesto', 'salmon', 'rucula', 'pepperonni', 'aceitunas', 'mozzarella', 'tomate']
# ['pesto', 'salmon', 'rucula', 'pepperonni', 'aceitunas', 'tomate', 'mozzarella']
# ['pesto', 'salmon', 'rucula', 'pepperonni', 'tomate', 'mozzarella', 'aceitunas']
# ['pesto', 'salmon', 'rucula', 'pepperonni', 'tomate', 'aceitunas', 'mozzarella']
#
# permutaciones coincide con num. factorial de elementos, 5040

# %% [markdown]
# <a id='combinaciones'></a>
# ## Actividad 2: Combinaciones
#
# Era una solemne tontería repetir ingredientes en una pizza o ponerlos todos en sus distintas permutaciones. Ahora vamos a intentar obtener combinaciones (tomar elementos sin repetir) de todos los ingredientes tomados de N en N.
#
# La forma sencilla de evitar repeticiones es que los elementos salgan **ordenados**. Dicho de otra manera, cada vez que ramifiques tomar uno de los que estén a la derecha del último elemento añadido en la solución.
#
# Para facilitar las cosas, añadiremos a `backtracking` un argumento más que es `desde` y que nos dice desde qué posición de la lista de elementos debemos ramificar:

# %%
def combinaciones(elementos, cantidad):
    def backtracking(sol, desde):
        if len(sol) == cantidad:
            yield sol.copy()
        else:
            for i in range(desde, len(elementos)):
                sol.append(elementos[i])
                yield from backtracking(sol, i + 1)
                sol.pop()

    yield from backtracking([],0) # desde 0

# %% [markdown]
# El resultado de ejecutar:
#
# ```python
# ingredientes = ['mozzarella','pepperoni','champiñón','aceitunas','anchoa','tomate']
# print("Vamos a probar con 3 ingredientes DIFERENTES:")
# for pizza in combinaciones(ingredientes,3):
#     print("-",", ".join(pizza))
# ```
#
# debe ser:
#
# ```
# Vamos a probar con 3 ingredientes DIFERENTES:
# - mozzarella, pepperoni, champiñón
# - mozzarella, pepperoni, aceitunas
# - mozzarella, pepperoni, anchoa
# - mozzarella, pepperoni, tomate
# - mozzarella, champiñón, aceitunas
# - mozzarella, champiñón, anchoa
# - mozzarella, champiñón, tomate
# - mozzarella, aceitunas, anchoa
# - mozzarella, aceitunas, tomate
# - mozzarella, anchoa, tomate
# - pepperoni, champiñón, aceitunas
# - pepperoni, champiñón, anchoa
# - pepperoni, champiñón, tomate
# - pepperoni, aceitunas, anchoa
# - pepperoni, aceitunas, tomate
# - pepperoni, anchoa, tomate
# - champiñón, aceitunas, anchoa
# - champiñón, aceitunas, tomate
# - champiñón, anchoa, tomate
# - aceitunas, anchoa, tomate
# ```

# %%
ingredientes = ['mozzarella','pepperoni','champiñón','aceitunas','anchoa','tomate']
print("Vamos a probar con 3 ingredientes DIFERENTES:")
for pizza in combinaciones(ingredientes,3):
    print("-",", ".join(map(str, pizza)))
# Out:
# Vamos a probar con 3 ingredientes DIFERENTES:
# - mozzarella, pepperoni, champiñón
# - mozzarella, pepperoni, aceitunas
# - mozzarella, pepperoni, anchoa
# - mozzarella, pepperoni, tomate
# - mozzarella, champiñón, aceitunas
# - mozzarella, champiñón, anchoa
# - mozzarella, champiñón, tomate
# - mozzarella, aceitunas, anchoa
# - mozzarella, aceitunas, tomate
# - mozzarella, anchoa, tomate
# - pepperoni, champiñón, aceitunas
# - pepperoni, champiñón, anchoa
# - pepperoni, champiñón, tomate
# - pepperoni, aceitunas, anchoa
# - pepperoni, aceitunas, tomate
# - pepperoni, anchoa, tomate
# - champiñón, aceitunas, anchoa
# - champiñón, aceitunas, tomate
# - champiñón, anchoa, tomate
# - aceitunas, anchoa, tomate

# %% [markdown]
# ### Cuestión
#
# ¿Cómo enumerarías todas las combinaciones de la bonoloto/primitiva sabiendo que cada combinación consiste en elegir 6 números distintos entre el 1 y el 49?
#
# Puedes hacer la prueba, pero obviamente saldrá un número muy grande de soluciones (alrededor de 14 millones).
# Prueba a sacar las 5 primeras soluciones... puedes meter un break o hacer algo tipo:
# ```python
# for i, otravariable in zip(range(5),OTRACOSA):
#     ...
# ```
# zip recorre ambos a la vez y parará cuando uno de ellos termine (range(5) en este caso...)

# %%
for i, pizza in zip(range(5), combinaciones(ingredientes,3)):
    print("-",", ".join(pizza))

sum(1 for _ in combinaciones(ingredientes,3))
# Out:
# - mozzarella, pepperoni, champiñón
# - mozzarella, pepperoni, aceitunas
# - mozzarella, pepperoni, anchoa
# - mozzarella, pepperoni, tomate
# - mozzarella, champiñón, aceitunas
# 20

# %% [markdown]
# <a id='exactcover'></a>
# ## Actividad 3: Cubrimiento exacto de un conjunto
#
# El cubrimiento exacto de un conjunto o *exact cover* es un problema muy famoso [https://en.wikipedia.org/wiki/Exact_cover](https://en.wikipedia.org/wiki/Exact_cover)
#
# - **Entrada:** Dado un conjunto $U$ (de Universo), nos dan una lista de subconjuntos de $U$. Ejemplo:
#
#    ```python
#    datos = [ {1,2,3}, {2,3,4}, {4,5}, {1,5}, {2,3} ]
#    ```
#
# - **Objetivo:** Se trata de seleccionar unos cuantos conjuntos de los que nos ha pasado de forma que constituyan una **PARTICIÓN** de $U$.
#
#   Es decir, que sean disjuntos entre sí y que su unión sea $U$.
#
#   Para el ejemplo anterior donde `U= {1,2,3,4,5}`:
#
#    ```python
#    solucion = [ {1,2,3}, {4,5} ]
#    ```
#
# La solución no tiene por qué existir ni tiene por qué ser única. En el ejemplo anterior también es solución:
#
# ```python
# solucion = {{2,3,4}, {1,5}}
# ```
#
# Representaremos la entrada mediante una lista de conjuntos:
#
# ```
# listaConjuntos = [{"casa","coche","gato"},
#                   {"casa","bici"},
#                   {"bici","perro"},
#                   {"boli","gato"},
#                   {"coche","gato","bici"},
#                   {"casa", "moto"},
#                   {"perro", "boli"},
#                   {"coche","moto"},
#                   {"casa"}]
# for solucion in exact_cover(listaConjuntos):
#     print(solucion)
# ```
#
# El resultado de ejecutar el código anterior:
#
# ```
# [{'perro', 'bici'}, {'gato', 'boli'}, {'coche', 'moto'}, {'casa'}]
# [{'coche', 'gato', 'bici'}, {'casa', 'moto'}, {'perro', 'boli'}]
# ```
#
# - Representaremos una solución mediante una secuencia de 0s y 1s donde 1 significa que lo tenemos en cuenta y 0 que no.
# - Empezaremos con `sol` la lista vacía (no hemos decidido nada).
# - Desenrollaremos el bucle de ramificar:
#
#   - Primero probamos seleccionar el conjunto $i$-ésimo ($i$ será `len(sol)`). En ese caso hay que comprobar que ese conjunto es disjunto a todos los que ya hemos seleccionado.
#   - Después consideramos el caso en el que nos saltamos el conjunto $i$-ésimo.
#
# - Si llegamos a un estado completo, hace falta ver si es factible (la
#   unión de todos los conjuntos seleccionados coincide con el
#   universo).
#
# Para ahorrarnos cálculos, vamos a llevar en todo momento un parámetro
# auxiliar `cjtAcumulado` que será la unión de todos los conjuntos
# seleccionados para formar parte de la solución. Con ello el esquema de
# lo que hay que implementar se corresponde al siguiente *pseudocódigo:*
#
# ```python
# def exact_cover(listaConjuntos, U=None): # ES PSEUDO-CÓDIGO!!!
#
#     # permitimos que nos pasen U, si no lo hacen lo calculamos:
#     if U is None:
#         U = set().union(*listaConjuntos)
#
#   def backtracking(sol, cjtAcumulado):
#     if es completo:
#       if es factible:
#         yield lista con cjts seleccionados en sol
#     else: # es estado intermedio
#       cjt = listaConjuntos[len(sol)] # el cjt a considerar ahora
# 	  # ramificar, hemos desenrollado los 2 casos:
#       if cjt disjunto de cjtAcumulado:
#         añadir un 1 en solucion (con append)
#         yield from backtracking pasándole cjtAcumulado|cjt
#         # donde | es el operador union
#         quitar 1 de solucion (pop)
#       # en cualquier caso probar a saltarse cjt
#       añadir un 0 en solucion (con append)
#       yield from backtracking sin añadir cjt al cjtAcumulado
#       quitar 0 de solucion (pop)
#
#   yield from backtracking([], set()) # cjtAcumulado empieza vacío
# ```
#
# Completa el siguiente código y comprueba que funciona:

# %%
def exact_cover(listaConjuntos, U=None):

    if U is None:
        U = set().union(*listaConjuntos) 
    
    def backtracking(sol, cjtAcumulado):
        if cjtAcumulado == U:
            yield [listaConjuntos[i] for i in range(len(sol)) if sol.copy()[i] == 1]
        elif len(sol) < len(listaConjuntos):
            cjt = listaConjuntos[len(sol)]

            if cjt.isdisjoint(cjtAcumulado):
                sol.append(1)
                yield from backtracking(sol, cjtAcumulado | cjt)
                sol.pop()

            sol.append(0)
            yield from backtracking(sol, cjtAcumulado) 
            sol.pop()

    yield from backtracking([], set())

# %% [markdown]
# El siguiente ejemplo tiene estas soluciones:
#
# ```
# [{'bici', 'perro'}, {'boli', 'gato'}, {'moto', 'coche'}, {'casa'}]
# [{'bici', 'coche', 'gato'}, {'casa', 'moto'}, {'boli', 'perro'}]
# ```

# %%
listaConjuntos = [{"casa","coche","gato"},
                  {"casa","bici"},
                  {"bici","perro"},
                  {"boli","gato"},
                  {"coche","gato","bici"},
                  {"casa", "moto"},
                  {"perro", "boli"},
                  {"coche","moto"},
                  {"casa"}]
for solucion in exact_cover(listaConjuntos):
    print(solucion)
# Out:
# [{'perro', 'bici'}, {'gato', 'boli'}, {'moto', 'coche'}, {'casa'}]
# [{'bici', 'gato', 'coche'}, {'moto', 'casa'}, {'perro', 'boli'}]

# %% [markdown]
# <a id='langford'></a>
# ## Actividad 4: Secuencias de Langford
#
# Una secuencia o
# [emparejamiento de Langford](https://en.wikipedia.org/wiki/Langford_pairing)
# de longitud $2N$ es una ordenación de los números
# $1,1,2,2,\ldots,N-1,N-1,N,N$ de manera que entre dos números $i$ hay
# $i$ números como en el siguiente ejemplo de
# [wikipedia](https://en.m.wikipedia.org/wiki/File:Langford_pairing.svg):
#
# $$ 4\qquad 1\qquad 3\qquad 1\qquad 2\qquad 4\qquad 3\qquad 2 $$
#
# https://upload.wikimedia.org/wikipedia/commons/d/db/Langford_pairing.svg
#
# Vamos a utilizar *backtracking*. Utilizaremos un vector (lista Python)
# de longitud $2N$ que estará inicializada a 0s (valor que denota un
# hueco en el vector).
#
# El algoritmo de backtracking intentará posicionar, una por una, las
# $N$ parejas de números empezando por los más altos (la pareja $N$,$N$)
# hasta la más bajita (la $1$,$1$).

# %% [markdown]
# ### Estructura de la solución
#
# Vamos a cambiar ligeramente el esquema de *backtracking*. Un posible esqueleto del programa sería:
#
# - En la función `langford` creamos una lista `seq` de longitud `2*N`
#   inicializada a 0s que será accesible desde cualquier llamada a
#   `backtracking`. Nunca cambiará de tamaño.
# - El parámetro a `backtracking` será `num` que es el número cuya pareja hay que situar en `seq` (empezando por `N`).
# - Si llegamos a `num==0` será un estado completo.
# - Ramificar consiste en probar todas las posibles posiciones en que podemos
# situar cada pareja en el vector. Por ejemplo, si vamos a situar el
# valor $3$ debemos tener en cuenta que si el primero ocupa la posición
# `i` en el vector (con `i` $\geq 0$) , el segundo ocupará la posición
# `i+1+3` (que debe de ser $\leq$ `2*N-1`). Además:
#
#   - no podemos poner los valores encima de otros (únicamente podremos
#     situarlos donde previamente tengamos 0s) y que
#   - al cambiar de rama debemos *deshacer* los cambios efectuados
#     poniendo a 0 las posiciones ocupadas previamente.
#
# ### Matemáticas al poder
#
# Se puede demostrar que solamente existen soluciones para aquellos valores  $N$ tal
# que el resto de dividir $N$ entre $4$ valga $0$ o $3$. Si no es el caso podemos evitar *backtracking:*
#
# ```python
# if N%4 in (0,3):
#     yield from backtracking(N)
# ```

# %%
def langford(N):
    N2   = 2*N
    seq  = [0]*N2
    def backtracking(num):
        print(seq)
        if num<=0:
            yield "-".join(map(str, seq))
        else:
            for i in range(N2 - num - 1):
                if  seq[i] == 0 and seq[i + num + 1] == 0:
                    seq[i] = seq[i + num + 1] = num
                    yield from backtracking(num - 1)
                    seq[i] = seq[i + num + 1] = 0
            pass    

    if N%4 in (0,3):
        yield from backtracking(N)

for i, sol in enumerate(langford(4)):
    print(i, sol)
    
# 0 4-1-3-1-2-4-3-2
# 1 2-3-4-2-1-3-1-4
# Out:
# [0, 0, 0, 0, 0, 0, 0, 0]
# [4, 0, 0, 0, 0, 4, 0, 0]
# [4, 0, 3, 0, 0, 4, 3, 0]
# [4, 2, 3, 0, 2, 4, 3, 0]
# [4, 0, 3, 0, 2, 4, 3, 2]
# [4, 1, 3, 1, 2, 4, 3, 2]
# 0 4-1-3-1-2-4-3-2
# [4, 0, 0, 3, 0, 4, 0, 3]
# [4, 2, 0, 3, 2, 4, 0, 3]
# [0, 4, 0, 0, 0, 0, 4, 0]
# [3, 4, 0, 0, 3, 0, 4, 0]
# [3, 4, 2, 0, 3, 2, 4, 0]
# [0, 4, 0, 3, 0, 0, 4, 3]
# [0, 4, 2, 3, 0, 2, 4, 3]
# [0, 0, 4, 0, 0, 0, 0, 4]
# [3, 0, 4, 0, 3, 0, 0, 4]
# [3, 0, 4, 2, 3, 0, 2, 4]
# [0, 3, 4, 0, 0, 3, 0, 4]
# [2, 3, 4, 2, 0, 3, 0, 4]
# [2, 3, 4, 2, 1, 3, 1, 4]
# 1 2-3-4-2-1-3-1-4
# [0, 3, 4, 2, 0, 3, 2, 4]

# %% [markdown]
# #### Otro ejemplo con N=7:
# ```python
# for i, sol in enumerate(langford(7)):
#     print(i, sol)
#
# 0 7-3-6-2-5-3-2-4-7-6-5-1-4-1
# 1 7-2-6-3-2-4-5-3-7-6-4-1-5-1
# ...
# 50 1-5-1-4-6-7-3-5-4-2-3-6-2-7
# 51 1-4-1-5-6-7-4-2-3-5-2-6-3-7
# ```

# %%
# otro ejemplo con N=7
for i, sol in enumerate(langford(7)):
    print(i, sol)
# Out:
# 0 7-3-6-2-5-3-2-4-7-6-5-1-4-1
# 1 7-2-6-3-2-4-5-3-7-6-4-1-5-1
# 2 7-2-4-6-2-3-5-4-7-3-6-1-5-1
# 3 7-3-1-6-1-3-4-5-7-2-6-4-2-5
# 4 7-1-4-1-6-3-5-4-7-3-2-6-5-2
# 5 7-1-3-1-6-4-3-5-7-2-4-6-2-5
# 6 7-4-1-5-1-6-4-3-7-5-2-3-6-2
# 7 7-2-4-5-2-6-3-4-7-5-3-1-6-1
# 8 5-7-2-6-3-2-5-4-3-7-6-1-4-1
# 9 3-7-4-6-3-2-5-4-2-7-6-1-5-1
# 10 5-7-4-1-6-1-5-4-3-7-2-6-3-2
# 11 5-7-2-3-6-2-5-3-4-7-1-6-1-4
# 12 1-7-1-2-6-4-2-5-3-7-4-6-3-5
# 13 5-7-1-4-1-6-5-3-4-7-2-3-6-2
# 14 1-7-1-2-5-6-2-3-4-7-5-3-6-4
# 15 2-7-4-2-3-5-6-4-3-7-1-5-1-6
# 16 6-2-7-4-2-3-5-6-4-3-7-1-5-1
# 17 2-6-7-2-1-5-1-4-6-3-7-5-4-3
# 18 3-6-7-1-3-1-4-5-6-2-7-4-2-5
# 19 5-1-7-1-6-2-5-4-2-3-7-6-4-3
# 20 2-3-7-2-6-3-5-1-4-1-7-6-5-4
# 21 4-1-7-1-6-4-2-5-3-2-7-6-3-5
# 22 5-2-7-3-2-6-5-3-4-1-7-1-6-4
# 23 3-5-7-4-3-6-2-5-4-2-7-1-6-1
# 24 3-5-7-2-3-6-2-5-4-1-7-1-6-4
# 25 2-4-7-2-3-6-4-5-3-1-7-1-6-5
# 26 5-6-1-7-1-3-5-4-6-3-2-7-4-2
# 27 4-6-1-7-1-4-5-2-6-3-2-7-5-3
# 28 1-6-1-7-2-4-5-2-6-3-4-7-5-3
# 29 4-6-1-7-1-4-3-5-6-2-3-7-2-5
# 30 5-3-6-7-2-3-5-2-4-6-1-7-1-4
# 31 4-5-6-7-1-4-1-5-3-6-2-7-3-2
# 32 3-4-6-7-3-2-4-5-2-6-1-7-1-5
# 33 5-2-4-7-2-6-5-4-1-3-1-7-6-3
# 34 3-4-5-7-3-6-4-1-5-1-2-7-6-2
# 35 1-5-1-7-3-4-6-5-3-2-4-7-2-6
# 36 6-1-5-1-7-3-4-6-5-3-2-4-7-2
# 37 4-6-3-5-7-4-3-2-6-5-2-1-7-1
# 38 2-6-3-2-7-4-3-5-6-1-4-1-7-5
# 39 5-3-6-4-7-3-5-2-4-6-2-1-7-1
# 40 4-1-6-1-7-4-3-5-2-6-3-2-7-5
# 41 2-3-6-2-7-3-4-5-1-6-1-4-7-5
# 42 1-5-1-6-7-2-4-5-2-3-6-4-7-3
# 43 1-4-1-6-7-3-4-5-2-3-6-2-7-5
# 44 1-6-1-3-5-7-4-3-6-2-5-4-2-7
# 45 2-6-3-2-5-7-3-4-6-1-5-1-4-7
# 46 5-2-6-4-2-7-5-3-4-6-1-3-1-7
# 47 2-5-6-2-3-7-4-5-3-6-1-4-1-7
# 48 5-2-4-6-2-7-5-4-3-1-6-1-3-7
# 49 1-5-1-6-3-7-4-5-3-2-6-4-2-7
# 50 1-5-1-4-6-7-3-5-4-2-3-6-2-7
# 51 1-4-1-5-6-7-4-2-3-5-2-6-3-7

# %% [markdown]
# <a id='langford_exactcover'></a>
# ## Actividad 5: Langford vía exact cover
#
# - Para reducir el problema de la secuencia de Langford de longitud $N$
# al *exact cover* necesitamos *en principio*, un conjunto `U` de longitud
# $2N$ correspondiente a las posiciones que podemos ocupar en la
# secuencia. Así, por ejemplo, si el vector se indexa entre `0` y
# `2*N-1`, podríamos utilizar las cadenas `p0`,`p1`,... como elementos
# del conjunto `U`.
#
# - Para cada posible número entre $1$ y $N$ necesitamos crear un
# subconjunto por cada posible posición en que podemos meter una pareja
# de estos valores.
#
#   Ejemplos:
#
#   - para el valor `1` deberíamos considerar los subconjuntos `{'p0','p2'},{'p1','p3'},{'p2','p4'},`...
#   - para el valor `2` deberíamos considerar los subconjuntos `{'p0','p3'},{'p1','p4'},{'p2','p5'},`...
#
#   Cada uno de esos conjuntos representa un par de cartas dispuestas a la distancia adecuada.
#
# Utilizar esto tal cual en *exact cover* no funciona, tiene un fallo ¿cuál?
#
#
# **¿Cuál es el fallo de este razonamiento?**
#
#   El problema de esta aproximación es que nada impide obtener una solución que utilize más de una vez un mismo número (par de cartas) al tiempo que quedarían números por utilizar.
#
#   Así, por ejemplo, para N=4 en lugar de una secuencia como:
# `[4,1,3,1,2,4,3,2]` se podría obtener un cubrimiento de
# `p0`, `p1`, `p2`, `p3`, `p4`, `p5`, `p6`, `p7` utilizando
# `{'p0','p2'}`, `{'p1','p3'}`, `{'p4','p6'}`, `{'p5','p7'}` dando la secuencia:
# `[1,1,1,1,1,1,1,1]`.

# %% [markdown]
# ### Generación de los conjuntos
#
# Para resolver el fallo anterior se propone incorporar en el conjunto `U`, además de elementos representando el hecho de ocupar cada una de las `2*N` posiciones del vector, otros `N` valores más que representen el hecho de usar cada uno de los `N` números a utilizar. Estos elementos los denotaremos mediante `n1`, `n2`, ... hasta $N$.
#
#   Ahora tendremos conjuntos tipo `{'p0','p2','n1'}` para indicar que las 2 cartas con el número `n1` se ha puesto en las posiciones `p0` y `p2`.
#
#
#
# -   Un cubrimiento exacto con conjuntos de esas tripletas va a tener que usar una sola vez cada posible posición y cada posible tipo de carta.
#
# - Completa la siguiente función que recibe `N` y genera la lista de conjuntos para resolver la secuencia de Langford con `exact_cover`:
#
# #### Internalizar cadenas en Python
#
# Para no tener múltiples copias de la misma cadeda podemos utilizar la función ```sys.intern(cadena)```. Esta función permite que al generar varias veces la misma cadena se utilice una sola referencia a una sola copia de la misma.

# %%
import sys
# sys.intern(cadena) permite tener una referencia unica a cada cadena

def langford_data_structure(N):
    # n1,n2,... indica que el valor se ha utilizado
    # p0,p1,... indica que la posicions se ha utilizado
    
    def value(i):
        return sys.intern(f'n{i}')
    def position(i):
        return sys.intern(f'p{i}')
    N2, DS = N*2, []   
    for num in range(1, N + 1):
        for i in range(N2 - num - 1):
            constraint_set = {value(num), position(i), position(i + num + 1)}
            DS.append(constraint_set)

    return DS

langford_data_structure(4)
# Out:
# [{'n1', 'p0', 'p2'},
#  {'n1', 'p1', 'p3'},
#  {'n1', 'p2', 'p4'},
#  {'n1', 'p3', 'p5'},
#  {'n1', 'p4', 'p6'},
#  {'n1', 'p5', 'p7'},
#  {'n2', 'p0', 'p3'},
#  {'n2', 'p1', 'p4'},
#  {'n2', 'p2', 'p5'},
#  {'n2', 'p3', 'p6'},
#  {'n2', 'p4', 'p7'},
#  {'n3', 'p0', 'p4'},
#  {'n3', 'p1', 'p5'},
#  {'n3', 'p2', 'p6'},
#  {'n3', 'p3', 'p7'},
#  {'n4', 'p0', 'p5'},
#  {'n4', 'p1', 'p6'},
#  {'n4', 'p2', 'p7'}]

# %% [markdown]
# #### Ejemplo
#
# ```python
# langford_data_structure(4)
# ```
#
# debería generar:
#
# ```python
# [{'n1', 'p0', 'p2'},
#  {'n1', 'p1', 'p3'},
#  {'n1', 'p2', 'p4'},
#  {'n1', 'p3', 'p5'},
#  {'n1', 'p4', 'p6'},
#  {'n1', 'p5', 'p7'},
#  {'n2', 'p0', 'p3'},
#  {'n2', 'p1', 'p4'},
#  {'n2', 'p2', 'p5'},
#  {'n2', 'p3', 'p6'},
#  {'n2', 'p4', 'p7'},
#  {'n3', 'p0', 'p4'},
#  {'n3', 'p1', 'p5'},
#  {'n3', 'p2', 'p6'},
#  {'n3', 'p3', 'p7'},
#  {'n4', 'p0', 'p5'},
#  {'n4', 'p1', 'p6'},
#  {'n4', 'p2', 'p7'}]
# ```

# %% [markdown]
# ## Actividad 5: Langford vía exact cover
#
# Para terminar, necesitamos una manera de convertir la solución devuelta por el *exact cover*:

# %%
def langford_exact_cover(N):
    if N%4 in (0,3):
        U = langford_data_structure(N)
        sol = [None]*2*N
        for coversol in exact_cover(U):
            for item in coversol:
                elems = sorted(item)
                n = int(elems[0][1:])
                p = int(elems[1][1:])
                sol[p]=n
                p = int(elems[2][1:])
                sol[p]=n
            yield "-".join(map(str,sol))

for i, sol in enumerate(langford_exact_cover(4)):
    print(i, sol)
# 0 4-1-3-1-2-4-3-2
# 1 2-3-4-2-1-3-1-4
# Out:
# 0 4-1-3-1-2-4-3-2
# 1 2-3-4-2-1-3-1-4

# %% [markdown]
# #### Ejemplo
# ```python
# for i, sol in enumerate(langford_exact_cover(7)):
#     print(i, sol)
# ```
# debería generar:
#
# ```
# 0 1-7-1-2-5-6-2-3-4-7-5-3-6-4
# 1 1-7-1-2-6-4-2-5-3-7-4-6-3-5
# ...
# 50 5-3-6-4-7-3-5-2-4-6-2-1-7-1
# 51 4-6-3-5-7-4-3-2-6-5-2-1-7-1
# ```

# %%
for i, sol in enumerate(langford_exact_cover(7)):
    print(i, sol)
# Out:
# 0 1-7-1-2-5-6-2-3-4-7-5-3-6-4
# 1 1-7-1-2-6-4-2-5-3-7-4-6-3-5
# 2 1-6-1-7-2-4-5-2-6-3-4-7-5-3
# 3 1-5-1-6-7-2-4-5-2-3-6-4-7-3
# 4 1-4-1-5-6-7-4-2-3-5-2-6-3-7
# 5 1-4-1-6-7-3-4-5-2-3-6-2-7-5
# 6 1-6-1-3-5-7-4-3-6-2-5-4-2-7
# 7 1-5-1-7-3-4-6-5-3-2-4-7-2-6
# 8 1-5-1-6-3-7-4-5-3-2-6-4-2-7
# 9 1-5-1-4-6-7-3-5-4-2-3-6-2-7
# 10 5-1-7-1-6-2-5-4-2-3-7-6-4-3
# 11 4-1-7-1-6-4-2-5-3-2-7-6-3-5
# 12 4-1-6-1-7-4-3-5-2-6-3-2-7-5
# 13 7-1-3-1-6-4-3-5-7-2-4-6-2-5
# 14 7-1-4-1-6-3-5-4-7-3-2-6-5-2
# 15 6-1-5-1-7-3-4-6-5-3-2-4-7-2
# 16 4-6-1-7-1-4-5-2-6-3-2-7-5-3
# 17 7-3-1-6-1-3-4-5-7-2-6-4-2-5
# 18 4-6-1-7-1-4-3-5-6-2-3-7-2-5
# 19 5-6-1-7-1-3-5-4-6-3-2-7-4-2
# 20 7-4-1-5-1-6-4-3-7-5-2-3-6-2
# 21 5-7-1-4-1-6-5-3-4-7-2-3-6-2
# 22 3-6-7-1-3-1-4-5-6-2-7-4-2-5
# 23 5-7-4-1-6-1-5-4-3-7-2-6-3-2
# 24 2-6-7-2-1-5-1-4-6-3-7-5-4-3
# 25 4-5-6-7-1-4-1-5-3-6-2-7-3-2
# 26 2-3-7-2-6-3-5-1-4-1-7-6-5-4
# 27 3-4-5-7-3-6-4-1-5-1-2-7-6-2
# 28 2-3-6-2-7-3-4-5-1-6-1-4-7-5
# 29 5-2-4-7-2-6-5-4-1-3-1-7-6-3
# 30 2-6-3-2-7-4-3-5-6-1-4-1-7-5
# 31 2-6-3-2-5-7-3-4-6-1-5-1-4-7
# 32 2-4-7-2-3-6-4-5-3-1-7-1-6-5
# 33 5-2-7-3-2-6-5-3-4-1-7-1-6-4
# 34 5-2-4-6-2-7-5-4-3-1-6-1-3-7
# 35 3-5-7-2-3-6-2-5-4-1-7-1-6-4
# 36 2-7-4-2-3-5-6-4-3-7-1-5-1-6
# 37 2-5-6-2-3-7-4-5-3-6-1-4-1-7
# 38 5-2-6-4-2-7-5-3-4-6-1-3-1-7
# 39 5-7-2-3-6-2-5-3-4-7-1-6-1-4
# 40 5-3-6-7-2-3-5-2-4-6-1-7-1-4
# 41 3-4-6-7-3-2-4-5-2-6-1-7-1-5
# 42 7-2-6-3-2-4-5-3-7-6-4-1-5-1
# 43 7-2-4-6-2-3-5-4-7-3-6-1-5-1
# 44 6-2-7-4-2-3-5-6-4-3-7-1-5-1
# 45 7-2-4-5-2-6-3-4-7-5-3-1-6-1
# 46 5-7-2-6-3-2-5-4-3-7-6-1-4-1
# 47 7-3-6-2-5-3-2-4-7-6-5-1-4-1
# 48 3-7-4-6-3-2-5-4-2-7-6-1-5-1
# 49 3-5-7-4-3-6-2-5-4-2-7-1-6-1
# 50 5-3-6-4-7-3-5-2-4-6-2-1-7-1
# 51 4-6-3-5-7-4-3-2-6-5-2-1-7-1
