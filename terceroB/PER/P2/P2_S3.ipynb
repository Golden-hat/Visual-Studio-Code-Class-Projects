# %% [markdown]
# # AdaBoost y Gradient boosting con árboles en un dataset de detección de spam
#
# Árboles de decisión y todos los ensembles propuestos funcionan en la práctica muy bien en datos tabulares como puede ser el problema de reconocimiento de spam en mails.
#
# Se propone pues emplear el dataset id=44 de openml de detección de Spam. Son un total de 4601 muestras con 57 características.

# %%
from sklearn.datasets import fetch_openml
from sklearn.model_selection import train_test_split

## Descarga del dataset Spam
X, y = fetch_openml(data_id=44, as_frame=False, cache=True, return_X_y=True)
print(X.shape)

## Partición train/test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=True, random_state=23)
# Out:
# (4601, 57)

# %% [markdown]
# ## AdaBoost
#
# Probemos el clasificador de AdaBoost

# %%
from sklearn.ensemble import AdaBoostClassifier

ab = AdaBoostClassifier()

acc=ab.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# /home/yassin/anaconda3/lib/python3.11/site-packages/sklearn/ensemble/_weight_boosting.py:519: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Precisión: 93.8%

# %% [markdown]
# **Ejercicio** Teniendo en cuenta la documentación [AdaBoost](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.AdaBoostClassifier.html) prueba mediante grid search a encontrar mejores parámetros.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
import pandas as pd
from sklearn.tree import DecisionTreeClassifier

ab = AdaBoostClassifier(estimator = DecisionTreeClassifier())

# Definir los parámetros a probar
G = {
    'n_estimators': [50, 100, 150],
    'estimator__max_depth': [2, 4, 6, 8,10]
}

# Configurar el GridSearchCV
GS = GridSearchCV(ab, param_grid=G, scoring='accuracy', refit=True, cv=5,verbose =10)

# Ajustar el modelo
GS.fit(X_train, y_train)

acc = GS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {GS.best_params_}')

# %% [markdown]
# ## GradientBoostingClassifier
#
# Probemos el clasificador Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier()

acc=gb.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Precisión: 95.0%

# %% [markdown]
# Los principales parámetros del GradientBoosting son:
# * n_estimators (100)
# * max_depth (3)
# * max_features
#
# **Ejercicio** prueba diferentes valores (lógicos) de estos parámetros mediante GridSearch.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV, train_test_split
import numpy as np
from scipy.stats import randint as sp_randint

# Definir el clasificador
gb = GradientBoostingClassifier()

# Definir los parámetros a probar
G = {
    'n_estimators': [50, 150],
    'max_depth': [3, 5],
    'max_features': ['sqrt', 'log2']
}


GS = GridSearchCV(gb, param_grid=G, scoring='accuracy', refit=True, cv=5,verbose =10)
# Ajustar el modelo
acc = GS.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [CV 1/5; 1/8] START max_depth=3, max_features=sqrt, n_estimators=50.............
# [CV 1/5; 1/8] END max_depth=3, max_features=sqrt, n_estimators=50;, score=0.935 total time=   0.1s
# [CV 2/5; 1/8] START max_depth=3, max_features=sqrt, n_estimators=50.............
# [CV 2/5; 1/8] END max_depth=3, max_features=sqrt, n_estimators=50;, score=0.928 total time=   0.1s
# [CV 3/5; 1/8] START max_depth=3, max_features=sqrt, n_estimators=50.............
# [CV 3/5; 1/8] END max_depth=3, max_features=sqrt, n_estimators=50;, score=0.948 total time=   0.1s
# [CV 4/5; 1/8] START max_depth=3, max_features=sqrt, n_estimators=50.............
# [CV 4/5; 1/8] END max_depth=3, max_features=sqrt, n_estimators=50;, score=0.936 total time=   0.1s
# [CV 5/5; 1/8] START max_depth=3, max_features=sqrt, n_estimators=50.............
# [CV 5/5; 1/8] END max_depth=3, max_features=sqrt, n_estimators=50;, score=0.933 total time=   0.1s
# [CV 1/5; 2/8] START max_depth=3, max_features=sqrt, n_estimators=150............
# [CV 1/5; 2/8] END max_depth=3, max_features=sqrt, n_estimators=150;, score=0.948 total time=   0.3s
# [CV 2/5; 2/8] START max_depth=3, max_features=sqrt, n_estimators=150............
# [CV 2/5; 2/8] END max_depth=3, max_features=sqrt, n_estimators=150;, score=0.939 total time=   0.2s
# [CV 3/5; 2/8] START max_depth=3, max_features=sqrt, n_estimators=150............
# [CV 3/5; 2/8] END max_depth=3, max_features=sqrt, n_estimators=150;, score=0.959 total time=   0.3s
# [CV 4/5; 2/8] START max_depth=3, max_features=sqrt, n_estimators=150............
# [CV 4/5; 2/8] END max_depth=3, max_features=sqrt, n_estimators=150;, score=0.944 total time=   0.3s
# [CV 5/5; 2/8] START max_depth=3, max_features=sqrt, n_estimators=150............
# [CV 5/5; 2/8] END max_depth=3, max_features=sqrt, n_estimators=150;, score=0.955 total time=   0.3s
# [CV 1/5; 3/8] START max_depth=3, max_features=log2, n_estimators=50.............
# [CV 1/5; 3/8] END max_depth=3, max_features=log2, n_estimators=50;, score=0.942 total time=   0.1s
# [CV 2/5; 3/8] START max_depth=3, max_features=log2, n_estimators=50.............
# [CV 2/5; 3/8] END max_depth=3, max_features=log2, n_estimators=50;, score=0.925 total time=   0.1s
# [CV 3/5; 3/8] START max_depth=3, max_features=log2, n_estimators=50.............
# [CV 3/5; 3/8] END max_depth=3, max_features=log2, n_estimators=50;, score=0.946 total time=   0.1s
# [CV 4/5; 3/8] START max_depth=3, max_features=log2, n_estimators=50.............
# [CV 4/5; 3/8] END max_depth=3, max_features=log2, n_estimators=50;, score=0.928 total time=   0.1s
# [CV 5/5; 3/8] START max_depth=3, max_features=log2, n_estimators=50.............
# [CV 5/5; 3/8] END max_depth=3, max_features=log2, n_estimators=50;, score=0.927 total time=   0.1s
# [CV 1/5; 4/8] START max_depth=3, max_features=log2, n_estimators=150............
# [CV 1/5; 4/8] END max_depth=3, max_features=log2, n_estimators=150;, score=0.943 total time=   0.2s
# [CV 2/5; 4/8] START max_depth=3, max_features=log2, n_estimators=150............
# [CV 2/5; 4/8] END max_depth=3, max_features=log2, n_estimators=150;, score=0.943 total time=   0.2s
# [CV 3/5; 4/8] START max_depth=3, max_features=log2, n_estimators=150............
# [CV 3/5; 4/8] END max_depth=3, max_features=log2, n_estimators=150;, score=0.962 total time=   0.2s
# [CV 4/5; 4/8] START max_depth=3, max_features=log2, n_estimators=150............
# [CV 4/5; 4/8] END max_depth=3, max_features=log2, n_estimators=150;, score=0.946 total time=   0.2s
# [CV 5/5; 4/8] START max_depth=3, max_features=log2, n_estimators=150............
# [CV 5/5; 4/8] END max_depth=3, max_features=log2, n_estimators=150;, score=0.955 total time=   0.2s
# [CV 1/5; 5/8] START max_depth=5, max_features=sqrt, n_estimators=50.............
# [CV 1/5; 5/8] END max_depth=5, max_features=sqrt, n_estimators=50;, score=0.942 total time=   0.1s
# [CV 2/5; 5/8] START max_depth=5, max_features=sqrt, n_estimators=50.............
# [CV 2/5; 5/8] END max_depth=5, max_features=sqrt, n_estimators=50;, score=0.942 total time=   0.2s
# [CV 3/5; 5/8] START max_depth=5, max_features=sqrt, n_estimators=50.............
# [CV 3/5; 5/8] END max_depth=5, max_features=sqrt, n_estimators=50;, score=0.950 total time=   0.2s
# [CV 4/5; 5/8] START max_depth=5, max_features=sqrt, n_estimators=50.............
# [CV 4/5; 5/8] END max_depth=5, max_features=sqrt, n_estimators=50;, score=0.938 total time=   0.1s
# [CV 5/5; 5/8] START max_depth=5, max_features=sqrt, n_estimators=50.............
# [CV 5/5; 5/8] END max_depth=5, max_features=sqrt, n_estimators=50;, score=0.951 total time=   0.2s
# [CV 1/5; 6/8] START max_depth=5, max_features=sqrt, n_estimators=150............
# [CV 1/5; 6/8] END max_depth=5, max_features=sqrt, n_estimators=150;, score=0.955 total time=   0.4s
# [CV 2/5; 6/8] START max_depth=5, max_features=sqrt, n_estimators=150............
# [CV 2/5; 6/8] END max_depth=5, max_features=sqrt, n_estimators=150;, score=0.954 total time=   0.4s
# [CV 3/5; 6/8] START max_depth=5, max_features=sqrt, n_estimators=150............
# [CV 3/5; 6/8] END max_depth=5, max_features=sqrt, n_estimators=150;, score=0.963 total time=   0.4s
# [CV 4/5; 6/8] START max_depth=5, max_features=sqrt, n_estimators=150............
# [CV 4/5; 6/8] END max_depth=5, max_features=sqrt, n_estimators=150;, score=0.943 total time=   0.4s
# [CV 5/5; 6/8] START max_depth=5, max_features=sqrt, n_estimators=150............
# [CV 5/5; 6/8] END max_depth=5, max_features=sqrt, n_estimators=150;, score=0.958 total time=   0.5s
# [CV 1/5; 7/8] START max_depth=5, max_features=log2, n_estimators=50.............
# [CV 1/5; 7/8] END max_depth=5, max_features=log2, n_estimators=50;, score=0.944 total time=   0.2s
# [CV 2/5; 7/8] START max_depth=5, max_features=log2, n_estimators=50.............
# [CV 2/5; 7/8] END max_depth=5, max_features=log2, n_estimators=50;, score=0.931 total time=   0.1s
# [CV 3/5; 7/8] START max_depth=5, max_features=log2, n_estimators=50.............
# [CV 3/5; 7/8] END max_depth=5, max_features=log2, n_estimators=50;, score=0.954 total time=   0.1s
# [CV 4/5; 7/8] START max_depth=5, max_features=log2, n_estimators=50.............
# [CV 4/5; 7/8] END max_depth=5, max_features=log2, n_estimators=50;, score=0.936 total time=   0.1s
# [CV 5/5; 7/8] START max_depth=5, max_features=log2, n_estimators=50.............
# [CV 5/5; 7/8] END max_depth=5, max_features=log2, n_estimators=50;, score=0.943 total time=   0.2s
# [CV 1/5; 8/8] START max_depth=5, max_features=log2, n_estimators=150............
# [CV 1/5; 8/8] END max_depth=5, max_features=log2, n_estimators=150;, score=0.950 total time=   0.4s
# [CV 2/5; 8/8] START max_depth=5, max_features=log2, n_estimators=150............
# [CV 2/5; 8/8] END max_depth=5, max_features=log2, n_estimators=150;, score=0.951 total time=   0.3s
# [CV 3/5; 8/8] START max_depth=5, max_features=log2, n_estimators=150............
# [CV 3/5; 8/8] END max_depth=5, max_features=log2, n_estimators=150;, score=0.966 total time=   0.3s
# [CV 4/5; 8/8] START max_depth=5, max_features=log2, n_estimators=150............
# [CV 4/5; 8/8] END max_depth=5, max_features=log2, n_estimators=150;, score=0.950 total time=   0.3s
# [CV 5/5; 8/8] START max_depth=5, max_features=log2, n_estimators=150............
# [CV 5/5; 8/8] END max_depth=5, max_features=log2, n_estimators=150;, score=0.965 total time=   0.3s
# Precisión: 95.4%

# %% [markdown]
# ### Acelerar la búsqueda de parámetros: RandomizedSearch
#
# Un problema recurrente que tenemos en estos experimentos es el coste temporal de encontrar los mejores parámetros mediante GridSearch. Una alternativa que reduce dicho coste temporal es el [RandomizedSearchCV](https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.RandomizedSearchCV.html)
#
# **Ejercicio** Implementa la misma búsqueda de valores que has realizado con GridSearch pero ahora con RandomizedSearch con n_iter=10 para limitar el número de pruebas a 10.

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV, train_test_split
import numpy as np
from scipy.stats import randint as sp_randint

gb = GradientBoostingClassifier()

# Definir los parámetros a probar
param_dist = {
    'n_estimators': sp_randint(50, 150),
    'max_depth': sp_randint(3, 5),
    'max_features': ['sqrt', 'log2']
}

# Configurar el RandomizedSearchCV
RS = RandomizedSearchCV(gb, param_distributions=param_dist, n_iter=10, cv=5, scoring='accuracy', random_state=42, verbose = 10)

# Ajustar el modelo
acc = RS.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5; 1/10] START max_depth=3, max_features=log2, n_estimators=142...........
# [CV 1/5; 1/10] END max_depth=3, max_features=log2, n_estimators=142;, score=0.944 total time=   0.2s
# [CV 2/5; 1/10] START max_depth=3, max_features=log2, n_estimators=142...........
# [CV 2/5; 1/10] END max_depth=3, max_features=log2, n_estimators=142;, score=0.938 total time=   0.2s
# [CV 3/5; 1/10] START max_depth=3, max_features=log2, n_estimators=142...........
# [CV 3/5; 1/10] END max_depth=3, max_features=log2, n_estimators=142;, score=0.959 total time=   0.2s
# [CV 4/5; 1/10] START max_depth=3, max_features=log2, n_estimators=142...........
# [CV 4/5; 1/10] END max_depth=3, max_features=log2, n_estimators=142;, score=0.942 total time=   0.2s
# [CV 5/5; 1/10] START max_depth=3, max_features=log2, n_estimators=142...........
# [CV 5/5; 1/10] END max_depth=3, max_features=log2, n_estimators=142;, score=0.954 total time=   0.2s
# [CV 1/5; 2/10] START max_depth=3, max_features=sqrt, n_estimators=121...........
# [CV 1/5; 2/10] END max_depth=3, max_features=sqrt, n_estimators=121;, score=0.946 total time=   0.2s
# [CV 2/5; 2/10] START max_depth=3, max_features=sqrt, n_estimators=121...........
# [CV 2/5; 2/10] END max_depth=3, max_features=sqrt, n_estimators=121;, score=0.944 total time=   0.2s
# [CV 3/5; 2/10] START max_depth=3, max_features=sqrt, n_estimators=121...........
# [CV 3/5; 2/10] END max_depth=3, max_features=sqrt, n_estimators=121;, score=0.963 total time=   0.2s
# [CV 4/5; 2/10] START max_depth=3, max_features=sqrt, n_estimators=121...........
# [CV 4/5; 2/10] END max_depth=3, max_features=sqrt, n_estimators=121;, score=0.942 total time=   0.2s
# [CV 5/5; 2/10] START max_depth=3, max_features=sqrt, n_estimators=121...........
# [CV 5/5; 2/10] END max_depth=3, max_features=sqrt, n_estimators=121;, score=0.952 total time=   0.2s
# [CV 1/5; 3/10] START max_depth=3, max_features=sqrt, n_estimators=132...........
# [CV 1/5; 3/10] END max_depth=3, max_features=sqrt, n_estimators=132;, score=0.948 total time=   0.2s
# [CV 2/5; 3/10] START max_depth=3, max_features=sqrt, n_estimators=132...........
# [CV 2/5; 3/10] END max_depth=3, max_features=sqrt, n_estimators=132;, score=0.944 total time=   0.2s
# [CV 3/5; 3/10] START max_depth=3, max_features=sqrt, n_estimators=132...........
# [CV 3/5; 3/10] END max_depth=3, max_features=sqrt, n_estimators=132;, score=0.958 total time=   0.2s
# [CV 4/5; 3/10] START max_depth=3, max_features=sqrt, n_estimators=132...........
# [CV 4/5; 3/10] END max_depth=3, max_features=sqrt, n_estimators=132;, score=0.940 total time=   0.2s
# [CV 5/5; 3/10] START max_depth=3, max_features=sqrt, n_estimators=132...........
# [CV 5/5; 3/10] END max_depth=3, max_features=sqrt, n_estimators=132;, score=0.954 total time=   0.2s
# [CV 1/5; 4/10] START max_depth=3, max_features=sqrt, n_estimators=124...........
# [CV 1/5; 4/10] END max_depth=3, max_features=sqrt, n_estimators=124;, score=0.943 total time=   0.2s
# [CV 2/5; 4/10] START max_depth=3, max_features=sqrt, n_estimators=124...........
# [CV 2/5; 4/10] END max_depth=3, max_features=sqrt, n_estimators=124;, score=0.950 total time=   0.2s
# [CV 3/5; 4/10] START max_depth=3, max_features=sqrt, n_estimators=124...........
# [CV 3/5; 4/10] END max_depth=3, max_features=sqrt, n_estimators=124;, score=0.961 total time=   0.2s
# [CV 4/5; 4/10] START max_depth=3, max_features=sqrt, n_estimators=124...........
# [CV 4/5; 4/10] END max_depth=3, max_features=sqrt, n_estimators=124;, score=0.939 total time=   0.2s
# [CV 5/5; 4/10] START max_depth=3, max_features=sqrt, n_estimators=124...........
# [CV 5/5; 4/10] END max_depth=3, max_features=sqrt, n_estimators=124;, score=0.957 total time=   0.2s
# [CV 1/5; 5/10] START max_depth=4, max_features=sqrt, n_estimators=149...........
# [CV 1/5; 5/10] END max_depth=4, max_features=sqrt, n_estimators=149;, score=0.950 total time=   0.3s
# [CV 2/5; 5/10] START max_depth=4, max_features=sqrt, n_estimators=149...........
# [CV 2/5; 5/10] END max_depth=4, max_features=sqrt, n_estimators=149;, score=0.947 total time=   0.3s
# [CV 3/5; 5/10] START max_depth=4, max_features=sqrt, n_estimators=149...........
# [CV 3/5; 5/10] END max_depth=4, max_features=sqrt, n_estimators=149;, score=0.966 total time=   0.3s
# [CV 4/5; 5/10] START max_depth=4, max_features=sqrt, n_estimators=149...........
# [CV 4/5; 5/10] END max_depth=4, max_features=sqrt, n_estimators=149;, score=0.947 total time=   0.3s
# [CV 5/5; 5/10] START max_depth=4, max_features=sqrt, n_estimators=149...........
# [CV 5/5; 5/10] END max_depth=4, max_features=sqrt, n_estimators=149;, score=0.958 total time=   0.3s
# [CV 1/5; 6/10] START max_depth=4, max_features=log2, n_estimators=52............
# [CV 1/5; 6/10] END max_depth=4, max_features=log2, n_estimators=52;, score=0.943 total time=   0.1s
# [CV 2/5; 6/10] START max_depth=4, max_features=log2, n_estimators=52............
# [CV 2/5; 6/10] END max_depth=4, max_features=log2, n_estimators=52;, score=0.938 total time=   0.1s
# [CV 3/5; 6/10] START max_depth=4, max_features=log2, n_estimators=52............
# [CV 3/5; 6/10] END max_depth=4, max_features=log2, n_estimators=52;, score=0.948 total time=   0.1s
# [CV 4/5; 6/10] START max_depth=4, max_features=log2, n_estimators=52............
# [CV 4/5; 6/10] END max_depth=4, max_features=log2, n_estimators=52;, score=0.936 total time=   0.1s
# [CV 5/5; 6/10] START max_depth=4, max_features=log2, n_estimators=52............
# [CV 5/5; 6/10] END max_depth=4, max_features=log2, n_estimators=52;, score=0.935 total time=   0.1s
# [CV 1/5; 7/10] START max_depth=4, max_features=sqrt, n_estimators=51............
# [CV 1/5; 7/10] END max_depth=4, max_features=sqrt, n_estimators=51;, score=0.944 total time=   0.1s
# [CV 2/5; 7/10] START max_depth=4, max_features=sqrt, n_estimators=51............
# [CV 2/5; 7/10] END max_depth=4, max_features=sqrt, n_estimators=51;, score=0.933 total time=   0.1s
# [CV 3/5; 7/10] START max_depth=4, max_features=sqrt, n_estimators=51............
# [CV 3/5; 7/10] END max_depth=4, max_features=sqrt, n_estimators=51;, score=0.948 total time=   0.1s
# [CV 4/5; 7/10] START max_depth=4, max_features=sqrt, n_estimators=51............
# [CV 4/5; 7/10] END max_depth=4, max_features=sqrt, n_estimators=51;, score=0.939 total time=   0.1s
# [CV 5/5; 7/10] START max_depth=4, max_features=sqrt, n_estimators=51............
# [CV 5/5; 7/10] END max_depth=4, max_features=sqrt, n_estimators=51;, score=0.942 total time=   0.1s
# [CV 1/5; 8/10] START max_depth=4, max_features=log2, n_estimators=79............
# [CV 1/5; 8/10] END max_depth=4, max_features=log2, n_estimators=79;, score=0.947 total time=   0.1s
# [CV 2/5; 8/10] START max_depth=4, max_features=log2, n_estimators=79............
# [CV 2/5; 8/10] END max_depth=4, max_features=log2, n_estimators=79;, score=0.944 total time=   0.1s
# [CV 3/5; 8/10] START max_depth=4, max_features=log2, n_estimators=79............
# [CV 3/5; 8/10] END max_depth=4, max_features=log2, n_estimators=79;, score=0.957 total time=   0.1s
# [CV 4/5; 8/10] START max_depth=4, max_features=log2, n_estimators=79............
# [CV 4/5; 8/10] END max_depth=4, max_features=log2, n_estimators=79;, score=0.942 total time=   0.1s
# [CV 5/5; 8/10] START max_depth=4, max_features=log2, n_estimators=79............
# [CV 5/5; 8/10] END max_depth=4, max_features=log2, n_estimators=79;, score=0.951 total time=   0.1s
# [CV 1/5; 9/10] START max_depth=4, max_features=log2, n_estimators=113...........
# [CV 1/5; 9/10] END max_depth=4, max_features=log2, n_estimators=113;, score=0.943 total time=   0.2s
# [CV 2/5; 9/10] START max_depth=4, max_features=log2, n_estimators=113...........
# [CV 2/5; 9/10] END max_depth=4, max_features=log2, n_estimators=113;, score=0.947 total time=   0.2s
# [CV 3/5; 9/10] START max_depth=4, max_features=log2, n_estimators=113...........
# [CV 3/5; 9/10] END max_depth=4, max_features=log2, n_estimators=113;, score=0.959 total time=   0.2s
# [CV 4/5; 9/10] START max_depth=4, max_features=log2, n_estimators=113...........
# [CV 4/5; 9/10] END max_depth=4, max_features=log2, n_estimators=113;, score=0.950 total time=   0.2s
# [CV 5/5; 9/10] START max_depth=4, max_features=log2, n_estimators=113...........
# [CV 5/5; 9/10] END max_depth=4, max_features=log2, n_estimators=113;, score=0.951 total time=   0.2s
# [CV 1/5; 10/10] START max_depth=4, max_features=sqrt, n_estimators=82...........
# [CV 1/5; 10/10] END max_depth=4, max_features=sqrt, n_estimators=82;, score=0.951 total time=   0.2s
# [CV 2/5; 10/10] START max_depth=4, max_features=sqrt, n_estimators=82...........
# [CV 2/5; 10/10] END max_depth=4, max_features=sqrt, n_estimators=82;, score=0.939 total time=   0.2s
# [CV 3/5; 10/10] START max_depth=4, max_features=sqrt, n_estimators=82...........
# [CV 3/5; 10/10] END max_depth=4, max_features=sqrt, n_estimators=82;, score=0.962 total time=   0.2s
# [CV 4/5; 10/10] START max_depth=4, max_features=sqrt, n_estimators=82...........
# [CV 4/5; 10/10] END max_depth=4, max_features=sqrt, n_estimators=82;, score=0.944 total time=   0.2s
# [CV 5/5; 10/10] START max_depth=4, max_features=sqrt, n_estimators=82...........
# [CV 5/5; 10/10] END max_depth=4, max_features=sqrt, n_estimators=82;, score=0.957 total time=   0.2s
# Precisión: 95.4%

# %% [markdown]
# ### Mejorar la búsqueda de parámetros: BayesianOptimization
#
# Optimización Bayesiana es una técnica avanzada de búsqueda de parámetros. Para poder emplearla hay que instalar la librería scikit-optimize. El uso de dicha técnica es similar a las ya empleadas con la diferencia que el rango de los parámetros hay que definirlos teniendo en cuenta además el tipo de los mismos: real, entero o categórico. Además los valores a probar no se listan explícitamente si no que se especifica un rango dentro del cual el algoritmo escogerá los valores.
#
# La ejecución puede resultar más lenta pero se pueden explorar más parámetros, de hecho se especifica un intervalo en lugar de valores concretos.

# %%
# !pip install scikit-optimize
# Out:
# Requirement already satisfied: scikit-optimize in /home/yassin/anaconda3/lib/python3.11/site-packages (0.10.1)
# Requirement already satisfied: joblib>=0.11 in /home/yassin/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.2.0)
# Requirement already satisfied: pyaml>=16.9 in /home/yassin/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (24.4.0)
# Requirement already satisfied: numpy>=1.20.3 in /home/yassin/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /home/yassin/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.11.4)
# Requirement already satisfied: scikit-learn>=1.0.0 in /home/yassin/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (1.4.2)
# Requirement already satisfied: packaging>=21.3 in /home/yassin/anaconda3/lib/python3.11/site-packages (from scikit-optimize) (23.1)
# Requirement already satisfied: PyYAML in /home/yassin/anaconda3/lib/python3.11/site-packages (from pyaml>=16.9->scikit-optimize) (6.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/yassin/anaconda3/lib/python3.11/site-packages (from scikit-learn>=1.0.0->scikit-optimize) (2.2.0)

# %%
from skopt import BayesSearchCV
from skopt.space import Real, Categorical, Integer
BS = BayesSearchCV(GradientBoostingClassifier(), G, scoring='accuracy', n_iter=10, refit=True, cv=5, verbose=10)

acc = BS.fit(X_train, y_train).score(X_test, y_test)
print(f'Precisión: {acc:.1%} con {BS.best_params_}')
# Out:
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=52.............
# /home/yassin/anaconda3/lib/python3.11/site-packages/skopt/space/space.py:110: UserWarning: Dimension [50, 150] was inferred to Integer(low=50, high=150, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 150), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# /home/yassin/anaconda3/lib/python3.11/site-packages/skopt/space/space.py:110: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# /home/yassin/anaconda3/lib/python3.11/site-packages/skopt/space/space.py:110: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# /home/yassin/anaconda3/lib/python3.11/site-packages/skopt/space/space.py:110: UserWarning: Dimension [50, 150] was inferred to Integer(low=50, high=150, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 150), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# /home/yassin/anaconda3/lib/python3.11/site-packages/skopt/space/space.py:110: UserWarning: Dimension [3, 5] was inferred to Integer(low=3, high=5, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(3, 5), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# /home/yassin/anaconda3/lib/python3.11/site-packages/skopt/space/space.py:110: UserWarning: Dimension [50, 150] was inferred to Integer(low=50, high=150, prior='uniform', transform='identity'). In upcoming versions of scikit-optimize, it will be inferred to Categorical(categories=(50, 150), prior=None). See the documentation of the check_dimension function for the upcoming API.
#   warnings.warn(
# [CV 1/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=52;, score=0.948 total time=   0.2s
# [CV 2/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=52.............
# [CV 2/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=52;, score=0.931 total time=   0.1s
# [CV 3/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=52.............
# [CV 3/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=52;, score=0.943 total time=   0.1s
# [CV 4/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=52.............
# [CV 4/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=52;, score=0.936 total time=   0.1s
# [CV 5/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=52.............
# [CV 5/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=52;, score=0.951 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=5, max_features=log2, n_estimators=92.............
# [CV 1/5; 1/1] END max_depth=5, max_features=log2, n_estimators=92;, score=0.951 total time=   0.3s
# [CV 2/5; 1/1] START max_depth=5, max_features=log2, n_estimators=92.............
# [CV 2/5; 1/1] END max_depth=5, max_features=log2, n_estimators=92;, score=0.950 total time=   0.3s
# [CV 3/5; 1/1] START max_depth=5, max_features=log2, n_estimators=92.............
# [CV 3/5; 1/1] END max_depth=5, max_features=log2, n_estimators=92;, score=0.965 total time=   0.3s
# [CV 4/5; 1/1] START max_depth=5, max_features=log2, n_estimators=92.............
# [CV 4/5; 1/1] END max_depth=5, max_features=log2, n_estimators=92;, score=0.951 total time=   0.2s
# [CV 5/5; 1/1] START max_depth=5, max_features=log2, n_estimators=92.............
# [CV 5/5; 1/1] END max_depth=5, max_features=log2, n_estimators=92;, score=0.957 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=3, max_features=log2, n_estimators=59.............
# [CV 1/5; 1/1] END max_depth=3, max_features=log2, n_estimators=59;, score=0.939 total time=   0.1s
# [CV 2/5; 1/1] START max_depth=3, max_features=log2, n_estimators=59.............
# [CV 2/5; 1/1] END max_depth=3, max_features=log2, n_estimators=59;, score=0.928 total time=   0.1s
# [CV 3/5; 1/1] START max_depth=3, max_features=log2, n_estimators=59.............
# [CV 3/5; 1/1] END max_depth=3, max_features=log2, n_estimators=59;, score=0.943 total time=   0.1s
# [CV 4/5; 1/1] START max_depth=3, max_features=log2, n_estimators=59.............
# [CV 4/5; 1/1] END max_depth=3, max_features=log2, n_estimators=59;, score=0.933 total time=   0.1s
# [CV 5/5; 1/1] START max_depth=3, max_features=log2, n_estimators=59.............
# [CV 5/5; 1/1] END max_depth=3, max_features=log2, n_estimators=59;, score=0.933 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=57.............
# [CV 1/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=57;, score=0.946 total time=   0.1s
# [CV 2/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=57.............
# [CV 2/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=57;, score=0.936 total time=   0.2s
# [CV 3/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=57.............
# [CV 3/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=57;, score=0.951 total time=   0.2s
# [CV 4/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=57.............
# [CV 4/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=57;, score=0.933 total time=   0.2s
# [CV 5/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=57.............
# [CV 5/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=57;, score=0.944 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=5, max_features=log2, n_estimators=94.............
# [CV 1/5; 1/1] END max_depth=5, max_features=log2, n_estimators=94;, score=0.951 total time=   0.3s
# [CV 2/5; 1/1] START max_depth=5, max_features=log2, n_estimators=94.............
# [CV 2/5; 1/1] END max_depth=5, max_features=log2, n_estimators=94;, score=0.954 total time=   0.3s
# [CV 3/5; 1/1] START max_depth=5, max_features=log2, n_estimators=94.............
# [CV 3/5; 1/1] END max_depth=5, max_features=log2, n_estimators=94;, score=0.957 total time=   0.3s
# [CV 4/5; 1/1] START max_depth=5, max_features=log2, n_estimators=94.............
# [CV 4/5; 1/1] END max_depth=5, max_features=log2, n_estimators=94;, score=0.948 total time=   0.3s
# [CV 5/5; 1/1] START max_depth=5, max_features=log2, n_estimators=94.............
# [CV 5/5; 1/1] END max_depth=5, max_features=log2, n_estimators=94;, score=0.954 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=5, max_features=log2, n_estimators=81.............
# [CV 1/5; 1/1] END max_depth=5, max_features=log2, n_estimators=81;, score=0.950 total time=   0.2s
# [CV 2/5; 1/1] START max_depth=5, max_features=log2, n_estimators=81.............
# [CV 2/5; 1/1] END max_depth=5, max_features=log2, n_estimators=81;, score=0.944 total time=   0.3s
# [CV 3/5; 1/1] START max_depth=5, max_features=log2, n_estimators=81.............
# [CV 3/5; 1/1] END max_depth=5, max_features=log2, n_estimators=81;, score=0.963 total time=   0.2s
# [CV 4/5; 1/1] START max_depth=5, max_features=log2, n_estimators=81.............
# [CV 4/5; 1/1] END max_depth=5, max_features=log2, n_estimators=81;, score=0.952 total time=   0.2s
# [CV 5/5; 1/1] START max_depth=5, max_features=log2, n_estimators=81.............
# [CV 5/5; 1/1] END max_depth=5, max_features=log2, n_estimators=81;, score=0.959 total time=   0.2s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=3, max_features=log2, n_estimators=98.............
# [CV 1/5; 1/1] END max_depth=3, max_features=log2, n_estimators=98;, score=0.943 total time=   0.1s
# [CV 2/5; 1/1] START max_depth=3, max_features=log2, n_estimators=98.............
# [CV 2/5; 1/1] END max_depth=3, max_features=log2, n_estimators=98;, score=0.946 total time=   0.1s
# [CV 3/5; 1/1] START max_depth=3, max_features=log2, n_estimators=98.............
# [CV 3/5; 1/1] END max_depth=3, max_features=log2, n_estimators=98;, score=0.959 total time=   0.1s
# [CV 4/5; 1/1] START max_depth=3, max_features=log2, n_estimators=98.............
# [CV 4/5; 1/1] END max_depth=3, max_features=log2, n_estimators=98;, score=0.939 total time=   0.1s
# [CV 5/5; 1/1] START max_depth=3, max_features=log2, n_estimators=98.............
# [CV 5/5; 1/1] END max_depth=3, max_features=log2, n_estimators=98;, score=0.947 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=131............
# [CV 1/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=131;, score=0.944 total time=   0.3s
# [CV 2/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=131............
# [CV 2/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=131;, score=0.944 total time=   0.3s
# [CV 3/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=131............
# [CV 3/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=131;, score=0.958 total time=   0.3s
# [CV 4/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=131............
# [CV 4/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=131;, score=0.947 total time=   0.3s
# [CV 5/5; 1/1] START max_depth=4, max_features=sqrt, n_estimators=131............
# [CV 5/5; 1/1] END max_depth=4, max_features=sqrt, n_estimators=131;, score=0.955 total time=   0.3s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=4, max_features=log2, n_estimators=60.............
# [CV 1/5; 1/1] END max_depth=4, max_features=log2, n_estimators=60;, score=0.950 total time=   0.1s
# [CV 2/5; 1/1] START max_depth=4, max_features=log2, n_estimators=60.............
# [CV 2/5; 1/1] END max_depth=4, max_features=log2, n_estimators=60;, score=0.938 total time=   0.1s
# [CV 3/5; 1/1] START max_depth=4, max_features=log2, n_estimators=60.............
# [CV 3/5; 1/1] END max_depth=4, max_features=log2, n_estimators=60;, score=0.959 total time=   0.1s
# [CV 4/5; 1/1] START max_depth=4, max_features=log2, n_estimators=60.............
# [CV 4/5; 1/1] END max_depth=4, max_features=log2, n_estimators=60;, score=0.943 total time=   0.1s
# [CV 5/5; 1/1] START max_depth=4, max_features=log2, n_estimators=60.............
# [CV 5/5; 1/1] END max_depth=4, max_features=log2, n_estimators=60;, score=0.948 total time=   0.1s
# Fitting 5 folds for each of 1 candidates, totalling 5 fits
# [CV 1/5; 1/1] START max_depth=5, max_features=sqrt, n_estimators=106............
# [CV 1/5; 1/1] END max_depth=5, max_features=sqrt, n_estimators=106;, score=0.946 total time=   0.4s
# [CV 2/5; 1/1] START max_depth=5, max_features=sqrt, n_estimators=106............
# [CV 2/5; 1/1] END max_depth=5, max_features=sqrt, n_estimators=106;, score=0.947 total time=   0.4s
# [CV 3/5; 1/1] START max_depth=5, max_features=sqrt, n_estimators=106............
# [CV 3/5; 1/1] END max_depth=5, max_features=sqrt, n_estimators=106;, score=0.961 total time=   0.3s
# [CV 4/5; 1/1] START max_depth=5, max_features=sqrt, n_estimators=106............
# [CV 4/5; 1/1] END max_depth=5, max_features=sqrt, n_estimators=106;, score=0.947 total time=   0.3s
# [CV 5/5; 1/1] START max_depth=5, max_features=sqrt, n_estimators=106............
# [CV 5/5; 1/1] END max_depth=5, max_features=sqrt, n_estimators=106;, score=0.952 total time=   0.3s
# Precisión: 95.5% con OrderedDict([('max_depth', 5), ('max_features', 'log2'), ('n_estimators', 92)])

# %% [markdown]
# ## HistGradientBoostingClassifier
# Un problema del clasificador GradientBoosting implementado en sklearn es su velocidad. Es un clasificador muy lento de entrenar. Por ello sklearn propone otro tipo de algoritmo de GradientBoosting que soporta paralelismo con OMP además de otras mejoras computacionales basadas en la discretización de las componentes mediante un histograma.
#
# Este otro algoritmo se denomina **HistGradientBoostingClassifier**. Su tiempo de ejecución es mucho mejor. Además se pueden obtener mejores resultados.

# %% [markdown]
# **Ejercicio** Analiza en la documentación [HistGradientBoosting](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingClassifier.html) los parámetros más relevantes y realiza una búsqueda de parámetros para obtener el mejor clasificador. A la hora de establecer los valores de los parámetros sería interesante fijarnos en los valores por defecto que se han empleado en el ejercicio anterior y poder explorar alrededor de dichos valores por defecto para conseguir mejores resultados.

# %%
from sklearn.experimental import enable_hist_gradient_boosting
from sklearn.ensemble import HistGradientBoostingClassifier

hgb = HistGradientBoostingClassifier()

G = {
    'learning_rate': [0.01, 0.1, 0.2],
    'max_iter': sp_randint(50, 200),
    'max_leaf_nodes': sp_randint(20, 100),
    'max_depth': [3, 5, 7,10],
    'min_samples_leaf': sp_randint(20, 50),
    'l2_regularization': [0.0, 0.1, 0.5],
    'max_bins': sp_randint(200, 255)
}

# Configurar el RandomizedSearchCV
RS = RandomizedSearchCV(hgb, param_distributions= G, n_iter=20, refit = True, cv=5, scoring='accuracy', random_state=42, verbose=10)

# Ajustar el modelo
acc = RS.fit(X_train, y_train).score(X_test, y_test)

print(f'Precisión: {acc:.1%}')
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [CV 1/5; 1/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40
# /home/yassin/anaconda3/lib/python3.11/site-packages/sklearn/experimental/enable_hist_gradient_boosting.py:15: UserWarning: Since version 1.0, it is not needed to import enable_hist_gradient_boosting anymore. HistGradientBoostingClassifier and HistGradientBoostingRegressor are now stable and can be normally imported from sklearn.ensemble.
#   warnings.warn(
# [CV 1/5; 1/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40;, score=0.914 total time=   0.3s
# [CV 2/5; 1/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40
# [CV 2/5; 1/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40;, score=0.906 total time=   0.2s
# [CV 3/5; 1/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40
# [CV 3/5; 1/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40;, score=0.928 total time=   0.3s
# [CV 4/5; 1/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40
# [CV 4/5; 1/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40;, score=0.920 total time=   0.3s
# [CV 5/5; 1/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40
# [CV 5/5; 1/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=214, max_depth=7, max_iter=121, max_leaf_nodes=80, min_samples_leaf=40;, score=0.924 total time=   0.3s
# [CV 1/5; 2/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43
# [CV 1/5; 2/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43;, score=0.951 total time=   0.3s
# [CV 2/5; 2/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43
# [CV 2/5; 2/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43;, score=0.947 total time=   0.3s
# [CV 3/5; 2/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43
# [CV 3/5; 2/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43;, score=0.962 total time=   0.3s
# [CV 4/5; 2/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43
# [CV 4/5; 2/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43;, score=0.942 total time=   0.2s
# [CV 5/5; 2/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43
# [CV 5/5; 2/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=218, max_depth=7, max_iter=124, max_leaf_nodes=94, min_samples_leaf=43;, score=0.963 total time=   0.2s
# [CV 1/5; 3/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25
# [CV 1/5; 3/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25;, score=0.944 total time=   0.0s
# [CV 2/5; 3/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25
# [CV 2/5; 3/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25;, score=0.939 total time=   0.1s
# [CV 3/5; 3/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25
# [CV 3/5; 3/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25;, score=0.957 total time=   0.0s
# [CV 4/5; 3/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25
# [CV 4/5; 3/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25;, score=0.942 total time=   0.0s
# [CV 5/5; 3/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25
# [CV 5/5; 3/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=221, max_depth=3, max_iter=51, max_leaf_nodes=49, min_samples_leaf=25;, score=0.958 total time=   0.0s
# [CV 1/5; 4/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48
# [CV 1/5; 4/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48;, score=0.916 total time=   0.2s
# [CV 2/5; 4/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48
# [CV 2/5; 4/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48;, score=0.899 total time=   0.2s
# [CV 3/5; 4/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48
# [CV 3/5; 4/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48;, score=0.929 total time=   0.2s
# [CV 4/5; 4/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48
# [CV 4/5; 4/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48;, score=0.920 total time=   0.2s
# [CV 5/5; 4/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48
# [CV 5/5; 4/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=232, max_depth=10, max_iter=107, max_leaf_nodes=41, min_samples_leaf=48;, score=0.920 total time=   0.2s
# [CV 1/5; 5/20] START l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49
# [CV 1/5; 5/20] END l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49;, score=0.897 total time=   0.1s
# [CV 2/5; 5/20] START l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49
# [CV 2/5; 5/20] END l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49;, score=0.893 total time=   0.1s
# [CV 3/5; 5/20] START l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49
# [CV 3/5; 5/20] END l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49;, score=0.916 total time=   0.1s
# [CV 4/5; 5/20] START l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49
# [CV 4/5; 5/20] END l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49;, score=0.899 total time=   0.1s
# [CV 5/5; 5/20] START l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49
# [CV 5/5; 5/20] END l2_regularization=0.0, learning_rate=0.01, max_bins=226, max_depth=7, max_iter=64, max_leaf_nodes=81, min_samples_leaf=49;, score=0.910 total time=   0.1s
# [CV 1/5; 6/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44
# [CV 1/5; 6/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44;, score=0.947 total time=   0.2s
# [CV 2/5; 6/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44
# [CV 2/5; 6/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44;, score=0.952 total time=   0.2s
# [CV 3/5; 6/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44
# [CV 3/5; 6/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44;, score=0.963 total time=   0.2s
# [CV 4/5; 6/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44
# [CV 4/5; 6/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44;, score=0.952 total time=   0.2s
# [CV 5/5; 6/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44
# [CV 5/5; 6/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=250, max_depth=10, max_iter=104, max_leaf_nodes=83, min_samples_leaf=44;, score=0.958 total time=   0.2s
# [CV 1/5; 7/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26
# [CV 1/5; 7/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26;, score=0.910 total time=   0.1s
# [CV 2/5; 7/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26
# [CV 2/5; 7/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26;, score=0.908 total time=   0.2s
# [CV 3/5; 7/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26
# [CV 3/5; 7/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26;, score=0.918 total time=   0.2s
# [CV 4/5; 7/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26
# [CV 4/5; 7/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26;, score=0.905 total time=   0.1s
# [CV 5/5; 7/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26
# [CV 5/5; 7/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=250, max_depth=7, max_iter=70, max_leaf_nodes=92, min_samples_leaf=26;, score=0.917 total time=   0.1s
# [CV 1/5; 8/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21
# [CV 1/5; 8/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21;, score=0.899 total time=   0.1s
# [CV 2/5; 8/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21
# [CV 2/5; 8/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21;, score=0.905 total time=   0.1s
# [CV 3/5; 8/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21
# [CV 3/5; 8/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21;, score=0.920 total time=   0.1s
# [CV 4/5; 8/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21
# [CV 4/5; 8/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21;, score=0.894 total time=   0.1s
# [CV 5/5; 8/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21
# [CV 5/5; 8/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=213, max_depth=5, max_iter=58, max_leaf_nodes=72, min_samples_leaf=21;, score=0.913 total time=   0.1s
# [CV 1/5; 9/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22
# [CV 1/5; 9/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22;, score=0.946 total time=   0.0s
# [CV 2/5; 9/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22
# [CV 2/5; 9/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22;, score=0.939 total time=   0.0s
# [CV 3/5; 9/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22
# [CV 3/5; 9/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22;, score=0.957 total time=   0.0s
# [CV 4/5; 9/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22
# [CV 4/5; 9/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22;, score=0.938 total time=   0.0s
# [CV 5/5; 9/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22
# [CV 5/5; 9/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=243, max_depth=3, max_iter=57, max_leaf_nodes=66, min_samples_leaf=22;, score=0.955 total time=   0.0s
# [CV 1/5; 10/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21
# [CV 1/5; 10/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21;, score=0.924 total time=   0.2s
# [CV 2/5; 10/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21
# [CV 2/5; 10/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21;, score=0.913 total time=   0.2s
# [CV 3/5; 10/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21
# [CV 3/5; 10/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21;, score=0.932 total time=   0.2s
# [CV 4/5; 10/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21
# [CV 4/5; 10/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21;, score=0.931 total time=   0.2s
# [CV 5/5; 10/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21
# [CV 5/5; 10/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=235, max_depth=5, max_iter=153, max_leaf_nodes=23, min_samples_leaf=21;, score=0.923 total time=   0.2s
# [CV 1/5; 11/20] START l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48
# [CV 1/5; 11/20] END l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48;, score=0.942 total time=   0.1s
# [CV 2/5; 11/20] START l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48
# [CV 2/5; 11/20] END l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48;, score=0.931 total time=   0.1s
# [CV 3/5; 11/20] START l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48
# [CV 3/5; 11/20] END l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48;, score=0.954 total time=   0.1s
# [CV 4/5; 11/20] START l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48
# [CV 4/5; 11/20] END l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48;, score=0.938 total time=   0.1s
# [CV 5/5; 11/20] START l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48
# [CV 5/5; 11/20] END l2_regularization=0.1, learning_rate=0.1, max_bins=253, max_depth=5, max_iter=53, max_leaf_nodes=73, min_samples_leaf=48;, score=0.946 total time=   0.1s
# [CV 1/5; 12/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34
# [CV 1/5; 12/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34;, score=0.946 total time=   0.1s
# [CV 2/5; 12/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34
# [CV 2/5; 12/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34;, score=0.947 total time=   0.1s
# [CV 3/5; 12/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34
# [CV 3/5; 12/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34;, score=0.965 total time=   0.2s
# [CV 4/5; 12/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34
# [CV 4/5; 12/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34;, score=0.950 total time=   0.2s
# [CV 5/5; 12/20] START l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34
# [CV 5/5; 12/20] END l2_regularization=0.5, learning_rate=0.1, max_bins=225, max_depth=10, max_iter=63, max_leaf_nodes=67, min_samples_leaf=34;, score=0.952 total time=   0.2s
# [CV 1/5; 13/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43
# [CV 1/5; 13/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43;, score=0.944 total time=   0.1s
# [CV 2/5; 13/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43
# [CV 2/5; 13/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43;, score=0.940 total time=   0.1s
# [CV 3/5; 13/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43
# [CV 3/5; 13/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43;, score=0.966 total time=   0.1s
# [CV 4/5; 13/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43
# [CV 4/5; 13/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43;, score=0.944 total time=   0.1s
# [CV 5/5; 13/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43
# [CV 5/5; 13/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=239, max_depth=3, max_iter=131, max_leaf_nodes=72, min_samples_leaf=43;, score=0.957 total time=   0.1s
# [CV 1/5; 14/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20
# [CV 1/5; 14/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20;, score=0.908 total time=   0.0s
# [CV 2/5; 14/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20
# [CV 2/5; 14/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20;, score=0.893 total time=   0.0s
# [CV 3/5; 14/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20
# [CV 3/5; 14/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20;, score=0.909 total time=   0.1s
# [CV 4/5; 14/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20
# [CV 4/5; 14/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20;, score=0.886 total time=   0.0s
# [CV 5/5; 14/20] START l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20
# [CV 5/5; 14/20] END l2_regularization=0.1, learning_rate=0.01, max_bins=244, max_depth=3, max_iter=64, max_leaf_nodes=64, min_samples_leaf=20;, score=0.899 total time=   0.1s
# [CV 1/5; 15/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43
# [CV 1/5; 15/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43;, score=0.951 total time=   0.4s
# [CV 2/5; 15/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43
# [CV 2/5; 15/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43;, score=0.947 total time=   0.3s
# [CV 3/5; 15/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43
# [CV 3/5; 15/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43;, score=0.970 total time=   0.4s
# [CV 4/5; 15/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43
# [CV 4/5; 15/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43;, score=0.952 total time=   0.3s
# [CV 5/5; 15/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43
# [CV 5/5; 15/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=208, max_depth=10, max_iter=178, max_leaf_nodes=27, min_samples_leaf=43;, score=0.958 total time=   0.3s
# [CV 1/5; 16/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22
# [CV 1/5; 16/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22;, score=0.952 total time=   0.1s
# [CV 2/5; 16/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22
# [CV 2/5; 16/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22;, score=0.947 total time=   0.1s
# [CV 3/5; 16/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22
# [CV 3/5; 16/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22;, score=0.963 total time=   0.1s
# [CV 4/5; 16/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22
# [CV 4/5; 16/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22;, score=0.936 total time=   0.1s
# [CV 5/5; 16/20] START l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22
# [CV 5/5; 16/20] END l2_regularization=0.5, learning_rate=0.2, max_bins=250, max_depth=3, max_iter=185, max_leaf_nodes=54, min_samples_leaf=22;, score=0.957 total time=   0.1s
# [CV 1/5; 17/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26
# [CV 1/5; 17/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26;, score=0.955 total time=   0.1s
# [CV 2/5; 17/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26
# [CV 2/5; 17/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26;, score=0.950 total time=   0.1s
# [CV 3/5; 17/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26
# [CV 3/5; 17/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26;, score=0.965 total time=   0.1s
# [CV 4/5; 17/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26
# [CV 4/5; 17/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26;, score=0.946 total time=   0.1s
# [CV 5/5; 17/20] START l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26
# [CV 5/5; 17/20] END l2_regularization=0.0, learning_rate=0.2, max_bins=204, max_depth=5, max_iter=90, max_leaf_nodes=47, min_samples_leaf=26;, score=0.959 total time=   0.1s
# [CV 1/5; 18/20] START l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22
# [CV 1/5; 18/20] END l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22;, score=0.950 total time=   0.3s
# [CV 2/5; 18/20] START l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22
# [CV 2/5; 18/20] END l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22;, score=0.961 total time=   0.4s
# [CV 3/5; 18/20] START l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22
# [CV 3/5; 18/20] END l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22;, score=0.967 total time=   0.4s
# [CV 4/5; 18/20] START l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22
# [CV 4/5; 18/20] END l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22;, score=0.948 total time=   0.5s
# [CV 5/5; 18/20] START l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22
# [CV 5/5; 18/20] END l2_regularization=0.0, learning_rate=0.1, max_bins=232, max_depth=10, max_iter=111, max_leaf_nodes=56, min_samples_leaf=22;, score=0.959 total time=   0.6s
# [CV 1/5; 19/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33
# [CV 1/5; 19/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33;, score=0.951 total time=   0.2s
# [CV 2/5; 19/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33
# [CV 2/5; 19/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33;, score=0.942 total time=   0.3s
# [CV 3/5; 19/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33
# [CV 3/5; 19/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33;, score=0.967 total time=   0.2s
# [CV 4/5; 19/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33
# [CV 4/5; 19/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33;, score=0.947 total time=   0.2s
# [CV 5/5; 19/20] START l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33
# [CV 5/5; 19/20] END l2_regularization=0.1, learning_rate=0.2, max_bins=234, max_depth=3, max_iter=150, max_leaf_nodes=66, min_samples_leaf=33;, score=0.957 total time=   0.2s
# [CV 1/5; 20/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28
# [CV 1/5; 20/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28;, score=0.929 total time=   0.4s
# [CV 2/5; 20/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28
# [CV 2/5; 20/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28;, score=0.918 total time=   0.4s
# [CV 3/5; 20/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28
# [CV 3/5; 20/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28;, score=0.938 total time=   0.4s
# [CV 4/5; 20/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28
# [CV 4/5; 20/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28;, score=0.929 total time=   0.4s
# [CV 5/5; 20/20] START l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28
# [CV 5/5; 20/20] END l2_regularization=0.5, learning_rate=0.01, max_bins=204, max_depth=5, max_iter=191, max_leaf_nodes=46, min_samples_leaf=28;, score=0.928 total time=   0.4s
# Precisión: 95.4%
